# %%
import spacy
from spacy.lang.en import English
from spacy.pipeline import EntityRuler
from spacy.util import minibatch, compounding
from spacy.training.example import Example
from pathlib import Path
import json
import time
import random
#Data loading/ Data manipulation
import pandas as pd
import numpy as np
import jsonlines

# %%
df = pd.read_csv("Resume/Resume.csv")
df = df.reindex(np.random.permutation(df.index))
data = df.copy().iloc[0:500]
data.head()
# Out:
#             ID                                         Resume_str  \
# 1764  28923650           THERMAL ENGINEERING INTERN       Summ...
# 552   28871170           ORGANIZER AND CAPACITY BUILDING STRAT...
# 2031  22546476           SAFETY MANAGER           Summary     ...
# 2037  12695537           UTILITY ENGINEER       Profile    Det...
# 1086  70528646           SALES REPRESENTATIVE       Summary   ...
#
#                                             Resume_html      Category
# 1764  <div class="fontsize fontface vmargins hmargin...   ENGINEERING
# 552   <div class="fontsize fontface vmargins hmargin...      ADVOCATE
# 2031  <div class="fontsize fontface vmargins hmargin...  CONSTRUCTION
# 2037  <div class="fontsize fontface vmargins hmargin...  CONSTRUCTION
# 1086  <div class="fontsize fontface vmargins hmargin...         SALES

# %%
def load_data(file):
    with open(file, 'r',encoding='utf-8') as f:
        data = json.load(f)
    return(data)

# %%
def save_data(file, data):
    with open(file , 'w' , encoding='utf-8') as f:
        json.dump(data , f , indent = 4)

# %%
def generate_more_data(file):
    data = load_data(file)
    new_char = []
    for item in data:
        new_char.append(item)
    final_characters = []
    for character in new_char:
        if "" != character:
            final_characters.append(character)
    final_char = list(set(final_characters))
    return final_char

# %%
def create_training_data(file, type):
    data = generate_more_data(file)
    patterns=[]
    for item in data:
        pattern = {
                    "label": type ,
                    "pattern" : item
                 }
        patterns.append(pattern)
    return patterns

# %%
def generate_rules(pattern, name):
    nlp = English()
    ruler = EntityRuler(nlp)
    
    ruler = nlp.add_pipe('entity_ruler')
    ruler.add_patterns(pattern)
    nlp.to_disk('{}_ner'.format(name))

# %%
def test_model(model,text):
    doc = model(text)
    results = []
    entities = []
    for ent in doc.ents:
        entities.append((ent.start_char,ent.end_char , ent.label_))
    if len(entities)>0:
        results = [text , {'entities':entities}]

    return results

# %%
def generate_training_data(model , data):
    Training_Data = []
    for d in data:
        segments =  d.split('\n\n')
        for seg in segments:
            seg = seg.strip()
            seg = seg.replace("\n"," ")
            results = test_model(model, seg)
            if results != None and results !=[] :
                Training_Data.append(results)
    return Training_Data

# %%
def train_spacy(data, iterations):
    start = time.process_time()
    TRAIN_DATA = data
    nlp = spacy.blank("en")
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        ner = nlp.add_pipe('ner',last = True)
    for _, annotations in TRAIN_DATA:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
    with nlp.disable_pipes(*other_pipes):
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            start2 = time.process_time()
            print ("Starting iteration " + str(itn+1))
            random.shuffle(TRAIN_DATA)
            losses = {}
            batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
            
            for batch in batches:
                for text, annotations in batch:
                    doc = nlp.make_doc(text)
                    example = Example.from_dict(doc, annotations)
                texts, annotations = zip(*batch)
                nlp.update(
                            [example],
                            drop=0.2,
                            sgd=optimizer,
                            losses=losses
                )
            print (losses)
            print("Time for iteration " + str(itn+1)+":",time.process_time() - start2, "sec\n")
    print("Total Time",time.process_time() - start, "sec")
    return (nlp)

# %%
def all_in_one(json_file , data , label ):
    patterns = create_training_data(json_file,label)
    generate_rules(patterns, label)
    rules = spacy.load('{}_ner'.format(label))
    Training_Data = generate_training_data(rules , data)
    save_data("Training_Data_{}.json".format(label),Training_Data)
    print('copy the code to load the training data :\n TRAIN_DATA_{} = load_data("Training_Data_{}.json") '.format(label,label))

# %% [markdown]
# ## 1. Company model

# %%
characters = generate_more_data('Companies.json')
characters
# Out:
# ['Interpublic Group of Companies Inc.',
#  'Southern California Edison',
#  'NRB Bearing',
#  'Kelly Services Inc.',
#  'Kotak Life Insurance Co. Ltd.',
#  'Bernhard Schulte Shipmanagement',
#  'Nagra Vision',
#  'Tesoro',
#  'Conectiv, Inc',
#  'Seagate Technology',
#  'Silicon Graphics',
#  'Arrow Electronics',
#  'Wachovia Corporation',
#  'Accord Investments',
#  'DTE Energy Co.',
#  'Soma Enterprises',
#  'WWE',
#  'AdvancePCS, Inc.',
#  'Winnebago Industries',
#  'VIZ Media',
#  'Johnson & Johnson',
#  'Adobe Systems Inc.',
#  'DPL Inc.',
#  'Rurash Financial',
#  'Northrop Grumman Corporation',
#  'United Parcel Service Inc',
#  'Star Merchant Services',
#  'Sun Pharma Industries Limited',
#  'Maytag Corporation',
#  'GeoSpoc Geospatial Services Pvt. Ltd',
#  '20Cube',
#  'Reliance Communications',
#  'Sequoia Voting Systems',
#  'Imperial Sugar Company',
#  'StockViews',
#  'Nash Finch Company',
#  'Larsen & Toubro ECC Dvision',
#  'PepsiCo',
#  'Arrow Electronics, Inc.',
#  'Corsair Memory',
#  'Strength Gurus',
#  'AnnTaylor Inc.',
#  'Lear Corporation',
#  'Indus Valley Partners',
#  'Sherwin-Williams Company',
#  'TRW Inc',
#  'Apollo Group',
#  'Greyvoid',
#  'EbixCash Financial Technologies',
#  'Pacific Gas & Electric Company (PG&E)',
#  'Spherion',
#  'Kurzweil Educational Systems',
#  'OSI Restaurant Partners',
#  'Becton Dickinson',
#  'Mutual of Omaha',
#  'Campbell Soup Co.',
#  'Awfis Space Solutions Private Limited',
#  'Union Planters Corp',
#  'Magna Consulting',
#  'Planet Spark',
#  'BMC Software',
#  'Cerner Corporation',
#  'A+ Electronics',
#  'Ericsson India',
#  'Office Depot Inc.',
#  'AND1',
#  'Mahindra Logistics',
#  'Citigroup, Inc',
#  'Dover Corporation',
#  'ExxonMobil Corporation',
#  'Client Associates',
#  'First Tennessee National Corp.',
#  'Nucor Corp',
#  'The Jolly Farmer',
#  'AMETEK',
#  'Axxela Advisory',
#  'Medtronic Inc.',
#  'GenCorp Inc.',
#  'Belk',
#  'National Semiconductor Corporation',
#  'Pactiv Corp',
#  'Waste Management Inc',
#  'Shaw Group Inc',
#  'Reliable Garden Management',
#  'Enterasys Networks',
#  'Caparo Corporate Services',
#  'DST Systems',
#  'Smith International Inc',
#  'Telephone & Data Systems Inc',
#  'Adolph Coors Company',
#  "Welch's",
#  'Stratapro',
#  'Bizoneer consulting',
#  'Ace Hardware Corporation',
#  'ARAMARK Corporation',
#  'Interstate Batteries',
#  'Tejas Networks',
#  'Computer Associates International Inc.',
#  'Novell',
#  'Airborne, Inc.',
#  'BorgWarner',
#  'Regalix',
#  'CMGI Inc.',
#  'Electronic Data Systems Corp.',
#  'Formula Grey',
#  'Encompass Services Corporation',
#  '6Wresearch',
#  'Belo Corp.',
#  'Magellan Health Services Inc.',
#  'CSX Corp.',
#  'Progress Energy Inc',
#  'The Happy Bear',
#  'ONEOK Inc',
#  'Landskip Yard Care',
#  'Sunoco',
#  'Realty Solution',
#  'Hub Group Inc.',
#  'Owens-Illinois Inc',
#  'M.D.C. Holdings Inc.',
#  'ZF India',
#  'Genuity Inc.',
#  'Nordstrom Inc',
#  'Arch Coal',
#  'Future Plan',
#  'uFaber Edutech Pvt Ltd.',
#  'Hike Education',
#  'Envirotecture Design',
#  "BYJU'S",
#  'Coventry Health Care',
#  'NLL Academy (NLB Services)',
#  'National Fuel Gas Company',
#  'Network Air',
#  'Adams Resources & Energy, Inc.',
#  'Matrix Interior Design',
#  'Intel',
#  'Bharti AXA Life Insurance Company Limited',
#  'R. R. Donnelley & Sons',
#  'Universal Corporation',
#  'Dex One',
#  'Thomas & Betts Corporation',
#  'Medimix International',
#  'Dynegy Inc.',
#  'CMIE',
#  'L-3 Communications Holdings Inc.',
#  'Computer Sciences Corp.',
#  'Credence Analytics',
#  'Monit',
#  'Indian Airlines',
#  'First National of Nebraska Inc.',
#  'Emcor Group Inc.',
#  'Granite Construction Incorporated',
#  'Shree Jain Roadways',
#  'Bethlehem Steel Corporation',
#  'Axis Bank',
#  'Rockwell Collins',
#  'Halliburton Co.',
#  'Pinnacle West Capital Corp',
#  'Forest Laboratories Inc.',
#  'Hyundai Motor India Limited (HMIL)',
#  'ACCO Brands',
#  'Quincy Newspapers',
#  'Sunkersett Financial Advisory',
#  'Polaris Industries',
#  'Yellow Brick Route',
#  'Morgan Stanley',
#  'Avon Products',
#  'ACC Ltd.',
#  'Best Biz Survis',
#  'Becton, Dickinson and Company',
#  'Idea Infinity',
#  'Teradyne Inc',
#  'U GRO CAPITAL',
#  'The MONY Group Inc.',
#  'Fiserv Inc.',
#  'Hughes Supply Inc.',
#  'Personal & Corporate Design',
#  'Jones Apparel Group Inc.',
#  'NTT Data Business Solutions Ltd',
#  'NIPPON PAINT (INDIA) PRIVATE LIMITED',
#  'Publix',
#  'RPM Inc.',
#  'Reebok International Ltd.',
#  'Brightpoint',
#  'Hovnanian Enterprises Inc.',
#  'Tavant Technologies Ltd',
#  'Verizon Communications Inc',
#  'Mattel Inc.',
#  'Infiniti Research Marketing Solutions',
#  'IZealiant Technologies',
#  'Diebold Incorporated',
#  'Star Assistance',
#  'Magik Gray',
#  'CH2M Hill Cos. Ltd.',
#  "Papa John's Pizza",
#  'Humana Inc.',
#  'Werner Enterprises',
#  'Cartoon Network Studios',
#  'Raytheon Company',
#  'Martin Marietta Materials Inc.',
#  'Yoma Technologies',
#  'Midwest Communications',
#  'Hawaiian Airlines',
#  'L & T Technology Services',
#  'Terra Nova Garden Services',
#  'Activision Blizzard',
#  'ArvinMeritor',
#  'OfficeMax Inc',
#  'Benchmark Electronics',
#  'MAQ Software',
#  'Gemstar-TV Guide International Inc.',
#  'Pro Star',
#  'Ferro Corp.',
#  'Phelps Dodge Corp.',
#  'Testor Corporation',
#  'Reliance Broadcast Network',
#  'Omni Source',
#  'Circuit City Stores Inc.',
#  'Teleflex Incorporated',
#  'Simplex Infrastructures',
#  'NeerInfo Solutions',
#  'Introlligent Inc.',
#  'Olan Mills, Inc.',
#  'Foamex International Inc',
#  'Marathon Oil',
#  "Victoria's Secret",
#  'Indifi Technologies Pvt. Ltd.',
#  'ConAgra Foods Inc.',
#  'Pickrr',
#  'Artivatic.ai',
#  'L&T Heavy Engineering',
#  'Idea Cellular',
#  'Family Dollar Stores Inc.',
#  'SAP Labs',
#  'RGF Executive Search India',
#  'Exide Industries',
#  'Briggs & Stratton',
#  'Levi Strauss & Co.',
#  'Extramarks Education India Pvt. Ltd',
#  'Eli Lilly and Company',
#  'Viacom',
#  'Harley-Davidson',
#  'Equity Office Properties Trust',
#  'Qpass',
#  'Storage Technology Corporation',
#  'UST Inc',
#  'Naukri.com',
#  'Lockheed Martin Corporation',
#  'General Dynamics Corporation',
#  'Deere & Company',
#  'Solectron Corp',
#  'Nordstrom',
#  'Comerica Inc.',
#  'National Engineering Industries Ltd',
#  'C. H. Robinson Worldwide Inc.',
#  'Quest Diagnostics Inc.',
#  'Energy East Corporation',
#  'KK Group',
#  'Marshall & Ilsley Corporation',
#  'Cadence Design Systems, Inc.',
#  'Beckman Coulter',
#  'The Goodyear Tire & Rubber Company',
#  'ADC Telecommunications, Inc.',
#  'IT Group Inc.',
#  'Myspace',
#  'General Motors Corporation',
#  'NielsenIQ',
#  'Applied Biosystems',
#  'Landskip Yard Service',
#  'Ameren',
#  'Honeywell International Inc.',
#  'CREMICA (MRS. BECTORS FOOD SPECIALITIES LTD)',
#  'Xcel Energy Inc',
#  'Realty Depot',
#  'WestPoint Stevens Inc',
#  'Marsh & McLennan',
#  'Zoo York',
#  'Air Products & Chemicals',
#  'Staff Leasing Inc.',
#  'Smurfit-Stone Container Corp',
#  'Data Bridge Market Research',
#  'Gannett Co., Inc.',
#  'Jones Soda Co.',
#  'Alexander & Baldwin',
#  'Sur La Table',
#  'Impetus',
#  'Ingersoll Rand',
#  'Stratabiz',
#  'FileMaker Inc., formerly Claris Corp.',
#  'facebook',
#  'Regis Corporation',
#  'The Lawn Guru',
#  'Dow Jones & Company',
#  'AOL Time Warner Inc.',
#  'Freedom Map',
#  'Tata Consulting Engineers Ltd.',
#  'Makebot',
#  'Uflex Limited',
#  'Collins & Aikman Corp.',
#  'Aramark',
#  'Public Service Enterprise Group Inc.',
#  'Just For Fun',
#  'MPS Group Inc.',
#  'CBRL Group Inc.',
#  'Monk Home Loans',
#  'BorgWarner Inc.',
#  'Federated Department Stores Inc.',
#  'Cogent Communications',
#  'Investors Clinic Infratech Private Limited',
#  'Belk, Inc.',
#  'Upgrad Education Pvt.Ltd',
#  'KPMG',
#  'Bharat Financial Inclusion Limited(BFIL)',
#  'US Cellular',
#  'Agilent Technologies',
#  'TurboHire',
#  'WNS Holdings',
#  'Granulesindia',
#  'CKE Restaurants Inc.',
#  'Practi-Plan Mapping',
#  'Hormel Foods Corp.',
#  'IDT Corporation',
#  'Jefferson-Pilot Co.',
#  'Zappos.com',
#  'Chem-Dry',
#  'Soyo Group',
#  'Dana Corporation',
#  'Cablevision Systems Corp',
#  "Dillard's Inc.",
#  'NTPC',
#  'Modern Architecture Design',
#  'Finpe (Fintech Banking & Financial Services a Skysoft Infotek India Pvt. Ltd.enterprise)',
#  'Di Giorgio Corporation',
#  'Crown Cork & Seal Co. Inc.',
#  'Body Fate',
#  'a21',
#  'Spartan Stores Inc',
#  'Trigon Healthcare Inc.',
#  'Dole Food Company, Inc.',
#  'LeapFrog Enterprises',
#  'National Commerce Financial Corporation',
#  'Directi',
#  'Brane Enterprises Pvt Ltd',
#  'Armstrong World Industries',
#  'American Airlines',
#  'Property Cloud',
#  'Limited Brands',
#  'Cole Haan',
#  'Mellon Financial Corporation',
#  'Broadcom',
#  'Pride International Inc',
#  'Johnson Controls Inc.',
#  'Phoenix Marketcity Resources Pvt. Ltd',
#  'Monk House Sales',
#  'SISA Information Security Pvt. Ltd',
#  'Kindred Healthcare Inc.',
#  'Micro Design',
#  'Costco',
#  'Whole Foods Market Inc',
#  'Home Depot',
#  'Garden Guru',
#  'Huntington Bancshares Inc.',
#  'Jackhammer Technologies',
#  'BJ Services Company',
#  'Lucas Oil',
#  'American Express',
#  'ANZ Support Services',
#  'Polaroid Corporation',
#  'Six Flags',
#  'United Parcel Service (UPS)',
#  'SBI Life Insurance Co. Ltd.',
#  'Olin Corp.',
#  'Allstate',
#  'Deloitte US India(Audit Services)',
#  'Venus Swimwear',
#  'Integrated Electrical Services Inc.',
#  'Alok Ingots',
#  'Kroger',
#  'Transocean',
#  'Plada Infotech',
#  'BFG Technologies',
#  'AES Corporation',
#  'Apache Corporation',
#  'General Communication',
#  'Atari',
#  'Bebo',
#  'Jarden',
#  'MTX Audio',
#  'Life Map',
#  'Mahindra Nevistar',
#  'Hella India',
#  'The Lubrizol Corporation',
#  'New York Times Company',
#  'DynCorp International',
#  'Costco Wholesale Corp.',
#  'Sears',
#  'Riverdeep',
#  'Elizabeth Arden',
#  'AirTran Holdings',
#  'International Business Machines Corp.',
#  'Pulte Homes Inc',
#  'THQ',
#  'CSA Advisor',
#  'Entertainment Network India Limited (ENIL),(Radio Mirchi)',
#  'Household International Corp.',
#  'Wm Wrigley Jr Company',
#  'Goodrich Corporation',
#  'Dream Home Improvements',
#  'Bennett Coleman and Co Ltd',
#  'DQE Inc.',
#  'KPMG Global Services',
#  "Schoep's Ice Cream",
#  'Visteon Corporation',
#  'AMERCO',
#  'Alladin Realty',
#  'Tempur-Pedic',
#  'ConsultBae',
#  'IIT Bombay',
#  'Middle Mile Pro',
#  'Casco Bay Lines',
#  'HCL Comnet',
#  'World Financial Group',
#  'STX',
#  'Target Corp.',
#  'Puget Energy Inc.',
#  'Southwest Airlines Co',
#  'Verizon Wireless',
#  'HealthPlix',
#  'NoPaperForms',
#  'FirmRoots Pvt Ltd',
#  'Kotak Mahindra Securities',
#  'Liberty Wealth Planners',
#  'iRobot',
#  'Walt Disney Co',
#  'Lexmark International Inc.',
#  'Ocean Spray',
#  'Cendant Corp',
#  'Profitpros',
#  'Russell Investment Group',
#  'Aspyr Media',
#  'Adaptaz',
#  'Asian Fusion',
#  'WESCO International Inc',
#  'Belle Ladi',
#  'Abbott Laboratories',
#  'Henry Schein Inc.',
#  'UnitedHealth Group Incorporated',
#  'Sierra Pacific Resources',
#  'Dream Home Real Estate Service',
#  'Net Elixir',
#  'On Semiconductor Corp',
#  'Convergys Corp.',
#  'Gillette Company',
#  'Finman Capital',
#  'PNM Resources Inc',
#  'Automatic Data Processing',
#  'Galaxy Man',
#  'Oxford Health Plans Inc',
#  'Total Serve',
#  "O'Reilly",
#  'Kenyt Techologies',
#  'Total Yard Management',
#  'Fruit of the Loom',
#  'Adaptec',
#  'BuyerForesight',
#  'Pioneer-Standard Electronics Inc.',
#  'Primedia Inc',
#  'Dereon',
#  'Frasca International',
#  'Hubbell Inc.',
#  'Intuit Inc.',
#  'Chubb Corp',
#  'Burlington Coat Factory',
#  'Viacom Inc',
#  'PayMe India',
#  'The Pink Pig Tavern',
#  'Valero Energy Corporation',
#  'John Hancock Financial Services Inc.',
#  'Omni Architectural Designs',
#  'SelectHub',
#  'Bharti Infratel',
#  'Eicher Motors Ltd.',
#  'Mars Incorporated',
#  'WIPRO Ltd',
#  'Enterprise GP Holdings',
#  'Amazon',
#  'Conseco',
#  'Royal Gas',
#  'Prestigabiz',
#  'FinEdge Advisory Pvt. Ltd.',
#  'ChevronTexaco Corp.',
#  'Decisive Markets Insights',
#  'PC Power and Cooling',
#  'US Airways',
#  'Thermo Electron Corporation',
#  'GreenPoint Financial Corp.',
#  'U.S. Robotics',
#  'Musco Lighting',
#  'GEMINI SOLUTIONS',
#  'Value Budget Housing Corporation',
#  'The Allstate Corporation',
#  'Vitagee',
#  'MTX Group Inc',
#  'Lennox International',
#  'Alaska Air Group',
#  'Gap',
#  'SunGard Data Systems Inc.',
#  'Lumencraft',
#  'Reliance Industries',
#  'Black Hills Corporation',
#  'Benori Knowledge Solutions',
#  'K 12 Techno Services',
#  'DirecTV',
#  'Solution Answers',
#  'Mikro Designs',
#  'Liberty Wealth Planner',
#  'Eastman Kodak',
#  'Merck & Co., Inc.',
#  'HAIER INDIA',
#  "Frost' n Sullivan",
#  'StatusNeo',
#  'Gold VIP Technology solution pvt ltd ( Crownit)',
#  'Unthinkable Software (A Unit of Daffodil Software)',
#  'Ryder System, Inc.',
#  'Audiovox Corporation',
#  "The Men's Wearhouse Inc.",
#  'Oreck Corporation',
#  'Gammon India',
#  'Nestle',
#  'Northeast Utilities System',
#  'Modern Realty',
#  'Belle Lady',
#  'Benesome',
#  'Mail-Well Inc.',
#  'Airgas, Inc.',
#  'Collabera',
#  'Affiliated Computer Services',
#  'Sony India',
#  'International Business Machines (IBM)',
#  'Savills',
#  'Cougar Investment',
#  'Pentair Inc',
#  'Siemens Information System Ltd',
#  'Charter Communications Inc.',
#  'K12 Techno Services Pvt Ltd',
#  'Prestiga-Biz',
#  'Timken India Ltd.',
#  'Phillips Van Heusen Corp.',
#  'Norfolk Southern Corporation',
#  'Golden Joy',
#  'St. Jude Medical Inc',
#  'Mondelez India Foods Private Limited (Formerly Cadbury India Ltd.)',
#  'Suzuki Powertrain Ltd.',
#  'Alleghany Corporation',
#  'Star Bright Investment Group',
#  'Gentiva Health Services Inc.',
#  'SanDisk',
#  'Allegheny Energy, Inc.',
#  'Sunoco Inc.',
#  'J.C. Penny Co.',
#  "Hardee's",
#  'Ashland Inc.',
#  'Cut Above',
#  'Four Leaf Clover',
#  'Toll Brothers Inc',
#  'Tesoro Petroleum Corp.',
#  'Atmos Energy Corporation',
#  'J.P. Morgan Chase & Co.',
#  'Southwest Airlines',
#  'Hettich',
#  'Anadarko Petroleum Corporation',
#  'Rainbow Life',
#  'E-zhe Source',
#  'BellSouth Corporation',
#  'B/E Aerospace',
#  'Kemet Corp.',
#  'IMS Group',
#  'Clear Channel Communications',
#  'GE Consumer & Industrial',
#  'Monk House Maker',
#  'DineEquity',
#  'AU Small Finance Bank',
#  'Health Net Inc.',
#  'Qwest',
#  'Quantum Corp',
#  'Fisher Scientific International Inc.',
#  'Brinker International',
#  'Learning Routes',
#  'Barnes & Noble, Inc.',
#  'Expeditors International of Washington Inc.',
#  'Prospa-Pal',
#  'The Coca-Cola Company',
#  'Hindustan  Unilever',
#  'CEIPAL Solutions Pvt. Ltd',
#  'Baxter International Inc.',
#  'Sonata Software',
#  'Omnicare Inc',
#  'PwC-SDC',
#  'Tata Elxsi',
#  'Ecolab Inc.',
#  'Way to go consultants',
#  'Yellow Corporation',
#  'Louisiana Pacific',
#  'Western Digital',
#  'Amdocs Development Centre',
#  'The Walt Disney Company',
#  'SEEDUP',
#  'Vigocare',
#  'Stetig Consulting Pvt Ltd',
#  'General Mills',
#  'South Indian Bank',
#  'Spherion Corp',
#  'The Polka Dot Bear Tavern',
#  'Georgia-Pacific Corporation',
#  'ArvinMeritor, Inc.',
#  'Hibernia Corp.',
#  'Zenoti',
#  'Pep Boys Manny, Moe & Jack',
#  'The Flying Bear',
#  'Castle Realty',
#  'Bajaj Housing Finance Ltd.',
#  'American Greetings',
#  'Cooper Industries Ltd.',
#  'Fisker Automotive',
#  'Pro Star Garden Management',
#  'Boston Scientific Corporation',
#  'Martin Marietta Materials',
#  'Capital IQ',
#  'Cognitrex Consultants Pvt. Ltd',
#  'Happy Bear Investment',
#  'Solutia Inc',
#  'Old Republic International Corp.',
#  'Ceasefire Industries Ltd.',
#  'Atmos Energy',
#  'GHD Inc.',
#  'DivX, Inc.',
#  'Sonic Solutions',
#  'Independent Investors',
#  'Cardinal Health Inc.',
#  'Transocean Inc',
#  'Globalpayex',
#  'Dole Foods',
#  'W. R. Berkley',
#  'ImaginXP',
#  'Illinois Tool Works Inc.',
#  'Deloitte Tax Services',
#  'Equifax Inc.',
#  'Polo Ralph Lauren Corp',
#  'AmerisourceBergen Corporation',
#  'H.B. Fuller Company',
#  'DURA Automotive Systems Inc.',
#  'Millenia Life',
#  'OneInsure (Robinhood Insurance)',
#  'Red Fox Tavern',
#  'Harman International Industries',
#  'BearingPoint',
#  'Baxter International',
#  'Dollar Tree',
#  'McCormick & Company',
#  'Garden Master',
#  'RBL Bank',
#  'Native',
#  'Acterna Corp.',
#  'Zune',
#  'Practi-Plan',
#  'Agriprocessors',
#  'Grass Roots Yard Services',
#  'Auto-Owners Insurance',
#  'Entergy',
#  'Robert Half International Inc.',
#  'Vizio',
#  'Teleperformance',
#  'Ecolab',
#  'Dreamscape Garden Care',
#  'DIMON Incorporated',
#  'System Star Solutions',
#  'CDI Corporation',
#  'Constellation Emergy Group Inc.',
#  'Tower Automotive Inc.',
#  'Flowers Foods Inc.',
#  'First Data Corp.',
#  'Ultimate Software',
#  'Kerr-McGee Corporation',
#  'Enrich Garden Services',
#  'Martha Stewart Living Omnimedia',
#  'WalkWater Talent Advisors Private Limited',
#  'Devon Energy',
#  'Datacorp',
#  'Integra Investment Service',
#  'ConvergenSEE',
#  'PPL Corp',
#  'Dean Foods Company',
#  'Total Quality',
#  'Integra Design',
#  'Mobisy Technologies Pvt. Ltd.',
#  'United Rentals Inc',
#  'Allergan, Inc.',
#  'News Corporation',
#  'SpotDraft',
#  'solutelabs',
#  'Star Interior Design',
#  'Nike',
#  'Healthsouth Corp',
#  'Bank of New York Mellon',
#  'Laboratory Corporation of America Holdings',
#  'ACT Manufacturing Inc.',
#  'PepsiCo Inc.',
#  'WWW Realty',
#  'Northrop Grumman',
#  'Indegene',
#  'Lawnscape Garden Maintenance',
#  'Avnet',
#  'Pall Corp',
#  'Prudential Financial Inc.',
#  'S3 Graphics',
#  'Evalueserve',
#  'Rich and Happy',
#  'Superior Appraisals',
#  'Champion Enterprises Inc.',
#  'Spandana Sphoorty Financial Services',
#  'Stilwell Financial Inc',
#  'World Airways',
#  'Delta Air Lines',
#  'El Paso Corporation',
#  'Spectrum Brands',
#  'Payless Shoesource Inc',
#  'Compuware Corp.',
#  'Ispat Industries Ltd.',
#  'UGI Corporation',
#  'Go Daddy',
#  'Owens & Minor Inc.',
#  'The Neiman Marcus Group Inc.',
#  'Netcordia',
#  'Raymond James Financial Inc.',
#  'Aumni Techworks',
#  'Parker Hannifin Corp.',
#  'Magna Wealth',
#  "Lowe's",
#  'Opticomp',
#  'The Bear Stearns Companies Inc.',
#  'Deloitte',
#  'Exact Realty',
#  'Libera',
#  'RGS Energy Group Inc',
#  'Penn Traffic Co.',
#  "Dippin' Dots",
#  'Iron Mountain',
#  'Ball Corp.',
#  'Control Data Corporation (CDC)',
#  'USG Corporation',
#  "Harrah's Entertainment Inc.",
#  'Banta Corporation',
#  'Amerada Hess Corporation',
#  'Lennar Corporation',
#  'Marathon Oil Corporation',
#  'Dun Rite Lawn Care',
#  'New World Realty',
#  'Zale Corporation',
#  'Manpower Inc.',
#  'Orion',
#  'Textron Inc',
#  'Ivax Corp.',
#  'Ummeed Housing Finance Ltd (Uhfl)',
#  'CA, Inc.',
#  'International Game Technology (IGT)',
#  'Netcore',
#  'Paramount Pictures',
#  'Hilton Hotels Corporation',
#  'Kenexa Corporation',
#  'Vassarlabs IT Solutions',
#  'BMC Software, Inc.',
#  'US Oncology Inc',
#  'ServiceMaster Co',
#  'Indiewealth',
#  'Plains All American Pipeline LP',
#  'H.J. Heinz Company',
#  'Amphenol Corporation',
#  'Express Scripts Inc.',
#  'Jaypee Rewa Cement Ltd.',
#  'USFreighways Corporation',
#  'Grey Fade',
#  'Kotak Mahindra Bank',
#  'SS&C Globeop financial services',
#  'Sapient',
#  'J. C. Penny',
#  'Kerr-McGee',
#  'Winn Dixie Stores Inc',
#  'Solution Realty',
#  'Emerson Electric Co.',
#  'Dale Carnegie (Walchand Group)',
#  'Aetna',
#  'Willamette Industries Inc.',
#  'SunTrust Banks Inc',
#  'The McGraw-Hill Companies Inc.',
#  'Hero FinCorp Ltd',
#  'Stewart Information Services Corp',
#  'Unitrin Inc',
#  'AutoZone',
#  'TJX Companies Inc',
#  'CREDFLOW',
#  'Aldrich Capital Partners',
#  'Invesco',
#  'Burlington Northern Santa Fe Corporation',
#  'Motorola Inc.',
#  'AFLAC Incorporated',
#  'VF Corporation',
#  'MyGate',
#  'Fresh&Easy Neighbourhood Market',
#  'ANS Commerce',
#  'Choices',
#  'WellPoint',
#  'FPL Group Inc.',
#  'Infinite Wealth',
#  'Berger Paints',
#  'Intuit',
#  'Scana Corp.',
#  'First Choice Garden Maintenance',
#  'American Financial Group',
#  'QVC',
#  'BlackRock Services',
#  'Screen Magic',
#  'House of Gas',
#  'Unified Western Grocers Inc',
#  'Burlington Resources Inc.',
#  'PRATHAM U/o IIFM Ltd',
#  'Bath & Body Works',
#  'Comcast',
#  'Atlas Architectural Designs',
#  'Affinity Investment Group',
#  'Reliance Securities',
#  'State Street Corp.',
#  'Tech Mahindra Ltd.',
#  'Weis Markets Inc.',
#  'Godrej Housing Finance',
#  'BlackRock',
#  'Budget Group, Inc.',
#  'Estee Lauder Companies Inc.',
#  'Crompton Corp.',
#  'Frontier Oil Corp',
#  'Peoples Energy Corp.',
#  'Pin Click',
#  'U.S. Steel',
#  'Pfizer Inc',
#  'Aspire System',
#  'Puravankara',
#  'Fit Tonic',
#  'Bucyrus International',
#  'Franklin Resources Inc.',
#  'Provident Financial Group',
#  'Zig Zag Children Clothes',
#  'Brightpoint, Inc.',
#  'Praxair Inc',
#  'Staples Inc',
#  'Puravankara Ltd',
#  'Avnet, Inc.',
#  'Payless ShoeSource',
#  'PWC SDC',
#  'Maruti Suzuki Ltd.',
#  'ZeroB (ION Exchange)',
#  'Knockout Kickboxing',
#  'Mazars',
#  'Unocal Corporation',
#  'Bharti Airtel Services',
#  'Butler America',
#  'Graybar Electric Company Inc.',
#  'Wynn Resorts',
#  'Saint-Gobain Glass',
#  'Manor Care Inc.',
#  'A.K. Capital Services Ltd.',
#  'Energizer Holdings Inc.',
#  'Pizza Hut',
#  'Allen Organ Company',
#  'E*Trade Group, Inc.',
#  'Paxton Media Group',
#  'Graviti Pharma',
#  'Scaler',
#  'CNA',
#  'Rockwell Collins Inc',
#  'Allmerica Financial Corporation',
#  'Quanta Services',
#  'Creative Wealth Management',
#  'Quintiles Transnational',
#  'Shirokiya',
#  'Level 3 Communications Inc.',
#  'Seksi Ladi',
#  'Micron Technology Operation India',
#  'National Service Industries Inc',
#  'Cintas Corp.',
#  'Afforda',
#  "Colt's Manufacturing Company",
#  'Growmark',
#  'Fidelity Investments',
#  'Finance Doctor Pvt Ltd',
#  'Anthem, Inc.',
#  'Awthentikz',
#  'Conseco Inc.',
#  'The White Rabbit',
#  'Navistar International Corporation',
#  'Beasts of Beauty',
#  'BSH Household Appliances Manufacturing',
#  'Genesis Health Ventures Inc.',
#  'Enquero Global',
#  'Marlabs',
#  'TCS BPS',
#  'Reliance Ajio',
#  'IDFC First Bank',
#  'Certybox',
#  'Digital Horizons',
#  'Lyondell Chemical Company',
#  'Pinkode',
#  "Pilgrim's Pride Corporation",
#  'PolyOne Corp',
#  'Gartner',
#  "Linens 'n Things Inc.",
#  'BNSF Railway',
#  'Bowater Incorporated',
#  'Garnet Interiors P Ltd',
#  'Ciena Corp.',
#  'Park Place Entertainment Corp',
#  'Bela Fasonado',
#  'MBNA Corporation',
#  'Trump Hotels & Casino Resorts Inc.',
#  'Borders Group',
#  'Pathmark Stores Inc.',
#  'Boeing',
#  'KPMC Tax Consultancy Pvt. Ltd',
#  'CAPLINE SERVICES PVT LTD.',
#  'Royal Caribbean International',
#  'Triton Communication',
#  'Red Bears Tavern',
#  'Reliance Jio',
#  'Liz Claiborne Inc.',
#  'Sauer-Danfoss',
#  'Swift Transportation, Co., Inc',
#  'Ames Department Stores, Inc.',
#  'Strategy Planner',
#  'Sanmina-SCI Inc',
#  'Analog Devices',
#  'MagnaSolution',
#  'Syntel',
#  'Country Delight',
#  'Meijer',
#  "Pilgrim's Pride",
#  'Cytec Industries Inc.',
#  'National City Corp.',
#  'Hinduja Housing Finance Limited',
#  'Paychex Inc',
#  'American Family Insurance',
#  'Ball Corporation',
#  'National Rural Utilities Cooperative Finance Corporation',
#  'J. P. Morgan Chase and Co.',
#  "Aaron's, Inc.",
#  'Fastenal',
#  'OPPO Mobile India Pvt. Ltd.',
#  'R.R. Donnelley & Sons Company',
#  'Science Applications Intl. Inc.',
#  'XL Dynamics India',
#  'Marriott Corporation',
#  'Sexy Babe',
#  'Xiaomi India',
#  'Asian Answers',
#  'Team Uno',
#  'DC Shoes',
#  'The Clorox Co.',
#  'TECO Energy Inc',
#  'Foster Wheeler Ltd.',
#  'Safeway Inc',
#  'Orange Mantra',
#  'Greenhandle',
#  'Chargepal',
#  'Banknorth Group, Inc.',
#  'Dow Chemical Company',
#  'ABM Industries Incorporated',
#  'Universal Sompo General Insurance',
#  'Brandscapes Worldwide',
#  'Global Market Insights Inc.',
#  'American Home Mortgage',
#  'No Paper Forms',
#  'New Era Tickets',
#  'Beckman Coulter, Inc.',
#  'Cognixia',
#  "Zaxby's",
#  'AFPRO',
#  'Universal Forest Products Inc',
#  'Albemarle Corporation',
#  'Lucasfilm',
#  'Del Monte Foods Co',
#  'Mariner Health Care Inc.',
#  'CVS Corp.',
#  'United Airlines',
#  'Maxaprofit',
#  'Acuserv',
#  'Altria Group (formerly Philip Morris Companies)',
#  'Altec Lansing',
#  'Suadela Investment',
#  'Compass Bancshares Inc',
#  'TechSci Research',
#  'Titania',
#  'Ganesh Premium Tea Pvt Ltd',
#  "Lawn N' Order Garden Care",
#  'Procter & Gamble',
#  ...]

# %%
company_patterns = create_training_data('Companies.json','COMPANY')

# %%
company_patterns
# Out:
# [{'label': 'COMPANY', 'pattern': 'Interpublic Group of Companies Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Southern California Edison'},
#  {'label': 'COMPANY', 'pattern': 'NRB Bearing'},
#  {'label': 'COMPANY', 'pattern': 'Kelly Services Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Kotak Life Insurance Co. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Bernhard Schulte Shipmanagement'},
#  {'label': 'COMPANY', 'pattern': 'Nagra Vision'},
#  {'label': 'COMPANY', 'pattern': 'Tesoro'},
#  {'label': 'COMPANY', 'pattern': 'Conectiv, Inc'},
#  {'label': 'COMPANY', 'pattern': 'Seagate Technology'},
#  {'label': 'COMPANY', 'pattern': 'Silicon Graphics'},
#  {'label': 'COMPANY', 'pattern': 'Arrow Electronics'},
#  {'label': 'COMPANY', 'pattern': 'Wachovia Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Accord Investments'},
#  {'label': 'COMPANY', 'pattern': 'DTE Energy Co.'},
#  {'label': 'COMPANY', 'pattern': 'Soma Enterprises'},
#  {'label': 'COMPANY', 'pattern': 'WWE'},
#  {'label': 'COMPANY', 'pattern': 'AdvancePCS, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Winnebago Industries'},
#  {'label': 'COMPANY', 'pattern': 'VIZ Media'},
#  {'label': 'COMPANY', 'pattern': 'Johnson & Johnson'},
#  {'label': 'COMPANY', 'pattern': 'Adobe Systems Inc.'},
#  {'label': 'COMPANY', 'pattern': 'DPL Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Rurash Financial'},
#  {'label': 'COMPANY', 'pattern': 'Northrop Grumman Corporation'},
#  {'label': 'COMPANY', 'pattern': 'United Parcel Service Inc'},
#  {'label': 'COMPANY', 'pattern': 'Star Merchant Services'},
#  {'label': 'COMPANY', 'pattern': 'Sun Pharma Industries Limited'},
#  {'label': 'COMPANY', 'pattern': 'Maytag Corporation'},
#  {'label': 'COMPANY', 'pattern': 'GeoSpoc Geospatial Services Pvt. Ltd'},
#  {'label': 'COMPANY', 'pattern': '20Cube'},
#  {'label': 'COMPANY', 'pattern': 'Reliance Communications'},
#  {'label': 'COMPANY', 'pattern': 'Sequoia Voting Systems'},
#  {'label': 'COMPANY', 'pattern': 'Imperial Sugar Company'},
#  {'label': 'COMPANY', 'pattern': 'StockViews'},
#  {'label': 'COMPANY', 'pattern': 'Nash Finch Company'},
#  {'label': 'COMPANY', 'pattern': 'Larsen & Toubro ECC Dvision'},
#  {'label': 'COMPANY', 'pattern': 'PepsiCo'},
#  {'label': 'COMPANY', 'pattern': 'Arrow Electronics, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Corsair Memory'},
#  {'label': 'COMPANY', 'pattern': 'Strength Gurus'},
#  {'label': 'COMPANY', 'pattern': 'AnnTaylor Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Lear Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Indus Valley Partners'},
#  {'label': 'COMPANY', 'pattern': 'Sherwin-Williams Company'},
#  {'label': 'COMPANY', 'pattern': 'TRW Inc'},
#  {'label': 'COMPANY', 'pattern': 'Apollo Group'},
#  {'label': 'COMPANY', 'pattern': 'Greyvoid'},
#  {'label': 'COMPANY', 'pattern': 'EbixCash Financial Technologies'},
#  {'label': 'COMPANY', 'pattern': 'Pacific Gas & Electric Company (PG&E)'},
#  {'label': 'COMPANY', 'pattern': 'Spherion'},
#  {'label': 'COMPANY', 'pattern': 'Kurzweil Educational Systems'},
#  {'label': 'COMPANY', 'pattern': 'OSI Restaurant Partners'},
#  {'label': 'COMPANY', 'pattern': 'Becton Dickinson'},
#  {'label': 'COMPANY', 'pattern': 'Mutual of Omaha'},
#  {'label': 'COMPANY', 'pattern': 'Campbell Soup Co.'},
#  {'label': 'COMPANY', 'pattern': 'Awfis Space Solutions Private Limited'},
#  {'label': 'COMPANY', 'pattern': 'Union Planters Corp'},
#  {'label': 'COMPANY', 'pattern': 'Magna Consulting'},
#  {'label': 'COMPANY', 'pattern': 'Planet Spark'},
#  {'label': 'COMPANY', 'pattern': 'BMC Software'},
#  {'label': 'COMPANY', 'pattern': 'Cerner Corporation'},
#  {'label': 'COMPANY', 'pattern': 'A+ Electronics'},
#  {'label': 'COMPANY', 'pattern': 'Ericsson India'},
#  {'label': 'COMPANY', 'pattern': 'Office Depot Inc.'},
#  {'label': 'COMPANY', 'pattern': 'AND1'},
#  {'label': 'COMPANY', 'pattern': 'Mahindra Logistics'},
#  {'label': 'COMPANY', 'pattern': 'Citigroup, Inc'},
#  {'label': 'COMPANY', 'pattern': 'Dover Corporation'},
#  {'label': 'COMPANY', 'pattern': 'ExxonMobil Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Client Associates'},
#  {'label': 'COMPANY', 'pattern': 'First Tennessee National Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Nucor Corp'},
#  {'label': 'COMPANY', 'pattern': 'The Jolly Farmer'},
#  {'label': 'COMPANY', 'pattern': 'AMETEK'},
#  {'label': 'COMPANY', 'pattern': 'Axxela Advisory'},
#  {'label': 'COMPANY', 'pattern': 'Medtronic Inc.'},
#  {'label': 'COMPANY', 'pattern': 'GenCorp Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Belk'},
#  {'label': 'COMPANY', 'pattern': 'National Semiconductor Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Pactiv Corp'},
#  {'label': 'COMPANY', 'pattern': 'Waste Management Inc'},
#  {'label': 'COMPANY', 'pattern': 'Shaw Group Inc'},
#  {'label': 'COMPANY', 'pattern': 'Reliable Garden Management'},
#  {'label': 'COMPANY', 'pattern': 'Enterasys Networks'},
#  {'label': 'COMPANY', 'pattern': 'Caparo Corporate Services'},
#  {'label': 'COMPANY', 'pattern': 'DST Systems'},
#  {'label': 'COMPANY', 'pattern': 'Smith International Inc'},
#  {'label': 'COMPANY', 'pattern': 'Telephone & Data Systems Inc'},
#  {'label': 'COMPANY', 'pattern': 'Adolph Coors Company'},
#  {'label': 'COMPANY', 'pattern': "Welch's"},
#  {'label': 'COMPANY', 'pattern': 'Stratapro'},
#  {'label': 'COMPANY', 'pattern': 'Bizoneer consulting'},
#  {'label': 'COMPANY', 'pattern': 'Ace Hardware Corporation'},
#  {'label': 'COMPANY', 'pattern': 'ARAMARK Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Interstate Batteries'},
#  {'label': 'COMPANY', 'pattern': 'Tejas Networks'},
#  {'label': 'COMPANY', 'pattern': 'Computer Associates International Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Novell'},
#  {'label': 'COMPANY', 'pattern': 'Airborne, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'BorgWarner'},
#  {'label': 'COMPANY', 'pattern': 'Regalix'},
#  {'label': 'COMPANY', 'pattern': 'CMGI Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Electronic Data Systems Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Formula Grey'},
#  {'label': 'COMPANY', 'pattern': 'Encompass Services Corporation'},
#  {'label': 'COMPANY', 'pattern': '6Wresearch'},
#  {'label': 'COMPANY', 'pattern': 'Belo Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Magellan Health Services Inc.'},
#  {'label': 'COMPANY', 'pattern': 'CSX Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Progress Energy Inc'},
#  {'label': 'COMPANY', 'pattern': 'The Happy Bear'},
#  {'label': 'COMPANY', 'pattern': 'ONEOK Inc'},
#  {'label': 'COMPANY', 'pattern': 'Landskip Yard Care'},
#  {'label': 'COMPANY', 'pattern': 'Sunoco'},
#  {'label': 'COMPANY', 'pattern': 'Realty Solution'},
#  {'label': 'COMPANY', 'pattern': 'Hub Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Owens-Illinois Inc'},
#  {'label': 'COMPANY', 'pattern': 'M.D.C. Holdings Inc.'},
#  {'label': 'COMPANY', 'pattern': 'ZF India'},
#  {'label': 'COMPANY', 'pattern': 'Genuity Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Nordstrom Inc'},
#  {'label': 'COMPANY', 'pattern': 'Arch Coal'},
#  {'label': 'COMPANY', 'pattern': 'Future Plan'},
#  {'label': 'COMPANY', 'pattern': 'uFaber Edutech Pvt Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Hike Education'},
#  {'label': 'COMPANY', 'pattern': 'Envirotecture Design'},
#  {'label': 'COMPANY', 'pattern': "BYJU'S"},
#  {'label': 'COMPANY', 'pattern': 'Coventry Health Care'},
#  {'label': 'COMPANY', 'pattern': 'NLL Academy (NLB Services)'},
#  {'label': 'COMPANY', 'pattern': 'National Fuel Gas Company'},
#  {'label': 'COMPANY', 'pattern': 'Network Air'},
#  {'label': 'COMPANY', 'pattern': 'Adams Resources & Energy, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Matrix Interior Design'},
#  {'label': 'COMPANY', 'pattern': 'Intel'},
#  {'label': 'COMPANY', 'pattern': 'Bharti AXA Life Insurance Company Limited'},
#  {'label': 'COMPANY', 'pattern': 'R. R. Donnelley & Sons'},
#  {'label': 'COMPANY', 'pattern': 'Universal Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Dex One'},
#  {'label': 'COMPANY', 'pattern': 'Thomas & Betts Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Medimix International'},
#  {'label': 'COMPANY', 'pattern': 'Dynegy Inc.'},
#  {'label': 'COMPANY', 'pattern': 'CMIE'},
#  {'label': 'COMPANY', 'pattern': 'L-3 Communications Holdings Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Computer Sciences Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Credence Analytics'},
#  {'label': 'COMPANY', 'pattern': 'Monit'},
#  {'label': 'COMPANY', 'pattern': 'Indian Airlines'},
#  {'label': 'COMPANY', 'pattern': 'First National of Nebraska Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Emcor Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Granite Construction Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'Shree Jain Roadways'},
#  {'label': 'COMPANY', 'pattern': 'Bethlehem Steel Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Axis Bank'},
#  {'label': 'COMPANY', 'pattern': 'Rockwell Collins'},
#  {'label': 'COMPANY', 'pattern': 'Halliburton Co.'},
#  {'label': 'COMPANY', 'pattern': 'Pinnacle West Capital Corp'},
#  {'label': 'COMPANY', 'pattern': 'Forest Laboratories Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Hyundai Motor India Limited (HMIL)'},
#  {'label': 'COMPANY', 'pattern': 'ACCO Brands'},
#  {'label': 'COMPANY', 'pattern': 'Quincy Newspapers'},
#  {'label': 'COMPANY', 'pattern': 'Sunkersett Financial Advisory'},
#  {'label': 'COMPANY', 'pattern': 'Polaris Industries'},
#  {'label': 'COMPANY', 'pattern': 'Yellow Brick Route'},
#  {'label': 'COMPANY', 'pattern': 'Morgan Stanley'},
#  {'label': 'COMPANY', 'pattern': 'Avon Products'},
#  {'label': 'COMPANY', 'pattern': 'ACC Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Best Biz Survis'},
#  {'label': 'COMPANY', 'pattern': 'Becton, Dickinson and Company'},
#  {'label': 'COMPANY', 'pattern': 'Idea Infinity'},
#  {'label': 'COMPANY', 'pattern': 'Teradyne Inc'},
#  {'label': 'COMPANY', 'pattern': 'U GRO CAPITAL'},
#  {'label': 'COMPANY', 'pattern': 'The MONY Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Fiserv Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Hughes Supply Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Personal & Corporate Design'},
#  {'label': 'COMPANY', 'pattern': 'Jones Apparel Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'NTT Data Business Solutions Ltd'},
#  {'label': 'COMPANY', 'pattern': 'NIPPON PAINT (INDIA) PRIVATE LIMITED'},
#  {'label': 'COMPANY', 'pattern': 'Publix'},
#  {'label': 'COMPANY', 'pattern': 'RPM Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Reebok International Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Brightpoint'},
#  {'label': 'COMPANY', 'pattern': 'Hovnanian Enterprises Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Tavant Technologies Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Verizon Communications Inc'},
#  {'label': 'COMPANY', 'pattern': 'Mattel Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Infiniti Research Marketing Solutions'},
#  {'label': 'COMPANY', 'pattern': 'IZealiant Technologies'},
#  {'label': 'COMPANY', 'pattern': 'Diebold Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'Star Assistance'},
#  {'label': 'COMPANY', 'pattern': 'Magik Gray'},
#  {'label': 'COMPANY', 'pattern': 'CH2M Hill Cos. Ltd.'},
#  {'label': 'COMPANY', 'pattern': "Papa John's Pizza"},
#  {'label': 'COMPANY', 'pattern': 'Humana Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Werner Enterprises'},
#  {'label': 'COMPANY', 'pattern': 'Cartoon Network Studios'},
#  {'label': 'COMPANY', 'pattern': 'Raytheon Company'},
#  {'label': 'COMPANY', 'pattern': 'Martin Marietta Materials Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Yoma Technologies'},
#  {'label': 'COMPANY', 'pattern': 'Midwest Communications'},
#  {'label': 'COMPANY', 'pattern': 'Hawaiian Airlines'},
#  {'label': 'COMPANY', 'pattern': 'L & T Technology Services'},
#  {'label': 'COMPANY', 'pattern': 'Terra Nova Garden Services'},
#  {'label': 'COMPANY', 'pattern': 'Activision Blizzard'},
#  {'label': 'COMPANY', 'pattern': 'ArvinMeritor'},
#  {'label': 'COMPANY', 'pattern': 'OfficeMax Inc'},
#  {'label': 'COMPANY', 'pattern': 'Benchmark Electronics'},
#  {'label': 'COMPANY', 'pattern': 'MAQ Software'},
#  {'label': 'COMPANY', 'pattern': 'Gemstar-TV Guide International Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Pro Star'},
#  {'label': 'COMPANY', 'pattern': 'Ferro Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Phelps Dodge Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Testor Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Reliance Broadcast Network'},
#  {'label': 'COMPANY', 'pattern': 'Omni Source'},
#  {'label': 'COMPANY', 'pattern': 'Circuit City Stores Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Teleflex Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'Simplex Infrastructures'},
#  {'label': 'COMPANY', 'pattern': 'NeerInfo Solutions'},
#  {'label': 'COMPANY', 'pattern': 'Introlligent Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Olan Mills, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Foamex International Inc'},
#  {'label': 'COMPANY', 'pattern': 'Marathon Oil'},
#  {'label': 'COMPANY', 'pattern': "Victoria's Secret"},
#  {'label': 'COMPANY', 'pattern': 'Indifi Technologies Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'ConAgra Foods Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Pickrr'},
#  {'label': 'COMPANY', 'pattern': 'Artivatic.ai'},
#  {'label': 'COMPANY', 'pattern': 'L&T Heavy Engineering'},
#  {'label': 'COMPANY', 'pattern': 'Idea Cellular'},
#  {'label': 'COMPANY', 'pattern': 'Family Dollar Stores Inc.'},
#  {'label': 'COMPANY', 'pattern': 'SAP Labs'},
#  {'label': 'COMPANY', 'pattern': 'RGF Executive Search India'},
#  {'label': 'COMPANY', 'pattern': 'Exide Industries'},
#  {'label': 'COMPANY', 'pattern': 'Briggs & Stratton'},
#  {'label': 'COMPANY', 'pattern': 'Levi Strauss & Co.'},
#  {'label': 'COMPANY', 'pattern': 'Extramarks Education India Pvt. Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Eli Lilly and Company'},
#  {'label': 'COMPANY', 'pattern': 'Viacom'},
#  {'label': 'COMPANY', 'pattern': 'Harley-Davidson'},
#  {'label': 'COMPANY', 'pattern': 'Equity Office Properties Trust'},
#  {'label': 'COMPANY', 'pattern': 'Qpass'},
#  {'label': 'COMPANY', 'pattern': 'Storage Technology Corporation'},
#  {'label': 'COMPANY', 'pattern': 'UST Inc'},
#  {'label': 'COMPANY', 'pattern': 'Naukri.com'},
#  {'label': 'COMPANY', 'pattern': 'Lockheed Martin Corporation'},
#  {'label': 'COMPANY', 'pattern': 'General Dynamics Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Deere & Company'},
#  {'label': 'COMPANY', 'pattern': 'Solectron Corp'},
#  {'label': 'COMPANY', 'pattern': 'Nordstrom'},
#  {'label': 'COMPANY', 'pattern': 'Comerica Inc.'},
#  {'label': 'COMPANY', 'pattern': 'National Engineering Industries Ltd'},
#  {'label': 'COMPANY', 'pattern': 'C. H. Robinson Worldwide Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Quest Diagnostics Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Energy East Corporation'},
#  {'label': 'COMPANY', 'pattern': 'KK Group'},
#  {'label': 'COMPANY', 'pattern': 'Marshall & Ilsley Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Cadence Design Systems, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Beckman Coulter'},
#  {'label': 'COMPANY', 'pattern': 'The Goodyear Tire & Rubber Company'},
#  {'label': 'COMPANY', 'pattern': 'ADC Telecommunications, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'IT Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Myspace'},
#  {'label': 'COMPANY', 'pattern': 'General Motors Corporation'},
#  {'label': 'COMPANY', 'pattern': 'NielsenIQ'},
#  {'label': 'COMPANY', 'pattern': 'Applied Biosystems'},
#  {'label': 'COMPANY', 'pattern': 'Landskip Yard Service'},
#  {'label': 'COMPANY', 'pattern': 'Ameren'},
#  {'label': 'COMPANY', 'pattern': 'Honeywell International Inc.'},
#  {'label': 'COMPANY',
#   'pattern': 'CREMICA (MRS. BECTORS FOOD SPECIALITIES LTD)'},
#  {'label': 'COMPANY', 'pattern': 'Xcel Energy Inc'},
#  {'label': 'COMPANY', 'pattern': 'Realty Depot'},
#  {'label': 'COMPANY', 'pattern': 'WestPoint Stevens Inc'},
#  {'label': 'COMPANY', 'pattern': 'Marsh & McLennan'},
#  {'label': 'COMPANY', 'pattern': 'Zoo York'},
#  {'label': 'COMPANY', 'pattern': 'Air Products & Chemicals'},
#  {'label': 'COMPANY', 'pattern': 'Staff Leasing Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Smurfit-Stone Container Corp'},
#  {'label': 'COMPANY', 'pattern': 'Data Bridge Market Research'},
#  {'label': 'COMPANY', 'pattern': 'Gannett Co., Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Jones Soda Co.'},
#  {'label': 'COMPANY', 'pattern': 'Alexander & Baldwin'},
#  {'label': 'COMPANY', 'pattern': 'Sur La Table'},
#  {'label': 'COMPANY', 'pattern': 'Impetus'},
#  {'label': 'COMPANY', 'pattern': 'Ingersoll Rand'},
#  {'label': 'COMPANY', 'pattern': 'Stratabiz'},
#  {'label': 'COMPANY', 'pattern': 'FileMaker Inc., formerly Claris Corp.'},
#  {'label': 'COMPANY', 'pattern': 'facebook'},
#  {'label': 'COMPANY', 'pattern': 'Regis Corporation'},
#  {'label': 'COMPANY', 'pattern': 'The Lawn Guru'},
#  {'label': 'COMPANY', 'pattern': 'Dow Jones & Company'},
#  {'label': 'COMPANY', 'pattern': 'AOL Time Warner Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Freedom Map'},
#  {'label': 'COMPANY', 'pattern': 'Tata Consulting Engineers Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Makebot'},
#  {'label': 'COMPANY', 'pattern': 'Uflex Limited'},
#  {'label': 'COMPANY', 'pattern': 'Collins & Aikman Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Aramark'},
#  {'label': 'COMPANY', 'pattern': 'Public Service Enterprise Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Just For Fun'},
#  {'label': 'COMPANY', 'pattern': 'MPS Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'CBRL Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Monk Home Loans'},
#  {'label': 'COMPANY', 'pattern': 'BorgWarner Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Federated Department Stores Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Cogent Communications'},
#  {'label': 'COMPANY', 'pattern': 'Investors Clinic Infratech Private Limited'},
#  {'label': 'COMPANY', 'pattern': 'Belk, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Upgrad Education Pvt.Ltd'},
#  {'label': 'COMPANY', 'pattern': 'KPMG'},
#  {'label': 'COMPANY', 'pattern': 'Bharat Financial Inclusion Limited(BFIL)'},
#  {'label': 'COMPANY', 'pattern': 'US Cellular'},
#  {'label': 'COMPANY', 'pattern': 'Agilent Technologies'},
#  {'label': 'COMPANY', 'pattern': 'TurboHire'},
#  {'label': 'COMPANY', 'pattern': 'WNS Holdings'},
#  {'label': 'COMPANY', 'pattern': 'Granulesindia'},
#  {'label': 'COMPANY', 'pattern': 'CKE Restaurants Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Practi-Plan Mapping'},
#  {'label': 'COMPANY', 'pattern': 'Hormel Foods Corp.'},
#  {'label': 'COMPANY', 'pattern': 'IDT Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Jefferson-Pilot Co.'},
#  {'label': 'COMPANY', 'pattern': 'Zappos.com'},
#  {'label': 'COMPANY', 'pattern': 'Chem-Dry'},
#  {'label': 'COMPANY', 'pattern': 'Soyo Group'},
#  {'label': 'COMPANY', 'pattern': 'Dana Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Cablevision Systems Corp'},
#  {'label': 'COMPANY', 'pattern': "Dillard's Inc."},
#  {'label': 'COMPANY', 'pattern': 'NTPC'},
#  {'label': 'COMPANY', 'pattern': 'Modern Architecture Design'},
#  {'label': 'COMPANY',
#   'pattern': 'Finpe (Fintech Banking & Financial Services a Skysoft Infotek India Pvt. Ltd.enterprise)'},
#  {'label': 'COMPANY', 'pattern': 'Di Giorgio Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Crown Cork & Seal Co. Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Body Fate'},
#  {'label': 'COMPANY', 'pattern': 'a21'},
#  {'label': 'COMPANY', 'pattern': 'Spartan Stores Inc'},
#  {'label': 'COMPANY', 'pattern': 'Trigon Healthcare Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Dole Food Company, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'LeapFrog Enterprises'},
#  {'label': 'COMPANY', 'pattern': 'National Commerce Financial Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Directi'},
#  {'label': 'COMPANY', 'pattern': 'Brane Enterprises Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Armstrong World Industries'},
#  {'label': 'COMPANY', 'pattern': 'American Airlines'},
#  {'label': 'COMPANY', 'pattern': 'Property Cloud'},
#  {'label': 'COMPANY', 'pattern': 'Limited Brands'},
#  {'label': 'COMPANY', 'pattern': 'Cole Haan'},
#  {'label': 'COMPANY', 'pattern': 'Mellon Financial Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Broadcom'},
#  {'label': 'COMPANY', 'pattern': 'Pride International Inc'},
#  {'label': 'COMPANY', 'pattern': 'Johnson Controls Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Phoenix Marketcity Resources Pvt. Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Monk House Sales'},
#  {'label': 'COMPANY', 'pattern': 'SISA Information Security Pvt. Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Kindred Healthcare Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Micro Design'},
#  {'label': 'COMPANY', 'pattern': 'Costco'},
#  {'label': 'COMPANY', 'pattern': 'Whole Foods Market Inc'},
#  {'label': 'COMPANY', 'pattern': 'Home Depot'},
#  {'label': 'COMPANY', 'pattern': 'Garden Guru'},
#  {'label': 'COMPANY', 'pattern': 'Huntington Bancshares Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Jackhammer Technologies'},
#  {'label': 'COMPANY', 'pattern': 'BJ Services Company'},
#  {'label': 'COMPANY', 'pattern': 'Lucas Oil'},
#  {'label': 'COMPANY', 'pattern': 'American Express'},
#  {'label': 'COMPANY', 'pattern': 'ANZ Support Services'},
#  {'label': 'COMPANY', 'pattern': 'Polaroid Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Six Flags'},
#  {'label': 'COMPANY', 'pattern': 'United Parcel Service (UPS)'},
#  {'label': 'COMPANY', 'pattern': 'SBI Life Insurance Co. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Olin Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Allstate'},
#  {'label': 'COMPANY', 'pattern': 'Deloitte US India(Audit Services)'},
#  {'label': 'COMPANY', 'pattern': 'Venus Swimwear'},
#  {'label': 'COMPANY', 'pattern': 'Integrated Electrical Services Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Alok Ingots'},
#  {'label': 'COMPANY', 'pattern': 'Kroger'},
#  {'label': 'COMPANY', 'pattern': 'Transocean'},
#  {'label': 'COMPANY', 'pattern': 'Plada Infotech'},
#  {'label': 'COMPANY', 'pattern': 'BFG Technologies'},
#  {'label': 'COMPANY', 'pattern': 'AES Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Apache Corporation'},
#  {'label': 'COMPANY', 'pattern': 'General Communication'},
#  {'label': 'COMPANY', 'pattern': 'Atari'},
#  {'label': 'COMPANY', 'pattern': 'Bebo'},
#  {'label': 'COMPANY', 'pattern': 'Jarden'},
#  {'label': 'COMPANY', 'pattern': 'MTX Audio'},
#  {'label': 'COMPANY', 'pattern': 'Life Map'},
#  {'label': 'COMPANY', 'pattern': 'Mahindra Nevistar'},
#  {'label': 'COMPANY', 'pattern': 'Hella India'},
#  {'label': 'COMPANY', 'pattern': 'The Lubrizol Corporation'},
#  {'label': 'COMPANY', 'pattern': 'New York Times Company'},
#  {'label': 'COMPANY', 'pattern': 'DynCorp International'},
#  {'label': 'COMPANY', 'pattern': 'Costco Wholesale Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Sears'},
#  {'label': 'COMPANY', 'pattern': 'Riverdeep'},
#  {'label': 'COMPANY', 'pattern': 'Elizabeth Arden'},
#  {'label': 'COMPANY', 'pattern': 'AirTran Holdings'},
#  {'label': 'COMPANY', 'pattern': 'International Business Machines Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Pulte Homes Inc'},
#  {'label': 'COMPANY', 'pattern': 'THQ'},
#  {'label': 'COMPANY', 'pattern': 'CSA Advisor'},
#  {'label': 'COMPANY',
#   'pattern': 'Entertainment Network India Limited (ENIL),(Radio Mirchi)'},
#  {'label': 'COMPANY', 'pattern': 'Household International Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Wm Wrigley Jr Company'},
#  {'label': 'COMPANY', 'pattern': 'Goodrich Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Dream Home Improvements'},
#  {'label': 'COMPANY', 'pattern': 'Bennett Coleman and Co Ltd'},
#  {'label': 'COMPANY', 'pattern': 'DQE Inc.'},
#  {'label': 'COMPANY', 'pattern': 'KPMG Global Services'},
#  {'label': 'COMPANY', 'pattern': "Schoep's Ice Cream"},
#  {'label': 'COMPANY', 'pattern': 'Visteon Corporation'},
#  {'label': 'COMPANY', 'pattern': 'AMERCO'},
#  {'label': 'COMPANY', 'pattern': 'Alladin Realty'},
#  {'label': 'COMPANY', 'pattern': 'Tempur-Pedic'},
#  {'label': 'COMPANY', 'pattern': 'ConsultBae'},
#  {'label': 'COMPANY', 'pattern': 'IIT Bombay'},
#  {'label': 'COMPANY', 'pattern': 'Middle Mile Pro'},
#  {'label': 'COMPANY', 'pattern': 'Casco Bay Lines'},
#  {'label': 'COMPANY', 'pattern': 'HCL Comnet'},
#  {'label': 'COMPANY', 'pattern': 'World Financial Group'},
#  {'label': 'COMPANY', 'pattern': 'STX'},
#  {'label': 'COMPANY', 'pattern': 'Target Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Puget Energy Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Southwest Airlines Co'},
#  {'label': 'COMPANY', 'pattern': 'Verizon Wireless'},
#  {'label': 'COMPANY', 'pattern': 'HealthPlix'},
#  {'label': 'COMPANY', 'pattern': 'NoPaperForms'},
#  {'label': 'COMPANY', 'pattern': 'FirmRoots Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Kotak Mahindra Securities'},
#  {'label': 'COMPANY', 'pattern': 'Liberty Wealth Planners'},
#  {'label': 'COMPANY', 'pattern': 'iRobot'},
#  {'label': 'COMPANY', 'pattern': 'Walt Disney Co'},
#  {'label': 'COMPANY', 'pattern': 'Lexmark International Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Ocean Spray'},
#  {'label': 'COMPANY', 'pattern': 'Cendant Corp'},
#  {'label': 'COMPANY', 'pattern': 'Profitpros'},
#  {'label': 'COMPANY', 'pattern': 'Russell Investment Group'},
#  {'label': 'COMPANY', 'pattern': 'Aspyr Media'},
#  {'label': 'COMPANY', 'pattern': 'Adaptaz'},
#  {'label': 'COMPANY', 'pattern': 'Asian Fusion'},
#  {'label': 'COMPANY', 'pattern': 'WESCO International Inc'},
#  {'label': 'COMPANY', 'pattern': 'Belle Ladi'},
#  {'label': 'COMPANY', 'pattern': 'Abbott Laboratories'},
#  {'label': 'COMPANY', 'pattern': 'Henry Schein Inc.'},
#  {'label': 'COMPANY', 'pattern': 'UnitedHealth Group Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'Sierra Pacific Resources'},
#  {'label': 'COMPANY', 'pattern': 'Dream Home Real Estate Service'},
#  {'label': 'COMPANY', 'pattern': 'Net Elixir'},
#  {'label': 'COMPANY', 'pattern': 'On Semiconductor Corp'},
#  {'label': 'COMPANY', 'pattern': 'Convergys Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Gillette Company'},
#  {'label': 'COMPANY', 'pattern': 'Finman Capital'},
#  {'label': 'COMPANY', 'pattern': 'PNM Resources Inc'},
#  {'label': 'COMPANY', 'pattern': 'Automatic Data Processing'},
#  {'label': 'COMPANY', 'pattern': 'Galaxy Man'},
#  {'label': 'COMPANY', 'pattern': 'Oxford Health Plans Inc'},
#  {'label': 'COMPANY', 'pattern': 'Total Serve'},
#  {'label': 'COMPANY', 'pattern': "O'Reilly"},
#  {'label': 'COMPANY', 'pattern': 'Kenyt Techologies'},
#  {'label': 'COMPANY', 'pattern': 'Total Yard Management'},
#  {'label': 'COMPANY', 'pattern': 'Fruit of the Loom'},
#  {'label': 'COMPANY', 'pattern': 'Adaptec'},
#  {'label': 'COMPANY', 'pattern': 'BuyerForesight'},
#  {'label': 'COMPANY', 'pattern': 'Pioneer-Standard Electronics Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Primedia Inc'},
#  {'label': 'COMPANY', 'pattern': 'Dereon'},
#  {'label': 'COMPANY', 'pattern': 'Frasca International'},
#  {'label': 'COMPANY', 'pattern': 'Hubbell Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Intuit Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Chubb Corp'},
#  {'label': 'COMPANY', 'pattern': 'Burlington Coat Factory'},
#  {'label': 'COMPANY', 'pattern': 'Viacom Inc'},
#  {'label': 'COMPANY', 'pattern': 'PayMe India'},
#  {'label': 'COMPANY', 'pattern': 'The Pink Pig Tavern'},
#  {'label': 'COMPANY', 'pattern': 'Valero Energy Corporation'},
#  {'label': 'COMPANY', 'pattern': 'John Hancock Financial Services Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Omni Architectural Designs'},
#  {'label': 'COMPANY', 'pattern': 'SelectHub'},
#  {'label': 'COMPANY', 'pattern': 'Bharti Infratel'},
#  {'label': 'COMPANY', 'pattern': 'Eicher Motors Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Mars Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'WIPRO Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Enterprise GP Holdings'},
#  {'label': 'COMPANY', 'pattern': 'Amazon'},
#  {'label': 'COMPANY', 'pattern': 'Conseco'},
#  {'label': 'COMPANY', 'pattern': 'Royal Gas'},
#  {'label': 'COMPANY', 'pattern': 'Prestigabiz'},
#  {'label': 'COMPANY', 'pattern': 'FinEdge Advisory Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'ChevronTexaco Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Decisive Markets Insights'},
#  {'label': 'COMPANY', 'pattern': 'PC Power and Cooling'},
#  {'label': 'COMPANY', 'pattern': 'US Airways'},
#  {'label': 'COMPANY', 'pattern': 'Thermo Electron Corporation'},
#  {'label': 'COMPANY', 'pattern': 'GreenPoint Financial Corp.'},
#  {'label': 'COMPANY', 'pattern': 'U.S. Robotics'},
#  {'label': 'COMPANY', 'pattern': 'Musco Lighting'},
#  {'label': 'COMPANY', 'pattern': 'GEMINI SOLUTIONS'},
#  {'label': 'COMPANY', 'pattern': 'Value Budget Housing Corporation'},
#  {'label': 'COMPANY', 'pattern': 'The Allstate Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Vitagee'},
#  {'label': 'COMPANY', 'pattern': 'MTX Group Inc'},
#  {'label': 'COMPANY', 'pattern': 'Lennox International'},
#  {'label': 'COMPANY', 'pattern': 'Alaska Air Group'},
#  {'label': 'COMPANY', 'pattern': 'Gap'},
#  {'label': 'COMPANY', 'pattern': 'SunGard Data Systems Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Lumencraft'},
#  {'label': 'COMPANY', 'pattern': 'Reliance Industries'},
#  {'label': 'COMPANY', 'pattern': 'Black Hills Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Benori Knowledge Solutions'},
#  {'label': 'COMPANY', 'pattern': 'K 12 Techno Services'},
#  {'label': 'COMPANY', 'pattern': 'DirecTV'},
#  {'label': 'COMPANY', 'pattern': 'Solution Answers'},
#  {'label': 'COMPANY', 'pattern': 'Mikro Designs'},
#  {'label': 'COMPANY', 'pattern': 'Liberty Wealth Planner'},
#  {'label': 'COMPANY', 'pattern': 'Eastman Kodak'},
#  {'label': 'COMPANY', 'pattern': 'Merck & Co., Inc.'},
#  {'label': 'COMPANY', 'pattern': 'HAIER INDIA'},
#  {'label': 'COMPANY', 'pattern': "Frost' n Sullivan"},
#  {'label': 'COMPANY', 'pattern': 'StatusNeo'},
#  {'label': 'COMPANY',
#   'pattern': 'Gold VIP Technology solution pvt ltd ( Crownit)'},
#  {'label': 'COMPANY',
#   'pattern': 'Unthinkable Software (A Unit of Daffodil Software)'},
#  {'label': 'COMPANY', 'pattern': 'Ryder System, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Audiovox Corporation'},
#  {'label': 'COMPANY', 'pattern': "The Men's Wearhouse Inc."},
#  {'label': 'COMPANY', 'pattern': 'Oreck Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Gammon India'},
#  {'label': 'COMPANY', 'pattern': 'Nestle'},
#  {'label': 'COMPANY', 'pattern': 'Northeast Utilities System'},
#  {'label': 'COMPANY', 'pattern': 'Modern Realty'},
#  {'label': 'COMPANY', 'pattern': 'Belle Lady'},
#  {'label': 'COMPANY', 'pattern': 'Benesome'},
#  {'label': 'COMPANY', 'pattern': 'Mail-Well Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Airgas, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Collabera'},
#  {'label': 'COMPANY', 'pattern': 'Affiliated Computer Services'},
#  {'label': 'COMPANY', 'pattern': 'Sony India'},
#  {'label': 'COMPANY', 'pattern': 'International Business Machines (IBM)'},
#  {'label': 'COMPANY', 'pattern': 'Savills'},
#  {'label': 'COMPANY', 'pattern': 'Cougar Investment'},
#  {'label': 'COMPANY', 'pattern': 'Pentair Inc'},
#  {'label': 'COMPANY', 'pattern': 'Siemens Information System Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Charter Communications Inc.'},
#  {'label': 'COMPANY', 'pattern': 'K12 Techno Services Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Prestiga-Biz'},
#  {'label': 'COMPANY', 'pattern': 'Timken India Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Phillips Van Heusen Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Norfolk Southern Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Golden Joy'},
#  {'label': 'COMPANY', 'pattern': 'St. Jude Medical Inc'},
#  {'label': 'COMPANY',
#   'pattern': 'Mondelez India Foods Private Limited (Formerly Cadbury India Ltd.)'},
#  {'label': 'COMPANY', 'pattern': 'Suzuki Powertrain Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Alleghany Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Star Bright Investment Group'},
#  {'label': 'COMPANY', 'pattern': 'Gentiva Health Services Inc.'},
#  {'label': 'COMPANY', 'pattern': 'SanDisk'},
#  {'label': 'COMPANY', 'pattern': 'Allegheny Energy, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Sunoco Inc.'},
#  {'label': 'COMPANY', 'pattern': 'J.C. Penny Co.'},
#  {'label': 'COMPANY', 'pattern': "Hardee's"},
#  {'label': 'COMPANY', 'pattern': 'Ashland Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Cut Above'},
#  {'label': 'COMPANY', 'pattern': 'Four Leaf Clover'},
#  {'label': 'COMPANY', 'pattern': 'Toll Brothers Inc'},
#  {'label': 'COMPANY', 'pattern': 'Tesoro Petroleum Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Atmos Energy Corporation'},
#  {'label': 'COMPANY', 'pattern': 'J.P. Morgan Chase & Co.'},
#  {'label': 'COMPANY', 'pattern': 'Southwest Airlines'},
#  {'label': 'COMPANY', 'pattern': 'Hettich'},
#  {'label': 'COMPANY', 'pattern': 'Anadarko Petroleum Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Rainbow Life'},
#  {'label': 'COMPANY', 'pattern': 'E-zhe Source'},
#  {'label': 'COMPANY', 'pattern': 'BellSouth Corporation'},
#  {'label': 'COMPANY', 'pattern': 'B/E Aerospace'},
#  {'label': 'COMPANY', 'pattern': 'Kemet Corp.'},
#  {'label': 'COMPANY', 'pattern': 'IMS Group'},
#  {'label': 'COMPANY', 'pattern': 'Clear Channel Communications'},
#  {'label': 'COMPANY', 'pattern': 'GE Consumer & Industrial'},
#  {'label': 'COMPANY', 'pattern': 'Monk House Maker'},
#  {'label': 'COMPANY', 'pattern': 'DineEquity'},
#  {'label': 'COMPANY', 'pattern': 'AU Small Finance Bank'},
#  {'label': 'COMPANY', 'pattern': 'Health Net Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Qwest'},
#  {'label': 'COMPANY', 'pattern': 'Quantum Corp'},
#  {'label': 'COMPANY', 'pattern': 'Fisher Scientific International Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Brinker International'},
#  {'label': 'COMPANY', 'pattern': 'Learning Routes'},
#  {'label': 'COMPANY', 'pattern': 'Barnes & Noble, Inc.'},
#  {'label': 'COMPANY',
#   'pattern': 'Expeditors International of Washington Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Prospa-Pal'},
#  {'label': 'COMPANY', 'pattern': 'The Coca-Cola Company'},
#  {'label': 'COMPANY', 'pattern': 'Hindustan  Unilever'},
#  {'label': 'COMPANY', 'pattern': 'CEIPAL Solutions Pvt. Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Baxter International Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Sonata Software'},
#  {'label': 'COMPANY', 'pattern': 'Omnicare Inc'},
#  {'label': 'COMPANY', 'pattern': 'PwC-SDC'},
#  {'label': 'COMPANY', 'pattern': 'Tata Elxsi'},
#  {'label': 'COMPANY', 'pattern': 'Ecolab Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Way to go consultants'},
#  {'label': 'COMPANY', 'pattern': 'Yellow Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Louisiana Pacific'},
#  {'label': 'COMPANY', 'pattern': 'Western Digital'},
#  {'label': 'COMPANY', 'pattern': 'Amdocs Development Centre'},
#  {'label': 'COMPANY', 'pattern': 'The Walt Disney Company'},
#  {'label': 'COMPANY', 'pattern': 'SEEDUP'},
#  {'label': 'COMPANY', 'pattern': 'Vigocare'},
#  {'label': 'COMPANY', 'pattern': 'Stetig Consulting Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'General Mills'},
#  {'label': 'COMPANY', 'pattern': 'South Indian Bank'},
#  {'label': 'COMPANY', 'pattern': 'Spherion Corp'},
#  {'label': 'COMPANY', 'pattern': 'The Polka Dot Bear Tavern'},
#  {'label': 'COMPANY', 'pattern': 'Georgia-Pacific Corporation'},
#  {'label': 'COMPANY', 'pattern': 'ArvinMeritor, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Hibernia Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Zenoti'},
#  {'label': 'COMPANY', 'pattern': 'Pep Boys Manny, Moe & Jack'},
#  {'label': 'COMPANY', 'pattern': 'The Flying Bear'},
#  {'label': 'COMPANY', 'pattern': 'Castle Realty'},
#  {'label': 'COMPANY', 'pattern': 'Bajaj Housing Finance Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'American Greetings'},
#  {'label': 'COMPANY', 'pattern': 'Cooper Industries Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Fisker Automotive'},
#  {'label': 'COMPANY', 'pattern': 'Pro Star Garden Management'},
#  {'label': 'COMPANY', 'pattern': 'Boston Scientific Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Martin Marietta Materials'},
#  {'label': 'COMPANY', 'pattern': 'Capital IQ'},
#  {'label': 'COMPANY', 'pattern': 'Cognitrex Consultants Pvt. Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Happy Bear Investment'},
#  {'label': 'COMPANY', 'pattern': 'Solutia Inc'},
#  {'label': 'COMPANY', 'pattern': 'Old Republic International Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Ceasefire Industries Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Atmos Energy'},
#  {'label': 'COMPANY', 'pattern': 'GHD Inc.'},
#  {'label': 'COMPANY', 'pattern': 'DivX, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Sonic Solutions'},
#  {'label': 'COMPANY', 'pattern': 'Independent Investors'},
#  {'label': 'COMPANY', 'pattern': 'Cardinal Health Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Transocean Inc'},
#  {'label': 'COMPANY', 'pattern': 'Globalpayex'},
#  {'label': 'COMPANY', 'pattern': 'Dole Foods'},
#  {'label': 'COMPANY', 'pattern': 'W. R. Berkley'},
#  {'label': 'COMPANY', 'pattern': 'ImaginXP'},
#  {'label': 'COMPANY', 'pattern': 'Illinois Tool Works Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Deloitte Tax Services'},
#  {'label': 'COMPANY', 'pattern': 'Equifax Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Polo Ralph Lauren Corp'},
#  {'label': 'COMPANY', 'pattern': 'AmerisourceBergen Corporation'},
#  {'label': 'COMPANY', 'pattern': 'H.B. Fuller Company'},
#  {'label': 'COMPANY', 'pattern': 'DURA Automotive Systems Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Millenia Life'},
#  {'label': 'COMPANY', 'pattern': 'OneInsure (Robinhood Insurance)'},
#  {'label': 'COMPANY', 'pattern': 'Red Fox Tavern'},
#  {'label': 'COMPANY', 'pattern': 'Harman International Industries'},
#  {'label': 'COMPANY', 'pattern': 'BearingPoint'},
#  {'label': 'COMPANY', 'pattern': 'Baxter International'},
#  {'label': 'COMPANY', 'pattern': 'Dollar Tree'},
#  {'label': 'COMPANY', 'pattern': 'McCormick & Company'},
#  {'label': 'COMPANY', 'pattern': 'Garden Master'},
#  {'label': 'COMPANY', 'pattern': 'RBL Bank'},
#  {'label': 'COMPANY', 'pattern': 'Native'},
#  {'label': 'COMPANY', 'pattern': 'Acterna Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Zune'},
#  {'label': 'COMPANY', 'pattern': 'Practi-Plan'},
#  {'label': 'COMPANY', 'pattern': 'Agriprocessors'},
#  {'label': 'COMPANY', 'pattern': 'Grass Roots Yard Services'},
#  {'label': 'COMPANY', 'pattern': 'Auto-Owners Insurance'},
#  {'label': 'COMPANY', 'pattern': 'Entergy'},
#  {'label': 'COMPANY', 'pattern': 'Robert Half International Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Vizio'},
#  {'label': 'COMPANY', 'pattern': 'Teleperformance'},
#  {'label': 'COMPANY', 'pattern': 'Ecolab'},
#  {'label': 'COMPANY', 'pattern': 'Dreamscape Garden Care'},
#  {'label': 'COMPANY', 'pattern': 'DIMON Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'System Star Solutions'},
#  {'label': 'COMPANY', 'pattern': 'CDI Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Constellation Emergy Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Tower Automotive Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Flowers Foods Inc.'},
#  {'label': 'COMPANY', 'pattern': 'First Data Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Ultimate Software'},
#  {'label': 'COMPANY', 'pattern': 'Kerr-McGee Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Enrich Garden Services'},
#  {'label': 'COMPANY', 'pattern': 'Martha Stewart Living Omnimedia'},
#  {'label': 'COMPANY', 'pattern': 'WalkWater Talent Advisors Private Limited'},
#  {'label': 'COMPANY', 'pattern': 'Devon Energy'},
#  {'label': 'COMPANY', 'pattern': 'Datacorp'},
#  {'label': 'COMPANY', 'pattern': 'Integra Investment Service'},
#  {'label': 'COMPANY', 'pattern': 'ConvergenSEE'},
#  {'label': 'COMPANY', 'pattern': 'PPL Corp'},
#  {'label': 'COMPANY', 'pattern': 'Dean Foods Company'},
#  {'label': 'COMPANY', 'pattern': 'Total Quality'},
#  {'label': 'COMPANY', 'pattern': 'Integra Design'},
#  {'label': 'COMPANY', 'pattern': 'Mobisy Technologies Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'United Rentals Inc'},
#  {'label': 'COMPANY', 'pattern': 'Allergan, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'News Corporation'},
#  {'label': 'COMPANY', 'pattern': 'SpotDraft'},
#  {'label': 'COMPANY', 'pattern': 'solutelabs'},
#  {'label': 'COMPANY', 'pattern': 'Star Interior Design'},
#  {'label': 'COMPANY', 'pattern': 'Nike'},
#  {'label': 'COMPANY', 'pattern': 'Healthsouth Corp'},
#  {'label': 'COMPANY', 'pattern': 'Bank of New York Mellon'},
#  {'label': 'COMPANY', 'pattern': 'Laboratory Corporation of America Holdings'},
#  {'label': 'COMPANY', 'pattern': 'ACT Manufacturing Inc.'},
#  {'label': 'COMPANY', 'pattern': 'PepsiCo Inc.'},
#  {'label': 'COMPANY', 'pattern': 'WWW Realty'},
#  {'label': 'COMPANY', 'pattern': 'Northrop Grumman'},
#  {'label': 'COMPANY', 'pattern': 'Indegene'},
#  {'label': 'COMPANY', 'pattern': 'Lawnscape Garden Maintenance'},
#  {'label': 'COMPANY', 'pattern': 'Avnet'},
#  {'label': 'COMPANY', 'pattern': 'Pall Corp'},
#  {'label': 'COMPANY', 'pattern': 'Prudential Financial Inc.'},
#  {'label': 'COMPANY', 'pattern': 'S3 Graphics'},
#  {'label': 'COMPANY', 'pattern': 'Evalueserve'},
#  {'label': 'COMPANY', 'pattern': 'Rich and Happy'},
#  {'label': 'COMPANY', 'pattern': 'Superior Appraisals'},
#  {'label': 'COMPANY', 'pattern': 'Champion Enterprises Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Spandana Sphoorty Financial Services'},
#  {'label': 'COMPANY', 'pattern': 'Stilwell Financial Inc'},
#  {'label': 'COMPANY', 'pattern': 'World Airways'},
#  {'label': 'COMPANY', 'pattern': 'Delta Air Lines'},
#  {'label': 'COMPANY', 'pattern': 'El Paso Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Spectrum Brands'},
#  {'label': 'COMPANY', 'pattern': 'Payless Shoesource Inc'},
#  {'label': 'COMPANY', 'pattern': 'Compuware Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Ispat Industries Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'UGI Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Go Daddy'},
#  {'label': 'COMPANY', 'pattern': 'Owens & Minor Inc.'},
#  {'label': 'COMPANY', 'pattern': 'The Neiman Marcus Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Netcordia'},
#  {'label': 'COMPANY', 'pattern': 'Raymond James Financial Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Aumni Techworks'},
#  {'label': 'COMPANY', 'pattern': 'Parker Hannifin Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Magna Wealth'},
#  {'label': 'COMPANY', 'pattern': "Lowe's"},
#  {'label': 'COMPANY', 'pattern': 'Opticomp'},
#  {'label': 'COMPANY', 'pattern': 'The Bear Stearns Companies Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Deloitte'},
#  {'label': 'COMPANY', 'pattern': 'Exact Realty'},
#  {'label': 'COMPANY', 'pattern': 'Libera'},
#  {'label': 'COMPANY', 'pattern': 'RGS Energy Group Inc'},
#  {'label': 'COMPANY', 'pattern': 'Penn Traffic Co.'},
#  {'label': 'COMPANY', 'pattern': "Dippin' Dots"},
#  {'label': 'COMPANY', 'pattern': 'Iron Mountain'},
#  {'label': 'COMPANY', 'pattern': 'Ball Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Control Data Corporation (CDC)'},
#  {'label': 'COMPANY', 'pattern': 'USG Corporation'},
#  {'label': 'COMPANY', 'pattern': "Harrah's Entertainment Inc."},
#  {'label': 'COMPANY', 'pattern': 'Banta Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Amerada Hess Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Lennar Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Marathon Oil Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Dun Rite Lawn Care'},
#  {'label': 'COMPANY', 'pattern': 'New World Realty'},
#  {'label': 'COMPANY', 'pattern': 'Zale Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Manpower Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Orion'},
#  {'label': 'COMPANY', 'pattern': 'Textron Inc'},
#  {'label': 'COMPANY', 'pattern': 'Ivax Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Ummeed Housing Finance Ltd (Uhfl)'},
#  {'label': 'COMPANY', 'pattern': 'CA, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'International Game Technology (IGT)'},
#  {'label': 'COMPANY', 'pattern': 'Netcore'},
#  {'label': 'COMPANY', 'pattern': 'Paramount Pictures'},
#  {'label': 'COMPANY', 'pattern': 'Hilton Hotels Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Kenexa Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Vassarlabs IT Solutions'},
#  {'label': 'COMPANY', 'pattern': 'BMC Software, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'US Oncology Inc'},
#  {'label': 'COMPANY', 'pattern': 'ServiceMaster Co'},
#  {'label': 'COMPANY', 'pattern': 'Indiewealth'},
#  {'label': 'COMPANY', 'pattern': 'Plains All American Pipeline LP'},
#  {'label': 'COMPANY', 'pattern': 'H.J. Heinz Company'},
#  {'label': 'COMPANY', 'pattern': 'Amphenol Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Express Scripts Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Jaypee Rewa Cement Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'USFreighways Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Grey Fade'},
#  {'label': 'COMPANY', 'pattern': 'Kotak Mahindra Bank'},
#  {'label': 'COMPANY', 'pattern': 'SS&C Globeop financial services'},
#  {'label': 'COMPANY', 'pattern': 'Sapient'},
#  {'label': 'COMPANY', 'pattern': 'J. C. Penny'},
#  {'label': 'COMPANY', 'pattern': 'Kerr-McGee'},
#  {'label': 'COMPANY', 'pattern': 'Winn Dixie Stores Inc'},
#  {'label': 'COMPANY', 'pattern': 'Solution Realty'},
#  {'label': 'COMPANY', 'pattern': 'Emerson Electric Co.'},
#  {'label': 'COMPANY', 'pattern': 'Dale Carnegie (Walchand Group)'},
#  {'label': 'COMPANY', 'pattern': 'Aetna'},
#  {'label': 'COMPANY', 'pattern': 'Willamette Industries Inc.'},
#  {'label': 'COMPANY', 'pattern': 'SunTrust Banks Inc'},
#  {'label': 'COMPANY', 'pattern': 'The McGraw-Hill Companies Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Hero FinCorp Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Stewart Information Services Corp'},
#  {'label': 'COMPANY', 'pattern': 'Unitrin Inc'},
#  {'label': 'COMPANY', 'pattern': 'AutoZone'},
#  {'label': 'COMPANY', 'pattern': 'TJX Companies Inc'},
#  {'label': 'COMPANY', 'pattern': 'CREDFLOW'},
#  {'label': 'COMPANY', 'pattern': 'Aldrich Capital Partners'},
#  {'label': 'COMPANY', 'pattern': 'Invesco'},
#  {'label': 'COMPANY', 'pattern': 'Burlington Northern Santa Fe Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Motorola Inc.'},
#  {'label': 'COMPANY', 'pattern': 'AFLAC Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'VF Corporation'},
#  {'label': 'COMPANY', 'pattern': 'MyGate'},
#  {'label': 'COMPANY', 'pattern': 'Fresh&Easy Neighbourhood Market'},
#  {'label': 'COMPANY', 'pattern': 'ANS Commerce'},
#  {'label': 'COMPANY', 'pattern': 'Choices'},
#  {'label': 'COMPANY', 'pattern': 'WellPoint'},
#  {'label': 'COMPANY', 'pattern': 'FPL Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Infinite Wealth'},
#  {'label': 'COMPANY', 'pattern': 'Berger Paints'},
#  {'label': 'COMPANY', 'pattern': 'Intuit'},
#  {'label': 'COMPANY', 'pattern': 'Scana Corp.'},
#  {'label': 'COMPANY', 'pattern': 'First Choice Garden Maintenance'},
#  {'label': 'COMPANY', 'pattern': 'American Financial Group'},
#  {'label': 'COMPANY', 'pattern': 'QVC'},
#  {'label': 'COMPANY', 'pattern': 'BlackRock Services'},
#  {'label': 'COMPANY', 'pattern': 'Screen Magic'},
#  {'label': 'COMPANY', 'pattern': 'House of Gas'},
#  {'label': 'COMPANY', 'pattern': 'Unified Western Grocers Inc'},
#  {'label': 'COMPANY', 'pattern': 'Burlington Resources Inc.'},
#  {'label': 'COMPANY', 'pattern': 'PRATHAM U/o IIFM Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Bath & Body Works'},
#  {'label': 'COMPANY', 'pattern': 'Comcast'},
#  {'label': 'COMPANY', 'pattern': 'Atlas Architectural Designs'},
#  {'label': 'COMPANY', 'pattern': 'Affinity Investment Group'},
#  {'label': 'COMPANY', 'pattern': 'Reliance Securities'},
#  {'label': 'COMPANY', 'pattern': 'State Street Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Tech Mahindra Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Weis Markets Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Godrej Housing Finance'},
#  {'label': 'COMPANY', 'pattern': 'BlackRock'},
#  {'label': 'COMPANY', 'pattern': 'Budget Group, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Estee Lauder Companies Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Crompton Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Frontier Oil Corp'},
#  {'label': 'COMPANY', 'pattern': 'Peoples Energy Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Pin Click'},
#  {'label': 'COMPANY', 'pattern': 'U.S. Steel'},
#  {'label': 'COMPANY', 'pattern': 'Pfizer Inc'},
#  {'label': 'COMPANY', 'pattern': 'Aspire System'},
#  {'label': 'COMPANY', 'pattern': 'Puravankara'},
#  {'label': 'COMPANY', 'pattern': 'Fit Tonic'},
#  {'label': 'COMPANY', 'pattern': 'Bucyrus International'},
#  {'label': 'COMPANY', 'pattern': 'Franklin Resources Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Provident Financial Group'},
#  {'label': 'COMPANY', 'pattern': 'Zig Zag Children Clothes'},
#  {'label': 'COMPANY', 'pattern': 'Brightpoint, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Praxair Inc'},
#  {'label': 'COMPANY', 'pattern': 'Staples Inc'},
#  {'label': 'COMPANY', 'pattern': 'Puravankara Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Avnet, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Payless ShoeSource'},
#  {'label': 'COMPANY', 'pattern': 'PWC SDC'},
#  {'label': 'COMPANY', 'pattern': 'Maruti Suzuki Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'ZeroB (ION Exchange)'},
#  {'label': 'COMPANY', 'pattern': 'Knockout Kickboxing'},
#  {'label': 'COMPANY', 'pattern': 'Mazars'},
#  {'label': 'COMPANY', 'pattern': 'Unocal Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Bharti Airtel Services'},
#  {'label': 'COMPANY', 'pattern': 'Butler America'},
#  {'label': 'COMPANY', 'pattern': 'Graybar Electric Company Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Wynn Resorts'},
#  {'label': 'COMPANY', 'pattern': 'Saint-Gobain Glass'},
#  {'label': 'COMPANY', 'pattern': 'Manor Care Inc.'},
#  {'label': 'COMPANY', 'pattern': 'A.K. Capital Services Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Energizer Holdings Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Pizza Hut'},
#  {'label': 'COMPANY', 'pattern': 'Allen Organ Company'},
#  {'label': 'COMPANY', 'pattern': 'E*Trade Group, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Paxton Media Group'},
#  {'label': 'COMPANY', 'pattern': 'Graviti Pharma'},
#  {'label': 'COMPANY', 'pattern': 'Scaler'},
#  {'label': 'COMPANY', 'pattern': 'CNA'},
#  {'label': 'COMPANY', 'pattern': 'Rockwell Collins Inc'},
#  {'label': 'COMPANY', 'pattern': 'Allmerica Financial Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Quanta Services'},
#  {'label': 'COMPANY', 'pattern': 'Creative Wealth Management'},
#  {'label': 'COMPANY', 'pattern': 'Quintiles Transnational'},
#  {'label': 'COMPANY', 'pattern': 'Shirokiya'},
#  {'label': 'COMPANY', 'pattern': 'Level 3 Communications Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Seksi Ladi'},
#  {'label': 'COMPANY', 'pattern': 'Micron Technology Operation India'},
#  {'label': 'COMPANY', 'pattern': 'National Service Industries Inc'},
#  {'label': 'COMPANY', 'pattern': 'Cintas Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Afforda'},
#  {'label': 'COMPANY', 'pattern': "Colt's Manufacturing Company"},
#  {'label': 'COMPANY', 'pattern': 'Growmark'},
#  {'label': 'COMPANY', 'pattern': 'Fidelity Investments'},
#  {'label': 'COMPANY', 'pattern': 'Finance Doctor Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Anthem, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Awthentikz'},
#  {'label': 'COMPANY', 'pattern': 'Conseco Inc.'},
#  {'label': 'COMPANY', 'pattern': 'The White Rabbit'},
#  {'label': 'COMPANY', 'pattern': 'Navistar International Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Beasts of Beauty'},
#  {'label': 'COMPANY', 'pattern': 'BSH Household Appliances Manufacturing'},
#  {'label': 'COMPANY', 'pattern': 'Genesis Health Ventures Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Enquero Global'},
#  {'label': 'COMPANY', 'pattern': 'Marlabs'},
#  {'label': 'COMPANY', 'pattern': 'TCS BPS'},
#  {'label': 'COMPANY', 'pattern': 'Reliance Ajio'},
#  {'label': 'COMPANY', 'pattern': 'IDFC First Bank'},
#  {'label': 'COMPANY', 'pattern': 'Certybox'},
#  {'label': 'COMPANY', 'pattern': 'Digital Horizons'},
#  {'label': 'COMPANY', 'pattern': 'Lyondell Chemical Company'},
#  {'label': 'COMPANY', 'pattern': 'Pinkode'},
#  {'label': 'COMPANY', 'pattern': "Pilgrim's Pride Corporation"},
#  {'label': 'COMPANY', 'pattern': 'PolyOne Corp'},
#  {'label': 'COMPANY', 'pattern': 'Gartner'},
#  {'label': 'COMPANY', 'pattern': "Linens 'n Things Inc."},
#  {'label': 'COMPANY', 'pattern': 'BNSF Railway'},
#  {'label': 'COMPANY', 'pattern': 'Bowater Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'Garnet Interiors P Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Ciena Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Park Place Entertainment Corp'},
#  {'label': 'COMPANY', 'pattern': 'Bela Fasonado'},
#  {'label': 'COMPANY', 'pattern': 'MBNA Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Trump Hotels & Casino Resorts Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Borders Group'},
#  {'label': 'COMPANY', 'pattern': 'Pathmark Stores Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Boeing'},
#  {'label': 'COMPANY', 'pattern': 'KPMC Tax Consultancy Pvt. Ltd'},
#  {'label': 'COMPANY', 'pattern': 'CAPLINE SERVICES PVT LTD.'},
#  {'label': 'COMPANY', 'pattern': 'Royal Caribbean International'},
#  {'label': 'COMPANY', 'pattern': 'Triton Communication'},
#  {'label': 'COMPANY', 'pattern': 'Red Bears Tavern'},
#  {'label': 'COMPANY', 'pattern': 'Reliance Jio'},
#  {'label': 'COMPANY', 'pattern': 'Liz Claiborne Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Sauer-Danfoss'},
#  {'label': 'COMPANY', 'pattern': 'Swift Transportation, Co., Inc'},
#  {'label': 'COMPANY', 'pattern': 'Ames Department Stores, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Strategy Planner'},
#  {'label': 'COMPANY', 'pattern': 'Sanmina-SCI Inc'},
#  {'label': 'COMPANY', 'pattern': 'Analog Devices'},
#  {'label': 'COMPANY', 'pattern': 'MagnaSolution'},
#  {'label': 'COMPANY', 'pattern': 'Syntel'},
#  {'label': 'COMPANY', 'pattern': 'Country Delight'},
#  {'label': 'COMPANY', 'pattern': 'Meijer'},
#  {'label': 'COMPANY', 'pattern': "Pilgrim's Pride"},
#  {'label': 'COMPANY', 'pattern': 'Cytec Industries Inc.'},
#  {'label': 'COMPANY', 'pattern': 'National City Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Hinduja Housing Finance Limited'},
#  {'label': 'COMPANY', 'pattern': 'Paychex Inc'},
#  {'label': 'COMPANY', 'pattern': 'American Family Insurance'},
#  {'label': 'COMPANY', 'pattern': 'Ball Corporation'},
#  {'label': 'COMPANY',
#   'pattern': 'National Rural Utilities Cooperative Finance Corporation'},
#  {'label': 'COMPANY', 'pattern': 'J. P. Morgan Chase and Co.'},
#  {'label': 'COMPANY', 'pattern': "Aaron's, Inc."},
#  {'label': 'COMPANY', 'pattern': 'Fastenal'},
#  {'label': 'COMPANY', 'pattern': 'OPPO Mobile India Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'R.R. Donnelley & Sons Company'},
#  {'label': 'COMPANY', 'pattern': 'Science Applications Intl. Inc.'},
#  {'label': 'COMPANY', 'pattern': 'XL Dynamics India'},
#  {'label': 'COMPANY', 'pattern': 'Marriott Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Sexy Babe'},
#  {'label': 'COMPANY', 'pattern': 'Xiaomi India'},
#  {'label': 'COMPANY', 'pattern': 'Asian Answers'},
#  {'label': 'COMPANY', 'pattern': 'Team Uno'},
#  {'label': 'COMPANY', 'pattern': 'DC Shoes'},
#  {'label': 'COMPANY', 'pattern': 'The Clorox Co.'},
#  {'label': 'COMPANY', 'pattern': 'TECO Energy Inc'},
#  {'label': 'COMPANY', 'pattern': 'Foster Wheeler Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Safeway Inc'},
#  {'label': 'COMPANY', 'pattern': 'Orange Mantra'},
#  {'label': 'COMPANY', 'pattern': 'Greenhandle'},
#  {'label': 'COMPANY', 'pattern': 'Chargepal'},
#  {'label': 'COMPANY', 'pattern': 'Banknorth Group, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Dow Chemical Company'},
#  {'label': 'COMPANY', 'pattern': 'ABM Industries Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'Universal Sompo General Insurance'},
#  {'label': 'COMPANY', 'pattern': 'Brandscapes Worldwide'},
#  {'label': 'COMPANY', 'pattern': 'Global Market Insights Inc.'},
#  {'label': 'COMPANY', 'pattern': 'American Home Mortgage'},
#  {'label': 'COMPANY', 'pattern': 'No Paper Forms'},
#  {'label': 'COMPANY', 'pattern': 'New Era Tickets'},
#  {'label': 'COMPANY', 'pattern': 'Beckman Coulter, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Cognixia'},
#  {'label': 'COMPANY', 'pattern': "Zaxby's"},
#  {'label': 'COMPANY', 'pattern': 'AFPRO'},
#  {'label': 'COMPANY', 'pattern': 'Universal Forest Products Inc'},
#  {'label': 'COMPANY', 'pattern': 'Albemarle Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Lucasfilm'},
#  {'label': 'COMPANY', 'pattern': 'Del Monte Foods Co'},
#  {'label': 'COMPANY', 'pattern': 'Mariner Health Care Inc.'},
#  {'label': 'COMPANY', 'pattern': 'CVS Corp.'},
#  {'label': 'COMPANY', 'pattern': 'United Airlines'},
#  {'label': 'COMPANY', 'pattern': 'Maxaprofit'},
#  {'label': 'COMPANY', 'pattern': 'Acuserv'},
#  {'label': 'COMPANY',
#   'pattern': 'Altria Group (formerly Philip Morris Companies)'},
#  {'label': 'COMPANY', 'pattern': 'Altec Lansing'},
#  {'label': 'COMPANY', 'pattern': 'Suadela Investment'},
#  {'label': 'COMPANY', 'pattern': 'Compass Bancshares Inc'},
#  {'label': 'COMPANY', 'pattern': 'TechSci Research'},
#  {'label': 'COMPANY', 'pattern': 'Titania'},
#  {'label': 'COMPANY', 'pattern': 'Ganesh Premium Tea Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': "Lawn N' Order Garden Care"},
#  {'label': 'COMPANY', 'pattern': 'Procter & Gamble'},
#  ...]

# %%
generate_rules(company_patterns, 'COMPANY')

# %%
company_rules = spacy.load('COMPANY_ner')

# %%
Training_Data_Company = generate_training_data(company_rules , data['Resume_str'])

# %%
# all_in_one('Company.json',data['Resume_str'],'COMPANY')

# %%
save_data("Training_Data_Company.json",Training_Data_Company)

# %% [markdown]
# ## #Training

# %%
TRAIN_DATA_Company = load_data("Training_Data_COMPANY.json")

# %%
nlp_company = train_spacy(TRAIN_DATA_Company , 50)
# Out:
# Starting iteration 1
# {'ner': 7403.826793408808}
# Time for iteration 1: 14.96875 sec
#
# Starting iteration 2
# {'ner': 136.94826408380936}
# Time for iteration 2: 13.40625 sec
#
# Starting iteration 3
# {'ner': 108.67391396989173}
# Time for iteration 3: 13.28125 sec
#
# Starting iteration 4
# {'ner': 108.36475825126031}
# Time for iteration 4: 14.328125 sec
#
# Starting iteration 5
# {'ner': 98.63942780365065}
# Time for iteration 5: 14.125 sec
#
# Starting iteration 6
# {'ner': 87.91711913030002}
# Time for iteration 6: 13.96875 sec
#
# Starting iteration 7
# {'ner': 60.76499486642481}
# Time for iteration 7: 13.03125 sec
#
# Starting iteration 8
# {'ner': 69.2269151490821}
# Time for iteration 8: 13.96875 sec
#
# Starting iteration 9
# {'ner': 34.24185930832607}
# Time for iteration 9: 13.078125 sec
#
# Starting iteration 10
# {'ner': 377.5546529713121}
# Time for iteration 10: 13.453125 sec
#
# Starting iteration 11
# {'ner': 52.785897381514204}
# Time for iteration 11: 13.515625 sec
#
# Starting iteration 12
# {'ner': 38.58656690532691}
# Time for iteration 12: 13.734375 sec
#
# Starting iteration 13
# {'ner': 111.78138026522}
# Time for iteration 13: 13.671875 sec
#
# Starting iteration 14
# {'ner': 39.255698090198926}
# Time for iteration 14: 13.265625 sec
#
# Starting iteration 15
# {'ner': 32.3197590809212}
# Time for iteration 15: 13.609375 sec
#
# Starting iteration 16
# {'ner': 430.2923332532088}
# Time for iteration 16: 13.265625 sec
#
# Starting iteration 17
# {'ner': 37.17001779595209}
# Time for iteration 17: 14.1875 sec
#
# Starting iteration 18
# {'ner': 27.45563964007166}
# Time for iteration 18: 14.1875 sec
#
# Starting iteration 19
# {'ner': 32.84020908728747}
# Time for iteration 19: 13.1875 sec
#
# Starting iteration 20
# {'ner': 166.81905985044833}
# Time for iteration 20: 13.375 sec
#
# Starting iteration 21
# {'ner': 16.567793609154908}
# Time for iteration 21: 13.609375 sec
#
# Starting iteration 22
# {'ner': 166.74108320939123}
# Time for iteration 22: 13.328125 sec
#
# Starting iteration 23
# {'ner': 20.406037261316673}
# Time for iteration 23: 13.625 sec
#
# Starting iteration 24
# {'ner': 12.007214873765925}
# Time for iteration 24: 13.84375 sec
#
# Starting iteration 25
# {'ner': 265.7673570266679}
# Time for iteration 25: 13.859375 sec
#
# Starting iteration 26
# {'ner': 21.279182395886505}
# Time for iteration 26: 13.234375 sec
#
# Starting iteration 27
# {'ner': 43.4112179325932}
# Time for iteration 27: 14.140625 sec
#
# Starting iteration 28
# {'ner': 40.74342306753078}
# Time for iteration 28: 13.78125 sec
#
# Starting iteration 29
# {'ner': 23.85983742748329}
# Time for iteration 29: 13.59375 sec
#
# Starting iteration 30
# {'ner': 24.418513364958866}
# Time for iteration 30: 14.34375 sec
#
# Starting iteration 31
# {'ner': 24.600449344035773}
# Time for iteration 31: 13.640625 sec
#
# Starting iteration 32
# {'ner': 19.85649208440267}
# Time for iteration 32: 13.5 sec
#
# Starting iteration 33
# {'ner': 23.007187978660422}
# Time for iteration 33: 13.15625 sec
#
# Starting iteration 34
# {'ner': 39.34213014449943}
# Time for iteration 34: 14.515625 sec
#
# Starting iteration 35
# {'ner': 17.41948756485467}
# Time for iteration 35: 13.546875 sec
#
# Starting iteration 36
# {'ner': 8.502326132363892}
# Time for iteration 36: 13.609375 sec
#
# Starting iteration 37
# {'ner': 25.598189868888547}
# Time for iteration 37: 13.078125 sec
#
# Starting iteration 38
# {'ner': 17.636454467061014}
# Time for iteration 38: 13.296875 sec
#
# Starting iteration 39
# {'ner': 9.11692812877399}
# Time for iteration 39: 13.28125 sec
#
# Starting iteration 40
# {'ner': 32.96933860843494}
# Time for iteration 40: 13.171875 sec
#
# Starting iteration 41
# {'ner': 23.595448940556842}
# Time for iteration 41: 13.953125 sec
#
# Starting iteration 42
# {'ner': 10.991769330487418}
# Time for iteration 42: 13.625 sec
#
# Starting iteration 43
# {'ner': 15.657281145861111}
# Time for iteration 43: 13.515625 sec
#
# Starting iteration 44
# {'ner': 18.37759651504098}
# Time for iteration 44: 13.625 sec
#
# Starting iteration 45
# {'ner': 12.363842257450548}
# Time for iteration 45: 13.75 sec
#
# Starting iteration 46
# {'ner': 170.6788517140727}
# Time for iteration 46: 13.890625 sec
#
# Starting iteration 47
# {'ner': 9.058472944652703}
# Time for iteration 47: 13.75 sec
#
# Starting iteration 48
# {'ner': 8.324820128361738}
# Time for iteration 48: 13.46875 sec
#
# Starting iteration 49
# {'ner': 60.965115012705255}
# Time for iteration 49: 13.578125 sec
#
# Starting iteration 50
# {'ner': 13.808073394230453}
# Time for iteration 50: 13.421875 sec
#
# Total Time 682.515625 sec

# %%
nlp_company.to_disk('Company_model')

# %% [markdown]
# ## #Testing

# %%
for text in df['Resume_str'].iloc[750:800]:

    for ent in nlp_company(text).ents:
         
        print(ent.text, ent.label_)
# Out:
# Infor COMPANY
# Infor COMPANY
# Total Quality COMPANY
# ... COMPANY
# Deloitte COMPANY
# Deloitte COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# FactSet COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Google COMPANY
# Google COMPANY
# Microsoft COMPANY
# Citrix COMPANY
# Twitter COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Best Buy COMPANY
# Amazon COMPANY
# Citrix COMPANY
# Citrix COMPANY
# Microsoft COMPANY
# Google COMPANY
# LinkedIn COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Gap COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Citrix COMPANY
# VLookup COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY

# %% [markdown]
# ## 2.Creating Job model

# %%
all_in_one('Jobs.json',data['Resume_str'],'JOBS')
# Out:
# copy the code to load the training data :
#  TRAIN_DATA_JOBS = load_data("Training_Data_JOBS.json")

# %% [markdown]
# ## #Training

# %%
TRAIN_DATA_JOB = load_data("Training_Data_JOBS.json")

# %%
nlp_job = train_spacy(TRAIN_DATA_JOB , 30)
# Out:
# Starting iteration 1
# {'ner': 4529.982361423046}
# Time for iteration 1: 20.90625 sec
#
# Starting iteration 2
# {'ner': 428.1034681043575}
# Time for iteration 2: 20.4375 sec
#
# Starting iteration 3
# {'ner': 298.4955564291333}
# Time for iteration 3: 19.6875 sec
#
# Starting iteration 4
# {'ner': 256.61046730290457}
# Time for iteration 4: 19.875 sec
#
# Starting iteration 5
# {'ner': 222.30583960599864}
# Time for iteration 5: 19.59375 sec
#
# Starting iteration 6
# {'ner': 156.60888734678366}
# Time for iteration 6: 20.0625 sec
#
# Starting iteration 7
# {'ner': 133.72382892135386}
# Time for iteration 7: 20.203125 sec
#
# Starting iteration 8
# {'ner': 182.1530448441432}
# Time for iteration 8: 19.59375 sec
#
# Starting iteration 9
# {'ner': 140.0385483820626}
# Time for iteration 9: 19.65625 sec
#
# Starting iteration 10
# {'ner': 127.99565015565321}
# Time for iteration 10: 20.0 sec
#
# Starting iteration 11
# {'ner': 89.9441712210246}
# Time for iteration 11: 19.5 sec
#
# Starting iteration 12
# {'ner': 81.72932763982838}
# Time for iteration 12: 20.09375 sec
#
# Starting iteration 13
# {'ner': 103.04921243700306}
# Time for iteration 13: 19.953125 sec
#
# Starting iteration 14
# {'ner': 135.8879492134018}
# Time for iteration 14: 19.4375 sec
#
# Starting iteration 15
# {'ner': 128.68973679768627}
# Time for iteration 15: 19.953125 sec
#
# Starting iteration 16
# {'ner': 105.29962307873396}
# Time for iteration 16: 20.078125 sec
#
# Starting iteration 17
# {'ner': 97.68559303298501}
# Time for iteration 17: 20.171875 sec
#
# Starting iteration 18
# {'ner': 102.36541873664719}
# Time for iteration 18: 21.109375 sec
#
# Starting iteration 19
# {'ner': 77.00331696898557}
# Time for iteration 19: 19.078125 sec
#
# Starting iteration 20
# {'ner': 78.72733920142834}
# Time for iteration 20: 20.453125 sec
#
# Starting iteration 21
# {'ner': 82.9831774074112}
# Time for iteration 21: 19.890625 sec
#
# Starting iteration 22
# {'ner': 65.96379197609583}
# Time for iteration 22: 20.15625 sec
#
# Starting iteration 23
# {'ner': 55.47405903911586}
# Time for iteration 23: 19.4375 sec
#
# Starting iteration 24
# {'ner': 82.6341120118056}
# Time for iteration 24: 20.625 sec
#
# Starting iteration 25
# {'ner': 79.85473834230828}
# Time for iteration 25: 20.046875 sec
#
# Starting iteration 26
# {'ner': 74.59118332338413}
# Time for iteration 26: 19.546875 sec
#
# Starting iteration 27
# {'ner': 55.553323813535926}
# Time for iteration 27: 19.28125 sec
#
# Starting iteration 28
# {'ner': 94.4277141410594}
# Time for iteration 28: 21.046875 sec
#
# Starting iteration 29
# {'ner': 60.04004468742555}
# Time for iteration 29: 20.15625 sec
#
# Starting iteration 30
# {'ner': 48.877244593498055}
# Time for iteration 30: 19.03125 sec
#
# Total Time 599.265625 sec

# %%
nlp_job.to_disk('Jobs_model')

# %% [markdown]
# ## #Testing

# %%
for text in df['Resume_str'].iloc[750:800]:

    for ent in nlp_job(text).ents:
         
        print(ent.text, ent.label_)
# Out:
# Manager JOBS
# Teller JOBS
# Agent JOBS
# Manager JOBS
# Manager JOBS
# Auditor JOBS
# Hostess JOBS
# Cashier JOBS
# Designer JOBS
# Manager JOBS
# Director JOBS
# Director JOBS
# Designer JOBS
# Designer JOBS
# Designer JOBS
# Graphic Designer JOBS
# Customer Service Representative JOBS
# Clerk JOBS
# Manager JOBS
# Professor JOBS
# Paralegal JOBS
# Manager JOBS
# Director JOBS
# Manager JOBS
# Manager JOBS
# Director JOBS
# Professor JOBS
# Manager JOBS
# Physician JOBS
# Director JOBS
# Director JOBS
# Manager JOBS
# Manager JOBS
# Manager JOBS
# Sales Manager JOBS
# Manager JOBS
# Manager JOBS
# Educational JOBS
# Manager JOBS
# Accountant JOBS
# Accountant JOBS
# Director JOBS
# Director JOBS
# Manager JOBS
# Accountant JOBS
# Accountant JOBS
# Director JOBS
# Compensation JOBS
# Adjuster JOBS
# Counselor JOBS
# Property JOBS
# Agent JOBS
# Counselor JOBS
# Physician JOBS
# Manager JOBS
# Specialist JOBS
# Director JOBS
# Director JOBS
# Director JOBS
# Manager JOBS
# Clinical JOBS
# Clinical JOBS
# Manager JOBS
# Director JOBS
# Director JOBS
# Construction Manager JOBS
# Engineer JOBS
# Director JOBS
# Doctor JOBS
# Manager JOBS
# Manager JOBS
# Manager JOBS
# Designer JOBS
# Designer JOBS
# Horticulturalist JOBS
# Manager JOBS
# Designer JOBS
# Designer JOBS
# Manager JOBS
# Technician JOBS
# Designer JOBS
# Manager JOBS
# Designer JOBS
# Designer JOBS
# Designer JOBS
# Customer Service Representative JOBS
# Manager JOBS
# Medical Assistant JOBS
# Clinical JOBS
# Teacher JOBS
# Medical Assistant JOBS
# Doctor JOBS
# Medical Assistant JOBS
# Clinical JOBS
# Medical Assistant JOBS
# Specialist JOBS
# Property JOBS
# Property JOBS
# Manager JOBS
# Manager JOBS
# Manager JOBS
# Director JOBS
# Secretary JOBS
# Manager JOBS
# Manager JOBS
# Baker JOBS
# Manager JOBS
# Manager JOBS
# Director JOBS
# Administrative Assistant JOBS
# Manager JOBS
# Manager JOBS
# Director JOBS
# Administrative Assistant JOBS
# Manager JOBS
# Director JOBS
# Cashier JOBS
# Specialist JOBS
# Specialist JOBS
# Specialist JOBS
# Administrative Assistant JOBS
# Instructor JOBS
# Technician JOBS
# Technician JOBS
# Manager JOBS
# Host JOBS
# Designer JOBS
# Equipment JOBS
# Designer JOBS
# Director JOBS
# Engineer JOBS
# Engineer JOBS
# Eurotech JOBS
# Specialist JOBS
# Director JOBS
# Engineer JOBS
# Manager JOBS
# Engineer JOBS
# Manager JOBS
# Engineer JOBS
# Director JOBS
# Engineer JOBS
# Engineer JOBS
# Director JOBS
# Sales Manager JOBS
# Sales Manager JOBS
# Director JOBS
# Educational JOBS
# Educational JOBS
# Educational JOBS
# Director JOBS
# Director JOBS
# Director JOBS
# Accountant JOBS
# Accountant JOBS
# Accountant JOBS
# Manager JOBS
# Equipment JOBS
# Auditor JOBS
# Manager JOBS
# Child JOBS
# Teller JOBS
# Teller JOBS
# Receptionist JOBS
# Manager JOBS
# Manager JOBS
# Chef JOBS
# Chef JOBS
# Chef JOBS
# Cook JOBS
# Chef JOBS
# Manager JOBS
# Specialist JOBS
# Instructor JOBS
# Fitness Trainer JOBS
# Manager JOBS
# Sales Manager JOBS
# Director JOBS
# Equipment JOBS
# Equipment JOBS
# Equipment JOBS
# Equipment JOBS
# Equipment JOBS
# Indicator JOBS
# Designer JOBS
# Designer JOBS
# Educational JOBS
# Director JOBS
# Manager JOBS
# Director JOBS
# Director JOBS
# Designer JOBS
# Educational JOBS
# Manager JOBS
# Teacher JOBS
# Educational JOBS
# Manager JOBS
# Teacher JOBS
# Director JOBS
# Accountant JOBS
# Accountant JOBS
# Educational JOBS
# Accountant JOBS
# Compensation JOBS
# Manager JOBS
# Mechanic JOBS
# Aircraft Technician JOBS
# Technician JOBS
# Financial Analyst JOBS
# Manager JOBS
# Director JOBS
# Compensation JOBS
# Compensation JOBS
# Manager JOBS
# Manager JOBS
# Manager JOBS
# Manager JOBS
# Engineer JOBS
# Engineer JOBS
# Designer JOBS
# Graphic Designer JOBS
# Editor JOBS
# Proofreader JOBS
# Specialist JOBS
# Producer JOBS
# Producer JOBS
# Producer JOBS
# Director JOBS
# Director JOBS
# Director JOBS
# Director JOBS
# Director JOBS
# Manager JOBS
# Editor JOBS
# Reporter JOBS
# Diplomacy JOBS

# %% [markdown]
# ## 3.Creating Education model

# %%
all_in_one('Education.json',data['Resume_str'],'EDUCATION')
# Out:
# copy the code to load the training data :
#  TRAIN_DATA_EDUCATION = load_data("Training_Data_EDUCATION.json")

# %% [markdown]
# ## #Training

# %%
TRAIN_DATA_EDUCATION = load_data("Training_Data_EDUCATION.json")

# %%
nlp_education = train_spacy(TRAIN_DATA_EDUCATION , 30)
# Out:
# Starting iteration 1
# {'ner': 5744.359347480603}
# Time for iteration 1: 9.25 sec
#
# Starting iteration 2
# {'ner': 251.76508041171246}
# Time for iteration 2: 8.84375 sec
#
# Starting iteration 3
# {'ner': 48.084731241128466}
# Time for iteration 3: 8.375 sec
#
# Starting iteration 4
# {'ner': 41.86431409665979}
# Time for iteration 4: 8.546875 sec
#
# Starting iteration 5
# {'ner': 20.446692312522597}
# Time for iteration 5: 8.515625 sec
#
# Starting iteration 6
# {'ner': 20.907547699762816}
# Time for iteration 6: 8.734375 sec
#
# Starting iteration 7
# {'ner': 22.954360278071373}
# Time for iteration 7: 8.375 sec
#
# Starting iteration 8
# {'ner': 18.880495986052413}
# Time for iteration 8: 8.5 sec
#
# Starting iteration 9
# {'ner': 12.155890301682021}
# Time for iteration 9: 7.953125 sec
#
# Starting iteration 10
# {'ner': 14.263146145917572}
# Time for iteration 10: 8.15625 sec
#
# Starting iteration 11
# {'ner': 11.728171947591989}
# Time for iteration 11: 8.265625 sec
#
# Starting iteration 12
# {'ner': 12.556757428908519}
# Time for iteration 12: 9.203125 sec
#
# Starting iteration 13
# {'ner': 6.638725921115684}
# Time for iteration 13: 8.609375 sec
#
# Starting iteration 14
# {'ner': 3.8389948544625443}
# Time for iteration 14: 8.46875 sec
#
# Starting iteration 15
# {'ner': 6.443179712269293}
# Time for iteration 15: 8.4375 sec
#
# Starting iteration 16
# {'ner': 2.0589730019869035}
# Time for iteration 16: 8.65625 sec
#
# Starting iteration 17
# {'ner': 5.434237758885352}
# Time for iteration 17: 8.90625 sec
#
# Starting iteration 18
# {'ner': 7.941769032911609}
# Time for iteration 18: 9.265625 sec
#
# Starting iteration 19
# {'ner': 2.6317644701587355}
# Time for iteration 19: 8.515625 sec
#
# Starting iteration 20
# {'ner': 2.5802026078520038e-05}
# Time for iteration 20: 9.109375 sec
#
# Starting iteration 21
# {'ner': 0.0003160562775512994}
# Time for iteration 21: 8.6875 sec
#
# Starting iteration 22
# {'ner': 1.755797519528695}
# Time for iteration 22: 9.0625 sec
#
# Starting iteration 23
# {'ner': 6.340608512561848}
# Time for iteration 23: 8.375 sec
#
# Starting iteration 24
# {'ner': 0.019584998850313402}
# Time for iteration 24: 9.46875 sec
#
# Starting iteration 25
# {'ner': 2.2881625334314637}
# Time for iteration 25: 9.15625 sec
#
# Starting iteration 26
# {'ner': 3.172109174726361}
# Time for iteration 26: 9.3125 sec
#
# Starting iteration 27
# {'ner': 5.996183205356219}
# Time for iteration 27: 9.109375 sec
#
# Starting iteration 28
# {'ner': 3.7416649604477805}
# Time for iteration 28: 8.40625 sec
#
# Starting iteration 29
# {'ner': 7.609118822519768}
# Time for iteration 29: 9.203125 sec
#
# Starting iteration 30
# {'ner': 3.916059651411903}
# Time for iteration 30: 8.546875 sec
#
# Total Time 262.203125 sec

# %%
nlp_education.to_disk('Education_model')

# %% [markdown]
# ## #Testing

# %%
for text in df['Resume_str'].iloc[750:800]:

    for ent in nlp_education(text).ents:
         
        print(ent.text, ent.label_)
# Out:
# Diploma EDUCATION
# Diploma EDUCATION
# Master of Science EDUCATION
# Master of Science EDUCATION
# Master's degree EDUCATION
# Diploma EDUCATION
# Diploma EDUCATION
# Bachelor of Professional EDUCATION
# Bachelor's degree EDUCATION
# Bachelor's degree EDUCATION
# Diploma EDUCATION
# Diploma EDUCATION
# Master of Science EDUCATION
# Diploma EDUCATION
# Bachelor of Dental EDUCATION
# Master of Science EDUCATION
# Master's Degree EDUCATION
# Master of Science EDUCATION
# Diploma EDUCATION
# Diploma EDUCATION
# Diploma EDUCATION
# Master of Science EDUCATION
# Bachelor  of EDUCATION
# Diploma EDUCATION
# Diploma EDUCATION
# Master of Technology EDUCATION
# Master of Chiropractic EDUCATION

# %% [markdown]
# ## 4.Creating Skill model

# %%
def load_jsonl(file):
    with open(file , 'r', encoding = 'utf-8') as f:
        data = [json.loads(line) for line in f]
    return data
skill_patterns = load_jsonl("jz_skill_patterns.jsonl")

# %%
generate_rules(skill_patterns, 'SKILL')

# %%
skill_rules = spacy.load('SKILL_ner')

# %%
Training_Data_Skill = generate_training_data(skill_rules , data['Resume_str'])

# %%
save_data("Training_Data_Skill.json",Training_Data_Skill)

# %% [markdown]
# ## #Training

# %%
TRAIN_DATA_SKILL = load_data("Training_Data_Skill.json")

# %%
nlp_skill = train_spacy(TRAIN_DATA_SKILL , 30)
# Out:
# Starting iteration 1
# {'ner': 6408.335494675233}
# Time for iteration 1: 21.46875 sec
#
# Starting iteration 2
# {'ner': 846.4045612367999}
# Time for iteration 2: 20.765625 sec
#
# Starting iteration 3
# {'ner': 540.6862681862888}
# Time for iteration 3: 20.046875 sec
#
# Starting iteration 4
# {'ner': 655.778152417762}
# Time for iteration 4: 21.21875 sec
#
# Starting iteration 5
# {'ner': 475.99520087548495}
# Time for iteration 5: 20.828125 sec
#
# Starting iteration 6
# {'ner': 564.2282106241917}
# Time for iteration 6: 21.546875 sec
#
# Starting iteration 7
# {'ner': 509.8512804234038}
# Time for iteration 7: 21.75 sec
#
# Starting iteration 8
# {'ner': 419.5681777034657}
# Time for iteration 8: 20.46875 sec
#
# Starting iteration 9
# {'ner': 324.69948997156706}
# Time for iteration 9: 21.21875 sec
#
# Starting iteration 10
# {'ner': 305.94626629902194}
# Time for iteration 10: 20.71875 sec
#
# Starting iteration 11
# {'ner': 338.48816361351834}
# Time for iteration 11: 21.578125 sec
#
# Starting iteration 12
# {'ner': 289.51283205946083}
# Time for iteration 12: 20.609375 sec
#
# Starting iteration 13
# {'ner': 308.0879350334808}
# Time for iteration 13: 20.59375 sec
#
# Starting iteration 14
# {'ner': 243.70108608640308}
# Time for iteration 14: 20.921875 sec
#
# Starting iteration 15
# {'ner': 230.53995069626436}
# Time for iteration 15: 20.46875 sec
#
# Starting iteration 16
# {'ner': 192.82138423919582}
# Time for iteration 16: 21.375 sec
#
# Starting iteration 17
# {'ner': 279.9627112029152}
# Time for iteration 17: 21.625 sec
#
# Starting iteration 18
# {'ner': 176.64505596882958}
# Time for iteration 18: 21.078125 sec
#
# Starting iteration 19
# {'ner': 265.6001528746832}
# Time for iteration 19: 20.65625 sec
#
# Starting iteration 20
# {'ner': 205.5547122120051}
# Time for iteration 20: 20.328125 sec
#
# Starting iteration 21
# {'ner': 223.11249077509362}
# Time for iteration 21: 20.671875 sec
#
# Starting iteration 22
# {'ner': 179.2677478161575}
# Time for iteration 22: 20.75 sec
#
# Starting iteration 23
# {'ner': 206.54881323462027}
# Time for iteration 23: 20.171875 sec
#
# Starting iteration 24
# {'ner': 150.26300785870583}
# Time for iteration 24: 21.34375 sec
#
# Starting iteration 25
# {'ner': 221.8917907758993}
# Time for iteration 25: 23.0 sec
#
# Starting iteration 26
# {'ner': 177.67597710622317}
# Time for iteration 26: 21.296875 sec
#
# Starting iteration 27
# {'ner': 122.03414830080251}
# Time for iteration 27: 20.546875 sec
#
# Starting iteration 28
# {'ner': 191.3303155653586}
# Time for iteration 28: 21.046875 sec
#
# Starting iteration 29
# {'ner': 158.95815837225817}
# Time for iteration 29: 21.0625 sec
#
# Starting iteration 30
# {'ner': 118.26316291886526}
# Time for iteration 30: 21.28125 sec
#
# Total Time 630.65625 sec

# %%
nlp_skill.to_disk('Skill_model')

# %% [markdown]
# ## #Testing

# %%
for text in df['Resume_str'].iloc[750:800]:

    for ent in nlp_skill(text).ents:
         
        print(ent.text, ent.label_)
# Out:
# engineering SKILL
# marketing SKILL
# C SKILL
# multimedia SKILL
# Engineering SKILL
# Business Administration SKILL
# Design SKILL
# Business Administration SKILL
# Business Administration SKILL
# finance SKILL
# finance SKILL
# Vault SKILL
# Software SKILL
# security SKILL
# vault SKILL
# payments SKILL
# Accounting SKILL
# finance SKILL
# marketing SKILL
# Operations management SKILL
# Documentation SKILL
# marketing SKILL
# Server SKILL
# server SKILL
# schedule SKILL
# DESIGN SKILL
# Design SKILL
# marketing SKILL
# Spring SKILL
# design SKILL
# Design SKILL
# marketing SKILL
# Project management SKILL
# Design SKILL
# Design SKILL
# spring SKILL
# support SKILL
# schedule SKILL
# material SKILL
# release SKILL
# design SKILL
# schedule SKILL
# schedule SKILL
# schedule SKILL
# support SKILL
# Certificate SKILL
# Certificate SKILL
# BUSINESS SKILL
# Business SKILL
# testing SKILL
# Business SKILL
# Project management SKILL
# Business process SKILL
# testing SKILL
# Business SKILL
# Project Management SKILL
# Business SKILL
# System Analysis SKILL
# business intelligence SKILL
# Oracle SKILL
# security SKILL
# Business SKILL
# database SKILL
# business SKILL
# business SKILL
# marketing SKILL
# Customer Relationship Management SKILL
# CRM SKILL
# business SKILL
# Oracle SKILL
# software SKILL
# business SKILL
# forums SKILL
# business SKILL
# business SKILL
# marketing SKILL
# business SKILL
# knowledge sharing SKILL
# Business SKILL
# business SKILL
# business SKILL
# finance SKILL
# accounting SKILL
# business SKILL
# marketing SKILL
# business SKILL
# Business SKILL
# business SKILL
# business SKILL
# marketing SKILL
# business SKILL
# C SKILL
# business SKILL
# business SKILL
# business SKILL
# marketing SKILL
# marketing SKILL
# Business SKILL
# Certificate SKILL
# Business SKILL
# Accounting SKILL
# Business Administration SKILL
# Business SKILL
# Business SKILL
# Business SKILL
# Business SKILL
# Customer Relationship Management SKILL
# Database SKILL
# Marketing SKILL
# Finance SKILL
# Marketing SKILL
# payments SKILL
# business SKILL
# business SKILL
# accounting SKILL
# accounting SKILL
# Business SKILL
# business SKILL
# accounting SKILL
# Business SKILL
# business SKILL
# marketing SKILL
# accounting SKILL
# Business SKILL
# Business SKILL
# Business SKILL
# Business SKILL
# business SKILL
# marketing SKILL
# OPERATIONS MANAGEMENT SKILL
# BUSINESS SKILL
# R SKILL
# payments SKILL
# schedule SKILL
# Operations Management SKILL
# Business Administration SKILL
# marketing SKILL
# accounting SKILL
# accounting SKILL
# Business Administration SKILL
# marketing SKILL
# Operations Management SKILL
# FINANCE SKILL
# monitoring SKILL
# finance SKILL
# Finance SKILL
# Oracle SKILL
# Business SKILL
# Finance SKILL
# business SKILL
# accounting SKILL
# finance SKILL
# Monitoring SKILL
# marketing SKILL
# sorting SKILL
# business SKILL
# advertising SKILL
# documentation SKILL
# Material SKILL
# Business SKILL
# finance SKILL
# accounting SKILL
# documentation SKILL
# accounting SKILL
# Oracle SKILL
# business SKILL
# Finance SKILL
# accounting SKILL
# Finance SKILL
# business SKILL
# payments SKILL
# schedule SKILL
# schedule SKILL
# payments SKILL
# payments SKILL
# Accounting SKILL
# accounting SKILL
# C SKILL
# Finance SKILL
# Finance SKILL
# Accounting SKILL
# advertising SKILL
# C SKILL
# finance SKILL
# documentation SKILL
# Finance SKILL
# accounting SKILL
# accounting SKILL
# marketing SKILL
# Oracle SKILL
# FINANCE SKILL
# accounting SKILL
# Oracle SKILL
# Finance SKILL
# Finance SKILL
# Finance SKILL
# Finance SKILL
# testing SKILL
# support SKILL
# Segment SKILL
# Business SKILL
# Accounting SKILL
# Support SKILL
# Accounting SKILL
# Oracle SKILL
# Project Management SKILL
# business administration SKILL
# Project Management SKILL
# Business SKILL
# Business SKILL
# workflow SKILL
# business SKILL
# security SKILL
# business SKILL
# documentation SKILL
# accounting SKILL
# business SKILL
# business SKILL
# workflow SKILL
# business SKILL
# business SKILL
# business SKILL
# business SKILL
# Project Management SKILL
# Project Management SKILL
# accounting SKILL
# Business SKILL
# business SKILL
# business SKILL
# documentation SKILL
# Project Management SKILL
# workflow SKILL
# C SKILL
# Project Management SKILL
# operations management SKILL
# design SKILL
# workflow SKILL
# design SKILL
# business SKILL
# Project Management SKILL
# project management SKILL
# business SKILL
# business SKILL
# business SKILL
# schedule SKILL
# design SKILL
# engineering SKILL
# business SKILL
# Civil Engineering SKILL
# Civil Engineering SKILL
# Finance SKILL
# Analytics SKILL
# Communications SKILL
# C SKILL
# design SKILL
# Finance SKILL
# Project Management SKILL
# testing SKILL
# support SKILL
# support SKILL
# support SKILL
# business SKILL
# documentation SKILL
# documentation SKILL
# database SKILL
# Business SKILL
# Business SKILL
# database SKILL
# documentation SKILL
# business SKILL
# design SKILL
# project management SKILL
# design SKILL
# interaction SKILL
# design SKILL
# design SKILL
# design SKILL
# documentation SKILL
# design SKILL
# testing SKILL
# design SKILL
# Design SKILL
# design SKILL
# engineering SKILL
# design SKILL
# design SKILL
# engineering SKILL
# schedule SKILL
# Design SKILL
# Design SKILL
# documentation SKILL
# design SKILL
# Business SKILL
# Security SKILL
# Project Management SKILL
# Data Center SKILL
# Operating Systems SKILL
# Windows SKILL
# Server SKILL
# Server SKILL
# Data Center SKILL
# Server SKILL
# API SKILL
# back office SKILL
# business SKILL
# support SKILL
# data center SKILL
# data center SKILL
# telecommunications SKILL
# support SKILL
# terminal SKILL
# support SKILL
# support SKILL
# support SKILL
# telecommunications SKILL
# software SKILL
# business SKILL
# design SKILL
# web security SKILL
# business SKILL
# Support SKILL
# software SKILL
# operating system SKILL
# email system SKILL
# server SKILL
# software SKILL
# Computer Science SKILL
# Computer Science SKILL
# API SKILL
# business SKILL
# Business SKILL
# support SKILL
# design SKILL
# Server SKILL
# Windows SKILL
# network hardware SKILL
# Operating Systems SKILL
# operating system SKILL
# Project Management SKILL
# telecommunications SKILL
# Design SKILL
# Design SKILL
# Certificate SKILL
# Design SKILL
# Certificate SKILL
# Spring SKILL
# Spring SKILL
# Spring SKILL
# MARKETING SKILL
# Marketing SKILL
# WordPress SKILL
# Google Analytics SKILL
# Adobe Photoshop SKILL
# Marketing SKILL
# marketing SKILL
# marketing SKILL
# payments SKILL
# Communications SKILL
# Communications SKILL
# Communications SKILL
# Communications SKILL
# Adobe Photoshop SKILL
# Google Analytics SKILL
# marketing SKILL
# Marketing SKILL
# Project management SKILL
# first mobile SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# collaboration SKILL
# business SKILL
# business SKILL
# marketing SKILL
# marketing SKILL
# Project management SKILL
# support SKILL
# operating systems SKILL
# software SKILL
# payments SKILL
# software SKILL
# software SKILL
# Support SKILL
# Data Center SKILL
# Support SKILL
# Business SKILL
# Communications SKILL
# Project Management SKILL
# Operating Systems SKILL
# Database SKILL
# Software Engineering SKILL
# Project Management SKILL
# Project Management SKILL
# accounting SKILL
# Business SKILL
# Communications SKILL
# business SKILL
# support SKILL
# Database SKILL
# Operating Systems SKILL
# Project Management SKILL
# Software Engineering SKILL
# SQL SKILL
# Support SKILL
# business SKILL
# support SKILL
# communications SKILL
# business SKILL
# SQL SKILL
# Database SKILL
# business SKILL
# INVISION SKILL
# accounting SKILL
# accounting SKILL
# database SKILL
# software SKILL
# business SKILL
# MARKETING AUTOMATION SKILL
# marketing SKILL
# business SKILL
# marketing SKILL
# business SKILL
# marketing SKILL
# Database SKILL
# collaboration SKILL
# Marketing Automation SKILL
# marketing SKILL
# marketing SKILL
# support SKILL
# marketing SKILL
# business SKILL
# marketing SKILL
# Oracle SKILL
# Twitter SKILL
# support SKILL
# business SKILL
# testing SKILL
# Design SKILL
# API SKILL
# documentation SKILL
# marketing SKILL
# segmentation SKILL
# testing SKILL
# marketing SKILL
# Marketing SKILL
# Marketing Automation SKILL
# Marketing SKILL
# design SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# Testing SKILL
# segmentation SKILL
# Support SKILL
# marketing SKILL
# analytics SKILL
# monitoring SKILL
# Database SKILL
# marketing SKILL
# Marketing SKILL
# Marketing SKILL
# communications SKILL
# project management SKILL
# Support SKILL
# accounting SKILL
# Marketing SKILL
# Marketing SKILL
# Oracle SKILL
# Marketing SKILL
# Oracle SKILL
# Marketing Automation SKILL
# Marketing SKILL
# Marketing SKILL
# ranking SKILL
# marketing SKILL
# system integration SKILL
# business process SKILL
# database SKILL
# Finance SKILL
# documentation SKILL
# documentation SKILL
# databases SKILL
# database SKILL
# documentation SKILL
# Support SKILL
# Schedule SKILL
# Help Desk SKILL
# Compose SKILL
# software SKILL
# relay SKILL
# Design SKILL
# marketing SKILL
# software SKILL
# software SKILL
# Business SKILL
# Business SKILL
# Accounting SKILL
# Accounting SKILL
# Support SKILL
# databases SKILL
# documentation SKILL
# Finance SKILL
# Help Desk SKILL
# marketing SKILL
# database SKILL
# communications SKILL
# marketing SKILL
# Project management SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# advertising SKILL
# marketing SKILL
# advertising SKILL
# database SKILL
# Project management SKILL
# database SKILL
# advertising SKILL
# business SKILL
# Business SKILL
# Business SKILL
# advertising SKILL
# project management SKILL
# marketing SKILL
# communications SKILL
# Software SKILL
# Publishing SKILL
# Software SKILL
# Accounting SKILL
# Schedule SKILL
# marketing SKILL
# communications SKILL
# accounting SKILL
# support SKILL
# LANGUAGES SKILL
# marketing SKILL
# marketing SKILL
# Mobile SKILL
# Mobile SKILL
# Documentation SKILL
# Mobile SKILL
# Mobile SKILL
# Mobile SKILL
# C SKILL
# Languages SKILL
# data management SKILL
# documentation SKILL
# support SKILL
# support SKILL
# database SKILL
# security SKILL
# communications SKILL
# design SKILL
# database SKILL
# support SKILL
# workload SKILL
# accounting SKILL
# data processing SKILL
# gums SKILL
# business SKILL
# accounting SKILL
# data processing SKILL
# database SKILL
# database SKILL
# operating system SKILL
# support SKILL
# Windows SKILL
# software SKILL
# computer network SKILL
# database SKILL
# Software SKILL
# database SKILL
# Windows SKILL
# BUSINESS SKILL
# BUSINESS SKILL
# Business SKILL
# Business SKILL
# business SKILL
# Business SKILL
# BUSINESS SKILL
# business SKILL
# marketing SKILL
# email marketing SKILL
# software SKILL
# business SKILL
# business SKILL
# marketing SKILL
# marketing SKILL
# design SKILL
# graphic design SKILL
# Business SKILL
# Marketing SKILL
# Advertising SKILL
# Advertising SKILL
# Business SKILL
# Marketing SKILL
# business SKILL
# Customer Relationship Management SKILL
# graphic design SKILL
# Marketing SKILL
# marketing SKILL
# Marketing SKILL
# Business SKILL
# INTERACTION SKILL
# design SKILL
# design SKILL
# design SKILL
# interaction SKILL
# Interaction SKILL
# Design SKILL
# engineering SKILL
# User interface SKILL
# design SKILL
# testing SKILL
# design SKILL
# Interaction SKILL
# design SKILL
# Design SKILL
# Software SKILL
# Software SKILL
# testing SKILL
# HTML SKILL
# 3D SKILL
# 3D SKILL
# SQL SKILL
# CDC/ SKILL
# design SKILL
# Project management SKILL
# Design SKILL
# Interaction SKILL
# Design SKILL
# Reality SKILL
# Interaction SKILL
# interaction SKILL
# software SKILL
# software SKILL
# testing SKILL
# interface analysis SKILL
# software SKILL
# Engineering SKILL
# Engineering SKILL
# reality SKILL
# software SKILL
# software SKILL
# support SKILL
# design SKILL
# design SKILL
# multimedia SKILL
# C SKILL
# testing SKILL
# testing SKILL
# business SKILL
# software SKILL
# Design SKILL
# marketing SKILL
# engineering SKILL
# engineering SKILL
# engineering SKILL
# design SKILL
# design SKILL
# workflow SKILL
# design SKILL
# testing SKILL
# software SKILL
# visualization SKILL
# software SKILL
# database SKILL
# security SKILL
# software SKILL
# design SKILL
# workflow SKILL
# software SKILL
# visualization SKILL
# design SKILL
# design SKILL
# workflow SKILL
# data analysis SKILL
# 3D SKILL
# visualization SKILL
# software SKILL
# design SKILL
# workflow SKILL
# 3D SKILL
# software SKILL
# design SKILL
# interaction SKILL
# user Interface SKILL
# design SKILL
# design SKILL
# database SKILL
# design SKILL
# data integrity SKILL
# software SKILL
# software SKILL
# Windows SKILL
# design SKILL
# design SKILL
# database SKILL
# testing SKILL
# marketing SKILL
# database SKILL
# 3D SKILL
# 3D SKILL
# 3D SKILL
# design SKILL
# Design SKILL
# 3D SKILL
# data integrity SKILL
# Software SKILL
# graphical user interface SKILL
# box SKILL
# design SKILL
# design SKILL
# engineering SKILL
# testing SKILL
# engineering SKILL
# marketing SKILL
# 3D SKILL
# 3D SKILL
# Engineering SKILL
# Engineering SKILL
# forums SKILL
# business SKILL
# business SKILL
# schedule SKILL
# Business SKILL
# ACCOUNTING SKILL
# BUSINESS SKILL
# ACCOUNTING SKILL
# ACCOUNTING SKILL
# BUSINESS SKILL
# Accounting SKILL
# Oracle SKILL
# Crystal SKILL
# R SKILL
# accounting SKILL
# accounting SKILL
# business SKILL
# accounting SKILL
# documentation SKILL
# Accounting SKILL
# accounting SKILL
# accounting SKILL
# accounting SKILL
# documentation SKILL
# Data Management SKILL
# accounting SKILL
# support SKILL
# accounting SKILL
# accounting SKILL
# Rotation SKILL
# accounting SKILL
# communications SKILL
# accounting SKILL
# business SKILL
# business SKILL
# Marathon SKILL
# Languages SKILL
# accounting SKILL
# Crystal SKILL
# Data Management SKILL
# documentation SKILL
# accounting SKILL
# Accounting SKILL
# Oracle SKILL
# Marathon SKILL
# Google SKILL
# Business SKILL
# Release SKILL
# publishing SKILL
# trend analysis SKILL
# unity SKILL
# Business SKILL
# business SKILL
# Payments SKILL
# Communications SKILL
# Business SKILL
# Business Administration SKILL
# Computer Science SKILL
# Computer Science SKILL
# Computer Science SKILL
# Documentation SKILL
# Data Processing SKILL
# Business Administration SKILL
# schedule SKILL
# Business Process SKILL
# payments SKILL
# collaboration SKILL
# support SKILL
# Support SKILL
# Task Management SKILL
# Certificate SKILL
# Business SKILL
# Marketing SKILL
# Business SKILL
# Finance SKILL
# marketing SKILL
# Certificate SKILL
# Support SKILL
# Business SKILL
# Business SKILL
# Finance SKILL
# Marketing SKILL
# Business SKILL
# Project Management SKILL
# Payments SKILL
# CHEF SKILL
# Chef SKILL
# Chef SKILL
# Chef SKILL
# Chef SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# business SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# business SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# business SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# business SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# business SKILL
# collaboration SKILL
# support SKILL
# marketing SKILL
# collaboration SKILL
# Marketing SKILL
# Marketing SKILL
# marketing SKILL
# support SKILL
# design SKILL
# testing SKILL
# mobile SKILL
# business SKILL
# business process SKILL
# Design SKILL
# Design SKILL
# business SKILL
# End Testing SKILL
# Documentation SKILL
# Material SKILL
# Software SKILL
# Business SKILL
# Testing SKILL
# Material SKILL
# Testing SKILL
# business SKILL
# Documentation SKILL
# Testing SKILL
# Testing SKILL
# Testing SKILL
# Testing SKILL
# Testing SKILL
# Security SKILL
# Testing SKILL
# Testing SKILL
# Testing SKILL
# Testing SKILL
# Interface Testing SKILL
# Testing SKILL
# Design SKILL
# Data Analysis SKILL
# Business SKILL
# Testing SKILL
# Documentation SKILL
# Design SKILL
# specification SKILL
# engineering SKILL
# Data analysis SKILL
# Interface Testing SKILL
# Testing SKILL
# business SKILL
# support SKILL
# Testing SKILL
# Business SKILL
# business process SKILL
# business SKILL
# Design SKILL
# Segment SKILL
# Design SKILL
# design SKILL
# schedule SKILL
# Mobile SKILL
# Specification SKILL
# business SKILL
# Material SKILL
# Material SKILL
# front end SKILL
# testing SKILL
# Support SKILL
# Testing SKILL
# Debugging SKILL
# Design SKILL
# data model SKILL
# business SKILL
# design SKILL
# Design SKILL
# Data Extraction SKILL
# Business SKILL
# Mobile SKILL
# End Testing SKILL
# Mobile SKILL
# Design SKILL
# Testing SKILL
# Business SKILL
# Business process SKILL
# End Testing SKILL
# Testing SKILL
# Business SKILL
# documentation SKILL
# testing SKILL
# business SKILL
# design SKILL
# Design SKILL
# testing SKILL
# box SKILL
# box SKILL
# testing SKILL
# business SKILL
# business SKILL
# Business process SKILL
# Data analysis SKILL
# Debugging SKILL
# documentation SKILL
# Design SKILL
# Specification SKILL
# design SKILL
# design SKILL
# material SKILL
# design SKILL
# Design SKILL
# advertising SKILL
# Certificate SKILL
# Design SKILL
# Certificate SKILL
# advertising SKILL
# business SKILL
# Business SKILL
# Project Management SKILL
# business SKILL
# project management SKILL
# documentation SKILL
# marketing SKILL
# marketing SKILL
# workflow SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# workflow SKILL
# interaction SKILL
# workflow SKILL
# workflow SKILL
# workflow SKILL
# business SKILL
# Finance SKILL
# Business SKILL
# Finance SKILL
# Business SKILL
# Business SKILL
# documentation SKILL
# marketing SKILL
# marketing SKILL
# Project Management SKILL
# workflow SKILL
# marketing SKILL
# Google Analytics SKILL
# business SKILL
# advertising SKILL
# marketing SKILL
# mobile SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# advertising SKILL
# advertising SKILL
# advertising SKILL
# Google Analytics SKILL
# Google Analytics SKILL
# advertising SKILL
# Google Analytics SKILL
# Google Analytics SKILL
# Google Analytics SKILL
# advertising SKILL
# Google Analytics SKILL
# marketing SKILL
# Google Analytics SKILL
# business SKILL
# business SKILL
# Marketing SKILL
# Google Analytics SKILL
# Google Analytics SKILL
# Google Analytics SKILL
# Marketing SKILL
# business SKILL
# marketing SKILL
# google analytics SKILL
# Marketing SKILL
# marketing SKILL
# spring SKILL
# Commerce SKILL
# Marketing SKILL
# Business SKILL
# Marketing SKILL
# Spring SKILL
# Spring SKILL
# advertising SKILL
# Google Analytics SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# advertising SKILL
# design SKILL
# Solid Modeling SKILL
# Design SKILL
# solid model SKILL
# component SKILL
# testing SKILL
# design SKILL
# simulation SKILL
# release SKILL
# design SKILL
# engineering SKILL
# design SKILL
# engineering SKILL
# engineering SKILL
# engineering SKILL
# Advertising SKILL
# Marketing SKILL
# Graphic Design SKILL
# Graphic Design SKILL
# Microcomputer SKILL
# Business SKILL
# Graphic Design SKILL
# Microcomputer SKILL
# Business SKILL
# databases SKILL
# debugging SKILL
# design SKILL
# publishing SKILL
# Design SKILL
# marketing SKILL
# FINANCE SKILL
# Accounting SKILL
# accounting SKILL
# accounting SKILL
# documentation SKILL
# Accounting SKILL
# accounting SKILL
# software SKILL
# Finance SKILL
# Certificate SKILL
# Accounting SKILL
# Languages SKILL
# Accounting SKILL
# Finance SKILL
# Windows SKILL
# documentation SKILL
# Project Management SKILL
# Business Administration SKILL
# Business Administration SKILL
# Certificate SKILL
# Security SKILL
# material SKILL
# security SKILL
# Certificate SKILL
# Languages SKILL
# Security SKILL
# Windows SKILL
# Windows SKILL
# Windows SKILL
# Security SKILL
# Project Management SKILL
# Documentation SKILL
# Storage Area Network SKILL
# FINANCE SKILL
# finance SKILL
# analytics SKILL
# project management SKILL
# payments SKILL
# Finance SKILL
# analytics SKILL
# SQL SKILL
# Oracle SKILL
# Business Intelligence SKILL
# Data analysis SKILL
# databases SKILL
# Finance SKILL
# Marketing SKILL
# business SKILL
# support SKILL
# testing SKILL
# Finance SKILL
# mobile SKILL
# payments SKILL
# Business Administration SKILL
# Finance SKILL
# Business Administration SKILL
# Finance SKILL
# Business Intelligence SKILL
# Data analysis SKILL
# databases SKILL
# Finance SKILL
# Marketing SKILL
# Oracle SKILL
# SQL SKILL
# library SKILL
# databases SKILL
# support SKILL
# documentation SKILL
# support SKILL
# support SKILL
# SOFTWARE ENGINEERING SKILL
# business SKILL
# Software SKILL
# Engineering SKILL
# Visual C++ SKILL
# Windows SKILL
# HTTP SKILL
# XML SKILL
# API SKILL
# API SKILL
# design SKILL
# documentation SKILL
# workflow SKILL
# business SKILL
# server SKILL
# ScrumMaster SKILL
# Server SKILL
# business SKILL
# Software SKILL
# C++ SKILL
# HTML5 SKILL
# JavaScript SKILL
# dash SKILL
# C SKILL
# framework SKILL
# testing SKILL
# API SKILL
# specification SKILL
# C++ SKILL
# API SKILL
# framework SKILL
# server SKILL
# API SKILL
# C++ SKILL
# C++ SKILL
# server SKILL
# Software SKILL
# Engineering SKILL
# server SKILL
# Software SKILL
# C++ SKILL
# business SKILL
# Software SKILL
# software SKILL
# C++ SKILL
# Windows SKILL
# Computer Science SKILL
# Computer Science SKILL
# Engineering SKILL
# Engineering SKILL
# API SKILL
# C++ SKILL
# documentation SKILL
# HTML5 SKILL
# XML SKILL
# JavaScript SKILL
# C SKILL
# Windows SKILL
# specification SKILL
# Visual C++ SKILL
# workflow SKILL
# business SKILL
# design SKILL
# business SKILL
# HTML SKILL
# CSS SKILL
# Business SKILL
# design SKILL
# collaboration SKILL
# Communications SKILL
# design SKILL
# graphic design SKILL
# support SKILL
# business SKILL
# business SKILL
# communications SKILL
# support SKILL
# Library SKILL
# library SKILL
# support SKILL
# business SKILL
# business SKILL
# finance SKILL
# documentation SKILL
# database SKILL
# business SKILL
# business SKILL
# marketing SKILL
# business SKILL
# business SKILL
# graphic design SKILL
# material SKILL
# Graphic Design SKILL
# Certificate SKILL
# Design SKILL
# Certificate SKILL
# business SKILL
# communications SKILL
# business SKILL
# CSS SKILL
# database SKILL
# documentation SKILL
# finance SKILL
# Graphic Design SKILL
# HTML SKILL
# marketing SKILL
# design SKILL
# BUSINESS SKILL
# business SKILL
# marketing SKILL
# business SKILL
# Marketing SKILL
# business SKILL
# Business SKILL
# business SKILL
# business SKILL
# business SKILL
# Business SKILL
# Business SKILL
# support SKILL
# Business SKILL
# business SKILL
# business SKILL
# Business SKILL
# Marketing SKILL
# CRM SKILL
# software SKILL
# Salespoint SKILL
# Marketing SKILL
# Business SKILL
# business SKILL

# %%
# Out:
# []

# %%
# Out:
# ['sentencizer']

# %%
# Out:
# {'summary': {'sentencizer': {'assigns': ['token.is_sent_start', 'doc.sents'],
#    'requires': [],
#    'scores': ['sents_f', 'sents_p', 'sents_r'],
#    'retokenizes': False}},
#  'problems': {'sentencizer': []},
#  'attrs': {'doc.sents': {'assigns': ['sentencizer'], 'requires': []},
#   'token.is_sent_start': {'assigns': ['sentencizer'], 'requires': []}}}
