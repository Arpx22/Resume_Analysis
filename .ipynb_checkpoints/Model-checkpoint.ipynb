# %%
import spacy
from spacy.lang.en import English
from spacy.pipeline import EntityRuler
from spacy.util import minibatch, compounding
from spacy.training.example import Example
from pathlib import Path
import json
import time
import random
#Data loading/ Data manipulation
import pandas as pd
import numpy as np
import jsonlines

# %%
df = pd.read_csv("Resume/Resume.csv")
df = df.reindex(np.random.permutation(df.index))
data = df.copy().iloc[0:500]
data.head()
# Out:
#             ID                                         Resume_str  \
# 343   13087952           TEACHER      Farrah M.    Bauman     ...
# 198   34051710           SR. GRAPHICS DESIGNER       Summary  ...
# 433   24240349           SUBSTITUTE TEACHER       Summary    A...
# 1604  13764840           BRAND MANAGER       Summary    Brand ...
# 441   37348041           ADVOCATE       Summary    Seeking a p...
#
#                                             Resume_html  Category
# 343   <div class="fontsize fontface vmargins hmargin...   TEACHER
# 198   <div class="fontsize fontface vmargins hmargin...  DESIGNER
# 433   <div class="fontsize fontface vmargins hmargin...   TEACHER
# 1604  <div class="fontsize fontface vmargins hmargin...   APPAREL
# 441   <div class="fontsize fontface vmargins hmargin...  ADVOCATE

# %%
def load_data(file):
    with open(file, 'r',encoding='utf-8') as f:
        data = json.load(f)
    return(data)

# %%
def save_data(file, data):
    with open(file , 'w' , encoding='utf-8') as f:
        json.dump(data , f , indent = 4)

# %%
def generate_more_data(file):
    data = load_data(file)
    new_char = []
    for item in data:
        new_char.append(item)
    final_characters = []
    for character in new_char:
        if "" != character:
            final_characters.append(character)
    final_char = list(set(final_characters))
    return final_char

# %%
def create_training_data(file, type):
    data = generate_more_data(file)
    patterns=[]
    for item in data:
        pattern = {
                    "label": type ,
                    "pattern" : item
                 }
        patterns.append(pattern)
    return patterns

# %%
def generate_rules(pattern, name):
    nlp = English()
    ruler = EntityRuler(nlp)
    
    ruler = nlp.add_pipe('entity_ruler')
    ruler.add_patterns(pattern)
    nlp.to_disk('{}_ner'.format(name))

# %%
def test_model(model,text):
    doc = model(text)
    results = []
    entities = []
    for ent in doc.ents:
        entities.append((ent.start_char,ent.end_char , ent.label_))
    if len(entities)>0:
        results = [text , {'entities':entities}]

    return results

# %%
def generate_training_data(model , data):
    Training_Data = []
    for d in data:
        segments =  d.split('\n\n')
        for seg in segments:
            seg = seg.strip()
            seg = seg.replace("\n"," ")
            results = test_model(model, seg)
            if results != None and results !=[] :
                Training_Data.append(results)
    return Training_Data

# %%
def train_spacy(data, iterations):
    start = time.process_time()
    TRAIN_DATA = data
    nlp = spacy.blank("en")
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        ner = nlp.add_pipe('ner',last = True)
    for _, annotations in TRAIN_DATA:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
    with nlp.disable_pipes(*other_pipes):
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            start2 = time.process_time()
            print ("Starting iteration " + str(itn+1))
            random.shuffle(TRAIN_DATA)
            losses = {}
            batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
            
            for batch in batches:
                for text, annotations in batch:
                    doc = nlp.make_doc(text)
                    example = Example.from_dict(doc, annotations)
                texts, annotations = zip(*batch)
                nlp.update(
                            [example],
                            drop=0.2,
                            sgd=optimizer,
                            losses=losses
                )
            print (losses)
            print("Time for iteration " + str(itn+1)+":",time.process_time() - start2, "sec\n")
    print("Total Time",time.process_time() - start, "sec")
    return (nlp)

# %%
def all_in_one(json_file , data , label ):
    patterns = create_training_data(json_file,label)
    generate_rules(patterns, label)
    rules = spacy.load('{}_ner'.format(label))
    Training_Data = generate_training_data(rules , data)
    save_data("Training_Data_{}.json".format(label),Training_Data)
    print('copy the code to load the training data :\n TRAIN_DATA_{} = load_data("Training_Data_{}.json") '.format(label,label))

# %% [markdown]
# ## 1.eating Company model

# %%
# characters = generate_more_data('Companies.json')

# %%
company_patterns = create_training_data('Companies.json','COMPANY')

# %%
company_patterns
# Out:
# [{'label': 'COMPANY', 'pattern': 'Kurzweil Educational Systems'},
#  {'label': 'COMPANY', 'pattern': 'Regalo Kitchens'},
#  {'label': 'COMPANY', 'pattern': 'Harley-Davidson Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Investors Clinic Infratech Private Limited'},
#  {'label': 'COMPANY', 'pattern': 'Williams Sonoma Inc'},
#  {'label': 'COMPANY', 'pattern': 'Kohler Company'},
#  {'label': 'COMPANY', 'pattern': 'AND1'},
#  {'label': 'COMPANY', 'pattern': 'Benchmark Electronics'},
#  {'label': 'COMPANY', 'pattern': 'J.P. Morgan Chase & Co.'},
#  {'label': 'COMPANY', 'pattern': 'Avant Garde Appraisal'},
#  {'label': 'COMPANY', 'pattern': 'Data Bridge Market Research'},
#  {'label': 'COMPANY', 'pattern': 'Stryker Corp'},
#  {'label': 'COMPANY', 'pattern': 'Consolidated Edison Inc.'},
#  {'label': 'COMPANY', 'pattern': 'First Data Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Ross Stores Inc'},
#  {'label': 'COMPANY', 'pattern': 'Duke Energy'},
#  {'label': 'COMPANY', 'pattern': 'Amkor Technology'},
#  {'label': 'COMPANY', 'pattern': 'Puravankara'},
#  {'label': 'COMPANY', 'pattern': 'KPMC Tax Consultancy Pvt. Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Independent Investors'},
#  {'label': 'COMPANY', 'pattern': 'Albertsons LLC'},
#  {'label': 'COMPANY', 'pattern': 'Mylan Lab'},
#  {'label': 'COMPANY', 'pattern': 'Flexus'},
#  {'label': 'COMPANY', 'pattern': 'Client Associates'},
#  {'label': 'COMPANY', 'pattern': 'Globalpayex'},
#  {'label': 'COMPANY', 'pattern': 'Atlas Architectural Designs'},
#  {'label': 'COMPANY', 'pattern': 'EMC Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Hallmark Cards'},
#  {'label': 'COMPANY', 'pattern': 'Eicher Motors Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Lexmark International Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Federated Department Stores Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Netobill'},
#  {'label': 'COMPANY', 'pattern': 'Polaroid Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Marriott International Inc.'},
#  {'label': 'COMPANY', 'pattern': 'CKE Restaurants'},
#  {'label': 'COMPANY', 'pattern': 'Hindustan  Unilever'},
#  {'label': 'COMPANY', 'pattern': 'Future Bright'},
#  {'label': 'COMPANY', 'pattern': 'FINFLUX'},
#  {'label': 'COMPANY', 'pattern': 'Bernhard Schulte Shipmanagement'},
#  {'label': 'COMPANY', 'pattern': 'Quest Technology Service'},
#  {'label': 'COMPANY', 'pattern': 'WNS Global Services (P) Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Apollo Global Management'},
#  {'label': 'COMPANY', 'pattern': "Wendy's/Arby's Group"},
#  {'label': 'COMPANY', 'pattern': 'Seaboard Corp'},
#  {'label': 'COMPANY', 'pattern': 'Frontier Oil Corp'},
#  {'label': 'COMPANY', 'pattern': 'K-Mart Corp.'},
#  {'label': 'COMPANY', 'pattern': 'JCPenney'},
#  {'label': 'COMPANY', 'pattern': 'Wealth Zone Group'},
#  {'label': 'COMPANY', 'pattern': 'Centrum Housing Finance Limited (CHFL)'},
#  {'label': 'COMPANY', 'pattern': 'Burger King Holdings'},
#  {'label': 'COMPANY', 'pattern': 'Motorola'},
#  {'label': 'COMPANY', 'pattern': 'NCR Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Arbitron'},
#  {'label': 'COMPANY', 'pattern': 'Informix'},
#  {'label': 'COMPANY', 'pattern': 'Premcor Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Energizer Holdings Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Tata Power'},
#  {'label': 'COMPANY', 'pattern': 'Sabre Holdings Corp'},
#  {'label': 'COMPANY', 'pattern': 'SalesForce'},
#  {'label': 'COMPANY', 'pattern': 'Smithfield Foods Inc'},
#  {'label': 'COMPANY', 'pattern': "Harrah's Entertainment Inc."},
#  {'label': 'COMPANY', 'pattern': 'Torfac India Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Kroger Co.'},
#  {'label': 'COMPANY', 'pattern': 'Equifax Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Total Yard Management'},
#  {'label': 'COMPANY', 'pattern': 'Directi'},
#  {'label': 'COMPANY', 'pattern': 'Amazon.com, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Choices'},
#  {'label': 'COMPANY', 'pattern': 'Modern Architecture Design'},
#  {'label': 'COMPANY', 'pattern': 'MGIC Investment Corporation'},
#  {'label': 'COMPANY', 'pattern': 'ConsultBae'},
#  {'label': 'COMPANY', 'pattern': 'GFB Great Food Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Titania'},
#  {'label': 'COMPANY', 'pattern': 'Cox Communications Inc.'},
#  {'label': 'COMPANY', 'pattern': 'UnitedHealth Group Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'Macroserve'},
#  {'label': 'COMPANY', 'pattern': 'Google'},
#  {'label': 'COMPANY', 'pattern': 'Ghost Concepts Software Services Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Interstate Bakeries Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Aricent Technologies'},
#  {'label': 'COMPANY', 'pattern': 'Marshall & Ilsley Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Uwajimaya'},
#  {'label': 'COMPANY', 'pattern': 'Memorex'},
#  {'label': 'COMPANY', 'pattern': 'Brane Enterprises Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'IDT Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Castle Realty'},
#  {'label': 'COMPANY', 'pattern': 'Allegheny Technologies'},
#  {'label': 'COMPANY', 'pattern': 'PRATHAM U/o IIFM Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Calpine Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Newgen Software Technologies Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Indian Airlines'},
#  {'label': 'COMPANY', 'pattern': 'India Mortgage Guarantee Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Testor Corporation'},
#  {'label': 'COMPANY', 'pattern': 'CVS Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Timken India Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Home First Finance India Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'BB&T Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Mozilla Foundation'},
#  {'label': 'COMPANY', 'pattern': 'Omnicom Group'},
#  {'label': 'COMPANY', 'pattern': 'Whataburger'},
#  {'label': 'COMPANY', 'pattern': 'Tyson Foods Inc'},
#  {'label': 'COMPANY', 'pattern': 'Teradyne Inc'},
#  {'label': 'COMPANY', 'pattern': 'Siemens Information System Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Del Monte Foods Co'},
#  {'label': 'COMPANY', 'pattern': 'Opticomp'},
#  {'label': 'COMPANY', 'pattern': 'Kroger'},
#  {'label': 'COMPANY', 'pattern': 'Tata Capital'},
#  {'label': 'COMPANY', 'pattern': 'Esselte'},
#  {'label': 'COMPANY', 'pattern': 'Archer Daniels Midland'},
#  {'label': 'COMPANY', 'pattern': 'Galaxy Man'},
#  {'label': 'COMPANY', 'pattern': 'L&T Heavy Engineering'},
#  {'label': 'COMPANY', 'pattern': 'PETsMART Inc'},
#  {'label': 'COMPANY', 'pattern': 'Arcesium'},
#  {'label': 'COMPANY', 'pattern': 'Scholastic Corp'},
#  {'label': 'COMPANY', 'pattern': 'JN-International Medical Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Middle Mile Pro'},
#  {'label': 'COMPANY', 'pattern': 'Hunt Petroleum'},
#  {'label': 'COMPANY', 'pattern': 'Comcast Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Stratabiz'},
#  {'label': 'COMPANY', 'pattern': 'Oreck Corporation'},
#  {'label': 'COMPANY', 'pattern': 'The Black & Decker Corporation'},
#  {'label': 'COMPANY', 'pattern': 'HDFC Life'},
#  {'label': 'COMPANY', 'pattern': 'Torrent Pharmaceuticals'},
#  {'label': 'COMPANY', 'pattern': 'Newmont Mining Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Conectiv, Inc'},
#  {'label': 'COMPANY', 'pattern': 'Vantec'},
#  {'label': 'COMPANY', 'pattern': 'Bain Capital'},
#  {'label': 'COMPANY', 'pattern': 'Earthlink, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Pinkode'},
#  {'label': 'COMPANY', 'pattern': 'Profitpros'},
#  {'label': 'COMPANY', 'pattern': 'Oglethorpe Power Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Columbia Sussex'},
#  {'label': 'COMPANY', 'pattern': 'WWW Realty'},
#  {'label': 'COMPANY', 'pattern': 'Novellus Systems'},
#  {'label': 'COMPANY', 'pattern': 'Puma'},
#  {'label': 'COMPANY', 'pattern': 'General Motors'},
#  {'label': 'COMPANY', 'pattern': 'Cendant Corp'},
#  {'label': 'COMPANY', 'pattern': 'NIF Private Limited'},
#  {'label': 'COMPANY', 'pattern': 'Helping Hand'},
#  {'label': 'COMPANY', 'pattern': 'Broadcom'},
#  {'label': 'COMPANY', 'pattern': 'Golden West Financial Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Exelon Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Adani Enterprises Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Netgear'},
#  {'label': 'COMPANY', 'pattern': 'Estee Lauder Companies Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Tempur-Pedic'},
#  {'label': 'COMPANY', 'pattern': 'American International Group'},
#  {'label': 'COMPANY', 'pattern': 'Paramount Pictures'},
#  {'label': 'COMPANY', 'pattern': 'Target Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Infiniti Research Marketing Solutions'},
#  {'label': 'COMPANY',
#   'pattern': 'ValueMomentum Software Services Private Limited.'},
#  {'label': 'COMPANY', 'pattern': 'Guidant Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Buena Vista Garden Maintenance'},
#  {'label': 'COMPANY', 'pattern': 'Bucyrus International'},
#  {'label': 'COMPANY', 'pattern': 'Halliburton'},
#  {'label': 'COMPANY', 'pattern': 'Beckman Coulter, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Specific Appraisals'},
#  {'label': 'COMPANY', 'pattern': 'Hornbeck Offshore Services'},
#  {'label': 'COMPANY', 'pattern': 'Eastman Kodak'},
#  {'label': 'COMPANY', 'pattern': 'Lear Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Quality Merchant Services'},
#  {'label': 'COMPANY', 'pattern': 'Alok Ingots'},
#  {'label': 'COMPANY', 'pattern': 'Exide Technologies'},
#  {'label': 'COMPANY', 'pattern': 'Diebold Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'Limited Inc.'},
#  {'label': 'COMPANY', 'pattern': 'The Pink Pig Tavern'},
#  {'label': 'COMPANY', 'pattern': 'Shopko Stores Inc'},
#  {'label': 'COMPANY', 'pattern': 'Sysco Corp'},
#  {'label': 'COMPANY', 'pattern': 'Thermo Electron Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Chevron'},
#  {'label': 'COMPANY', 'pattern': 'Odex Solutions Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Apache Software Foundation'},
#  {'label': 'COMPANY', 'pattern': 'Quality Realty Service'},
#  {'label': 'COMPANY', 'pattern': 'Fred Meyer, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Perisolution'},
#  {'label': 'COMPANY', 'pattern': 'Dollar Tree Stores, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Zig Zag Children Clothes'},
#  {'label': 'COMPANY', 'pattern': 'Red River Broadcasting'},
#  {'label': 'COMPANY', 'pattern': 'Brightpoint, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Dynegy Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Beasts of Beauty'},
#  {'label': 'COMPANY', 'pattern': 'Fairchild Semiconductor International Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Sempra Energy'},
#  {'label': 'COMPANY', 'pattern': 'Berger Paints'},
#  {'label': 'COMPANY', 'pattern': 'Bansal Roofing Products Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Applera Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Renys'},
#  {'label': 'COMPANY', 'pattern': 'KB Home'},
#  {'label': 'COMPANY', 'pattern': 'Dover Corporation, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Six Flags'},
#  {'label': 'COMPANY', 'pattern': 'GMR Energy'},
#  {'label': 'COMPANY', 'pattern': 'Microsoft (Redmond)'},
#  {'label': 'COMPANY', 'pattern': 'Office Depot'},
#  {'label': 'COMPANY', 'pattern': 'United Services Automobile Association'},
#  {'label': 'COMPANY', 'pattern': 'El Paso Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Sprint Nextel Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Solectron Corp'},
#  {'label': 'COMPANY', 'pattern': 'Pro-Care Garden Maintenance'},
#  {'label': 'COMPANY', 'pattern': 'Allmerica Financial Corporation'},
#  {'label': 'COMPANY', 'pattern': '3M Company'},
#  {'label': 'COMPANY', 'pattern': 'Spherion Corp'},
#  {'label': 'COMPANY', 'pattern': 'Ingles Market Inc'},
#  {'label': 'COMPANY', 'pattern': 'Boyd Gaming'},
#  {'label': 'COMPANY', 'pattern': 'Deloitte'},
#  {'label': 'COMPANY', 'pattern': 'AFLAC Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'Benchmark Electronics, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'PriceWaterHouse Coopers SDC US Advisory'},
#  {'label': 'COMPANY', 'pattern': 'Comfort Systems USA Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Hyundai Motors'},
#  {'label': 'COMPANY', 'pattern': 'Comcast'},
#  {'label': 'COMPANY', 'pattern': 'Essar Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Axis Mutual Fund'},
#  {'label': 'COMPANY', 'pattern': 'Terra Nova Garden Services'},
#  {'label': 'COMPANY', 'pattern': 'NetZero'},
#  {'label': 'COMPANY', 'pattern': 'Stewart Information Services Corp'},
#  {'label': 'COMPANY', 'pattern': 'Fender Musical Instruments Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Pacific Gas & Electric Company (PG&E)'},
#  {'label': 'COMPANY', 'pattern': 'Edge Yard Service'},
#  {'label': 'COMPANY', 'pattern': 'Hawaiian Electric Industries Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Factset'},
#  {'label': 'COMPANY', 'pattern': 'AnnTaylor Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Martha Stewart Living Omnimedia'},
#  {'label': 'COMPANY', 'pattern': 'Mattel Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Tropicana Products'},
#  {'label': 'COMPANY', 'pattern': 'Oracle India Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'HomeLane'},
#  {'label': 'COMPANY', 'pattern': 'Infinity Investment Plan'},
#  {'label': 'COMPANY', 'pattern': 'Golden Joy'},
#  {'label': 'COMPANY', 'pattern': 'Empezar Global'},
#  {'label': 'COMPANY', 'pattern': 'PROPERTY PISTOL'},
#  {'label': 'COMPANY', 'pattern': 'Advanced Micro Devices, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Marathon Oil Corporation'},
#  {'label': 'COMPANY', 'pattern': 'High Beam Global'},
#  {'label': 'COMPANY', 'pattern': 'MOCA Technology Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Omnicare'},
#  {'label': 'COMPANY', 'pattern': 'Kenyt Techologies'},
#  {'label': 'COMPANY', 'pattern': 'Maxi-Tech'},
#  {'label': 'COMPANY', 'pattern': 'Ergode It services'},
#  {'label': 'COMPANY', 'pattern': 'Barclays'},
#  {'label': 'COMPANY', 'pattern': 'AES Corporation'},
#  {'label': 'COMPANY', 'pattern': 'ADC Telecommunications, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Magik Lamp'},
#  {'label': 'COMPANY', 'pattern': 'Vodafone'},
#  {'label': 'COMPANY', 'pattern': 'Southern California Edison'},
#  {'label': 'COMPANY', 'pattern': 'Rayovac'},
#  {'label': 'COMPANY', 'pattern': 'Acme Brick Company'},
#  {'label': 'COMPANY', 'pattern': 'Best Buy Co., Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Applied Materials'},
#  {'label': 'COMPANY', 'pattern': 'Calpine'},
#  {'label': 'COMPANY', 'pattern': "Zaxby's"},
#  {'label': 'COMPANY', 'pattern': 'Eddie Bauer'},
#  {'label': 'COMPANY', 'pattern': 'Kalpataru Limited'},
#  {'label': 'COMPANY', 'pattern': 'Astoria Financial Corporation'},
#  {'label': 'COMPANY', 'pattern': 'R. R. Donnelley & Sons'},
#  {'label': 'COMPANY', 'pattern': "Albertson's, Inc."},
#  {'label': 'COMPANY', 'pattern': 'Life Map'},
#  {'label': 'COMPANY', 'pattern': 'CEAT TYRE'},
#  {'label': 'COMPANY', 'pattern': 'AU Small Finance Bank'},
#  {'label': 'COMPANY', 'pattern': 'Mellon Financial Corporation'},
#  {'label': 'COMPANY', 'pattern': 'National Fuel Gas Company'},
#  {'label': 'COMPANY', 'pattern': 'Best Buy'},
#  {'label': 'COMPANY', 'pattern': 'Myspace'},
#  {'label': 'COMPANY', 'pattern': 'TJX Companies Inc'},
#  {'label': 'COMPANY', 'pattern': 'Chillpill Venture'},
#  {'label': 'COMPANY', 'pattern': 'Gap'},
#  {'label': 'COMPANY', 'pattern': 'Black Hills Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Nike Inc'},
#  {'label': 'COMPANY', 'pattern': 'Intuit Inc.'},
#  {'label': 'COMPANY', 'pattern': 'One-Up Realty'},
#  {'label': 'COMPANY', 'pattern': 'Maruti Insurance Broking Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Georgia Gulf Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Phillips Petroleum Co'},
#  {'label': 'COMPANY', 'pattern': 'VOLVO AUTO INDIA PRIVATE LTD'},
#  {'label': 'COMPANY', 'pattern': 'Chargepal'},
#  {'label': 'COMPANY', 'pattern': 'ADROSONIC'},
#  {'label': 'COMPANY', 'pattern': 'Pitambara Selections'},
#  {'label': 'COMPANY', 'pattern': 'NTL Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'Abercrombie & Fitch Co.'},
#  {'label': 'COMPANY', 'pattern': 'Lawyered'},
#  {'label': 'COMPANY', 'pattern': 'Libera'},
#  {'label': 'COMPANY', 'pattern': 'Citigroup'},
#  {'label': 'COMPANY', 'pattern': 'Novell'},
#  {'label': 'COMPANY', 'pattern': 'Rent A Center Inc'},
#  {'label': 'COMPANY', 'pattern': 'FIS Solutions'},
#  {'label': 'COMPANY', 'pattern': 'Universo Realtors'},
#  {'label': 'COMPANY', 'pattern': 'The Coca-Cola Company'},
#  {'label': 'COMPANY', 'pattern': 'Big Basket'},
#  {'label': 'COMPANY', 'pattern': 'DaVita Inc.'},
#  {'label': 'COMPANY', 'pattern': 'BlackRock'},
#  {'label': 'COMPANY', 'pattern': 'NirogGyan'},
#  {'label': 'COMPANY', 'pattern': 'International Multifoods Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Fireball'},
#  {'label': 'COMPANY', 'pattern': 'USFreighways Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Rockwell Automation Inc'},
#  {'label': 'COMPANY', 'pattern': 'Capitalcorp'},
#  {'label': 'COMPANY', 'pattern': 'Alberto-Culver Company'},
#  {'label': 'COMPANY', 'pattern': 'Storage Technology Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Pacific Gas & Electric Corp.'},
#  {'label': 'COMPANY', 'pattern': "Dippin' Dots"},
#  {'label': 'COMPANY', 'pattern': 'Lyondell Chemical Company'},
#  {'label': 'COMPANY', 'pattern': 'Xanadu Realty'},
#  {'label': 'COMPANY', 'pattern': 'Hot Topic'},
#  {'label': 'COMPANY', 'pattern': 'International Paper'},
#  {'label': 'COMPANY', 'pattern': 'Nextel Communications Inc'},
#  {'label': 'COMPANY', 'pattern': 'The MONY Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'USG Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Whole Foods Market Inc'},
#  {'label': 'COMPANY', 'pattern': 'LODHA Group'},
#  {'label': 'COMPANY', 'pattern': 'United Stationers Inc'},
#  {'label': 'COMPANY', 'pattern': 'Aquila, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'UGI Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Winnebago Industries'},
#  {'label': 'COMPANY', 'pattern': 'Asian Plan'},
#  {'label': 'COMPANY', 'pattern': 'E*Trade Group, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Sanmina-SCI Inc'},
#  {'label': 'COMPANY', 'pattern': 'Aurobindo Realty & Infrastrcture Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Chandan Timber and Arts'},
#  {'label': 'COMPANY', 'pattern': 'Dole Foods'},
#  {'label': 'COMPANY', 'pattern': 'Westinghouse Digital LLC'},
#  {'label': 'COMPANY', 'pattern': 'Mordor Intelligence'},
#  {'label': 'COMPANY', 'pattern': 'Reliance Ajio'},
#  {'label': 'COMPANY', 'pattern': 'Viacom'},
#  {'label': 'COMPANY', 'pattern': 'Advantica Restaurant Group, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Echostar Communications Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Airgas'},
#  {'label': 'COMPANY', 'pattern': 'Caterpillar'},
#  {'label': 'COMPANY', 'pattern': 'Paxton Media Group'},
#  {'label': 'COMPANY', 'pattern': 'Adfactors Pr Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Dover Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Adaptabiz'},
#  {'label': 'COMPANY', 'pattern': 'M.D.C. Holdings Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Oshkosh Truck Corp'},
#  {'label': 'COMPANY', 'pattern': 'Ericsson India'},
#  {'label': 'COMPANY', 'pattern': 'Avaya'},
#  {'label': 'COMPANY', 'pattern': 'Way to go consultants'},
#  {'label': 'COMPANY', 'pattern': 'Hubbell Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Parag Milk Foods'},
#  {'label': 'COMPANY', 'pattern': 'Centaur Pharmaceuticals Ltd.'},
#  {'label': 'COMPANY', 'pattern': "Linens 'n Things Inc."},
#  {'label': 'COMPANY', 'pattern': 'Star Assistance'},
#  {'label': 'COMPANY', 'pattern': 'Dynegy'},
#  {'label': 'COMPANY', 'pattern': 'Siebel Systems Inc'},
#  {'label': 'COMPANY', 'pattern': 'Visa Steel'},
#  {'label': 'COMPANY', 'pattern': 'Champion Enterprises Inc.'},
#  {'label': 'COMPANY', 'pattern': 'APAC Financial Services Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Axis Securities'},
#  {'label': 'COMPANY', 'pattern': 'Worthington Industries Inc'},
#  {'label': 'COMPANY', 'pattern': 'Doculabs'},
#  {'label': 'COMPANY', 'pattern': 'Total Network Development'},
#  {'label': 'COMPANY', 'pattern': 'Casco Bay Lines'},
#  {'label': 'COMPANY', 'pattern': 'Certybox'},
#  {'label': 'COMPANY', 'pattern': 'International Business Machines (IBM)'},
#  {'label': 'COMPANY', 'pattern': 'Matrix Architectural Service'},
#  {'label': 'COMPANY', 'pattern': 'Fragrant Flower Lawn Services'},
#  {'label': 'COMPANY', 'pattern': 'Berkshire Hathaway Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Olin Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Alliant Energy Corporation'},
#  {'label': 'COMPANY', 'pattern': 'American Greetings Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Neeyamo Enterprise Solutions'},
#  {'label': 'COMPANY', 'pattern': 'DC Comics'},
#  {'label': 'COMPANY', 'pattern': 'AMC Entertainment Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Airgas, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'ICICI Wealth Management'},
#  {'label': 'COMPANY', 'pattern': 'UAL Corporation'},
#  {'label': 'COMPANY', 'pattern': 'American Water Works Company, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Origo Finance'},
#  {'label': 'COMPANY', 'pattern': 'Auto-Owners Insurance'},
#  {'label': 'COMPANY', 'pattern': 'Bio-Rad Laboratories'},
#  {'label': 'COMPANY', 'pattern': 'Triad Hospitals Inc'},
#  {'label': 'COMPANY', 'pattern': 'CREDFLOW'},
#  {'label': 'COMPANY', 'pattern': "Lowe's"},
#  {'label': 'COMPANY', 'pattern': 'Lyxel and Flamingo Digital Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Federal Express Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Northern Star'},
#  {'label': 'COMPANY', 'pattern': 'ViewSonic'},
#  {'label': 'COMPANY', 'pattern': 'Finwizard Technology Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Peoples Energy Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Fiserv'},
#  {'label': 'COMPANY', 'pattern': 'Adapt'},
#  {'label': 'COMPANY', 'pattern': 'Precision Castparts Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Take-Two Interactive'},
#  {'label': 'COMPANY', 'pattern': 'OSI Restaurant Partners'},
#  {'label': 'COMPANY', 'pattern': 'Global Data Research Center'},
#  {'label': 'COMPANY', 'pattern': 'Autoliv, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Coforge Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'CESC'},
#  {'label': 'COMPANY', 'pattern': 'Gas Legion'},
#  {'label': 'COMPANY', 'pattern': 'Dr Pepper Snapple Group'},
#  {'label': 'COMPANY', 'pattern': 'Anheuser-Busch Companies, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'CBRL Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Accuquote'},
#  {'label': 'COMPANY', 'pattern': 'MTX Audio'},
#  {'label': 'COMPANY', 'pattern': 'Mu Sigma'},
#  {'label': 'COMPANY', 'pattern': 'C.H. Robinson Worldwide'},
#  {'label': 'COMPANY', 'pattern': 'TCS CBO'},
#  {'label': 'COMPANY', 'pattern': 'GEICO'},
#  {'label': 'COMPANY', 'pattern': 'Harman International Industries Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Cut Rite Lawn Care'},
#  {'label': 'COMPANY', 'pattern': 'Office Max'},
#  {'label': 'COMPANY', 'pattern': 'The White Rabbit'},
#  {'label': 'COMPANY', 'pattern': 'Broadwing, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'DVC'},
#  {'label': 'COMPANY', 'pattern': 'Constellation Emergy Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Danaher'},
#  {'label': 'COMPANY', 'pattern': 'The Spotted Cougar'},
#  {'label': 'COMPANY', 'pattern': 'Lehman Brothers Holdings Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Sun Microsystems, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Blue Star Infotech Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Quiznos'},
#  {'label': 'COMPANY', 'pattern': '3DPLM Software Solutions'},
#  {'label': 'COMPANY', 'pattern': 'Custom Lawn Care'},
#  {'label': 'COMPANY', 'pattern': 'Avis Budget Group'},
#  {'label': 'COMPANY', 'pattern': 'Valspar Corporation'},
#  {'label': 'COMPANY', 'pattern': 'iRobot'},
#  {'label': 'COMPANY', 'pattern': 'Net Elixir'},
#  {'label': 'COMPANY', 'pattern': 'Unisource Energy Corp'},
#  {'label': 'COMPANY', 'pattern': 'PalmOne, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'KLA-Tencor Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Waste Management Inc'},
#  {'label': 'COMPANY', 'pattern': 'Bed Bath & Beyond'},
#  {'label': 'COMPANY', 'pattern': 'Nationwide Insurance'},
#  {'label': 'COMPANY', 'pattern': 'Forum Communications'},
#  {'label': 'COMPANY', 'pattern': 'Wallace Computer Services Inc'},
#  {'label': 'COMPANY', 'pattern': 'United Defense Industries Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Dell, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Campbell Soup Co.'},
#  {'label': 'COMPANY', 'pattern': 'Energy East'},
#  {'label': 'COMPANY', 'pattern': 'IMS Health Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Giant Food'},
#  {'label': 'COMPANY', 'pattern': 'Armstrong World Industries'},
#  {'label': 'COMPANY', 'pattern': 'The May Department Stores Company'},
#  {'label': 'COMPANY', 'pattern': 'System Star'},
#  {'label': 'COMPANY', 'pattern': 'Mindtree Consulting'},
#  {'label': 'COMPANY', 'pattern': 'Aetna Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Affiliated Computer Services, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'The Flying Hippo'},
#  {'label': 'COMPANY', 'pattern': 'Amazon Development Center India'},
#  {'label': 'COMPANY', 'pattern': 'IFB Industries'},
#  {'label': 'COMPANY', 'pattern': 'Encompass Services Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Corning Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Maytag Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Xcel Energy Inc'},
#  {'label': 'COMPANY', 'pattern': 'IHS Markit Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'OM Logistics'},
#  {'label': 'COMPANY', 'pattern': 'SS&C Globeop financial services'},
#  {'label': 'COMPANY', 'pattern': 'TRW Inc'},
#  {'label': 'COMPANY', 'pattern': 'Temple-Inland Inc'},
#  {'label': 'COMPANY', 'pattern': 'Union Pacific Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Phar Mor Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Infoedge India(Naukri.com_'},
#  {'label': 'COMPANY',
#   'pattern': 'Finpe (Fintech Banking & Financial Services a Skysoft Infotek India Pvt. Ltd.enterprise)'},
#  {'label': 'COMPANY', 'pattern': 'Consolidated Freightways Corp.'},
#  {'label': 'COMPANY', 'pattern': 'E-zhe Source'},
#  {'label': 'COMPANY', 'pattern': 'Soma Enterprises'},
#  {'label': 'COMPANY', 'pattern': 'Warner Bros. Entertainment'},
#  {'label': 'COMPANY', 'pattern': 'General Dynamics'},
#  {'label': 'COMPANY', 'pattern': 'Quantum Corp'},
#  {'label': 'COMPANY', 'pattern': 'Noble Energy Inc'},
#  {'label': 'COMPANY', 'pattern': 'MasTec Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Ford Motor Company'},
#  {'label': 'COMPANY', 'pattern': 'Custom Lawn Service'},
#  {'label': 'COMPANY', 'pattern': 'AnaSpec'},
#  {'label': 'COMPANY', 'pattern': 'B O International'},
#  {'label': 'COMPANY', 'pattern': 'IMS Group'},
#  {'label': 'COMPANY', 'pattern': 'Sterling Ledet & Associates, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Cuemath'},
#  {'label': 'COMPANY', 'pattern': 'Transocean Inc'},
#  {'label': 'COMPANY', 'pattern': 'Owens & Minor Inc.'},
#  {'label': 'COMPANY', 'pattern': 'JUSCO Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Ingram Micro Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Schering-Plough Corp'},
#  {'label': 'COMPANY', 'pattern': 'Savills'},
#  {'label': 'COMPANY', 'pattern': 'Integra Investment Service'},
#  {'label': 'COMPANY', 'pattern': 'Afuze Collezioni'},
#  {'label': 'COMPANY', 'pattern': 'Atari'},
#  {'label': 'COMPANY', 'pattern': 'AutoNation, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'We Make Scholars'},
#  {'label': 'COMPANY', 'pattern': 'Vertex Pharmaceuticals'},
#  {'label': 'COMPANY', 'pattern': 'Wisconsin Energy Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Magna Wealth'},
#  {'label': 'COMPANY', 'pattern': 'Dream Home Real Estate Service'},
#  {'label': 'COMPANY', 'pattern': 'ChexSystems'},
#  {'label': 'COMPANY', 'pattern': 'Garden Guru'},
#  {'label': 'COMPANY', 'pattern': 'Belkin'},
#  {'label': 'COMPANY', 'pattern': 'LeapFrog Enterprises'},
#  {'label': 'COMPANY', 'pattern': 'Anixter International Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Del Monte Foods'},
#  {'label': 'COMPANY', 'pattern': 'Integra Investment Plan'},
#  {'label': 'COMPANY', 'pattern': 'Tower Research Capital'},
#  {'label': 'COMPANY', 'pattern': 'Financial Hospital'},
#  {'label': 'COMPANY', 'pattern': 'Cogent Communications'},
#  {'label': 'COMPANY', 'pattern': 'GeoSpoc Geospatial Services Pvt. Ltd'},
#  {'label': 'COMPANY', 'pattern': 'American Power Conversion Corporation'},
#  {'label': 'COMPANY', 'pattern': 'TMP Worldwide Inc'},
#  {'label': 'COMPANY', 'pattern': 'Udayy'},
#  {'label': 'COMPANY', 'pattern': 'Boston Scientific Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Utkarsh Small Finance Bank Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'W. R. Grace and Company'},
#  {'label': 'COMPANY', 'pattern': 'Trump Hotels & Casino Resorts Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Vaughan & Bushnell Manufacturing'},
#  {'label': 'COMPANY', 'pattern': 'FirstEnergy Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Solution Realty'},
#  {'label': 'COMPANY', 'pattern': 'Rohm & Haas Co.'},
#  {'label': 'COMPANY', 'pattern': 'Multicerv'},
#  {'label': 'COMPANY', 'pattern': 'Mount Meru Group'},
#  {'label': 'COMPANY', 'pattern': 'Netcore'},
#  {'label': 'COMPANY', 'pattern': 'Hercules Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Formula Gray'},
#  {'label': 'COMPANY', 'pattern': 'Soyo Group'},
#  {'label': 'COMPANY', 'pattern': 'Comdisco Inc.'},
#  {'label': 'COMPANY', 'pattern': "McDonald's Corporation"},
#  {'label': 'COMPANY', 'pattern': 'Beazer Homes USA'},
#  {'label': 'COMPANY', 'pattern': 'Seagate Technology'},
#  {'label': 'COMPANY', 'pattern': 'Maxiserve'},
#  {'label': 'COMPANY', 'pattern': "Pilgrim's Pride Corporation"},
#  {'label': 'COMPANY', 'pattern': 'Qualcomm'},
#  {'label': 'COMPANY', 'pattern': 'ManPower'},
#  {'label': 'COMPANY', 'pattern': 'Shure Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'Brunswick Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Metalsa'},
#  {'label': 'COMPANY', 'pattern': 'Kemet Corp.'},
#  {'label': 'COMPANY', 'pattern': 'RPM Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Federal Home Loan Mortgage Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Mission Realty'},
#  {'label': 'COMPANY', 'pattern': 'Loews Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Belo Corp.'},
#  {'label': 'COMPANY', 'pattern': 'BMC Software'},
#  {'label': 'COMPANY', 'pattern': 'Houchens Industries'},
#  {'label': 'COMPANY', 'pattern': 'Foster Wheeler Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Grass Roots Yard Services'},
#  {'label': 'COMPANY', 'pattern': 'GETWORK'},
#  {'label': 'COMPANY', 'pattern': 'Paychex Inc'},
#  {'label': 'COMPANY', 'pattern': 'Insight Enterprises Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Reliance Steel & Aluminum Co.'},
#  {'label': 'COMPANY', 'pattern': 'Thomas & Betts Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Goldman Sachs'},
#  {'label': 'COMPANY', 'pattern': 'Millennium Chemicals Inc.'},
#  {'label': 'COMPANY', 'pattern': 'DynCorp'},
#  {'label': 'COMPANY', 'pattern': 'Trinity Industries Inc'},
#  {'label': 'COMPANY', 'pattern': 'Kantar Group'},
#  {'label': 'COMPANY', 'pattern': 'ICICI PRUDENTIAL LIFE INSURANCE COMPANY'},
#  {'label': 'COMPANY', 'pattern': 'Infosys Technologies'},
#  {'label': 'COMPANY', 'pattern': 'Stater Bros. Holdings Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Dynatronics Accessories'},
#  {'label': 'COMPANY', 'pattern': 'Subway'},
#  {'label': 'COMPANY', 'pattern': 'Magik Gray'},
#  {'label': 'COMPANY', 'pattern': 'Starbucks Corp'},
#  {'label': 'COMPANY', 'pattern': 'Envirotecture Design'},
#  {'label': 'COMPANY', 'pattern': 'Nvidia'},
#  {'label': 'COMPANY', 'pattern': 'Go Daddy'},
#  {'label': 'COMPANY', 'pattern': 'Furniture Brands International Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Lucas Oil'},
#  {'label': 'COMPANY', 'pattern': 'Steinway & Sons'},
#  {'label': 'COMPANY', 'pattern': 'USA Interactive'},
#  {'label': 'COMPANY', 'pattern': 'PPG Industries Inc'},
#  {'label': 'COMPANY', 'pattern': 'Grade A Investment'},
#  {'label': 'COMPANY', 'pattern': 'Digital Horizons'},
#  {'label': 'COMPANY', 'pattern': 'Great Lakes Chemical Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Hibernia Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Alienware'},
#  {'label': 'COMPANY', 'pattern': 'Gatorade'},
#  {'label': 'COMPANY', 'pattern': 'Powerbod'},
#  {'label': 'COMPANY',
#   'pattern': 'Paisadukaan.com - BigWin Infotech Private Limited'},
#  {'label': 'COMPANY', 'pattern': 'Garden Master'},
#  {'label': 'COMPANY', 'pattern': 'Gold Touch'},
#  {'label': 'COMPANY', 'pattern': 'K12 Techno Services Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Grey Global Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Magna Solution'},
#  {'label': 'COMPANY', 'pattern': 'Lumencraft'},
#  {'label': 'COMPANY', 'pattern': 'Dow Jones & Company'},
#  {'label': 'COMPANY', 'pattern': 'Gold Leaf Garden Management'},
#  {'label': 'COMPANY', 'pattern': 'Jefferson-Pilot Co.'},
#  {'label': 'COMPANY', 'pattern': 'Chicago Bridge & Iron Company'},
#  {'label': 'COMPANY', 'pattern': 'Shirokiya'},
#  {'label': 'COMPANY', 'pattern': 'Harsco Corp.'},
#  {'label': 'COMPANY', 'pattern': 'MBNA Corporation'},
#  {'label': 'COMPANY', 'pattern': 'NetDNA'},
#  {'label': 'COMPANY', 'pattern': 'Runwal Developers'},
#  {'label': 'COMPANY', 'pattern': 'Gamma Grays'},
#  {'label': 'COMPANY', 'pattern': 'Halliburton Co.'},
#  {'label': 'COMPANY', 'pattern': 'Household International Corp.'},
#  {'label': 'COMPANY', 'pattern': 'C. H. Robinson Worldwide Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Motilal Oswal Financial Services'},
#  {'label': 'COMPANY', 'pattern': 'Mutual of Omaha'},
#  {'label': 'COMPANY', 'pattern': 'Citrix'},
#  {'label': 'COMPANY', 'pattern': 'Paccar Inc'},
#  {'label': 'COMPANY', 'pattern': 'Valero Energy Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Lee (jeans)'},
#  {'label': 'COMPANY', 'pattern': 'XPAC'},
#  {'label': 'COMPANY', 'pattern': 'Fifth Third Bancorp'},
#  {'label': 'COMPANY', 'pattern': 'U.S. Industries Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Martel Communication'},
#  {'label': 'COMPANY', 'pattern': 'Plan Smart'},
#  {'label': 'COMPANY', 'pattern': 'Brindco Sales Private Limited'},
#  {'label': 'COMPANY', 'pattern': 'Naturohair'},
#  {'label': 'COMPANY', 'pattern': 'PSS World Medical Inc'},
#  {'label': 'COMPANY', 'pattern': 'Praxair Inc'},
#  {'label': 'COMPANY', 'pattern': 'ServiceMaster Co'},
#  {'label': 'COMPANY', 'pattern': 'Stewart & Stevenson Services Inc'},
#  {'label': 'COMPANY', 'pattern': 'Ricaria Support Services Pvt ltd'},
#  {'label': 'COMPANY', 'pattern': 'Community Health Systems Inc.'},
#  {'label': 'COMPANY', 'pattern': 'McLeodUSA Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'CSX Corp.'},
#  {'label': 'COMPANY', 'pattern': 'PNM Resources Inc'},
#  {'label': 'COMPANY', 'pattern': 'OpenMarket Inc.'},
#  {'label': 'COMPANY', 'pattern': 'John Deere India (P) Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Molex Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'Always (product)'},
#  {'label': 'COMPANY', 'pattern': 'PC Power and Cooling'},
#  {'label': 'COMPANY', 'pattern': 'Provident Financial Group'},
#  {'label': 'COMPANY', 'pattern': 'Rockwell Collins'},
#  {'label': 'COMPANY', 'pattern': "O'Reilly"},
#  {'label': 'COMPANY', 'pattern': 'New Era Tickets'},
#  {'label': 'COMPANY', 'pattern': 'Amphenol Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Belk'},
#  {'label': 'COMPANY', 'pattern': 'Simply Save'},
#  {'label': 'COMPANY', 'pattern': 'Brinker International, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Indifi Technologies Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Analog Devices'},
#  {'label': 'COMPANY', 'pattern': 'Puravankara Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Tata Consulting Engineers Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Tellabs Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Dun & Bradstreet Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Energizer Holdings'},
#  {'label': 'COMPANY', 'pattern': 'PWC'},
#  {'label': 'COMPANY',
#   'pattern': 'Burlington Coat Factory Warehouse Corporation'},
#  {'label': 'COMPANY', 'pattern': 'i-flex Solutions'},
#  {'label': 'COMPANY', 'pattern': 'Multi-Systems Merchant Services'},
#  {'label': 'COMPANY', 'pattern': 'Dell Computer Corporation'},
#  {'label': 'COMPANY', 'pattern': 'The Bear Stearns Companies Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Columbia Pictures'},
#  {'label': 'COMPANY', 'pattern': 'Azentio Software Private Limited'},
#  {'label': 'COMPANY', 'pattern': 'Nash Finch Company'},
#  {'label': 'COMPANY', 'pattern': 'Chem-Dry'},
#  {'label': 'COMPANY', 'pattern': 'H.B. Fuller Company'},
#  {'label': 'COMPANY', 'pattern': 'Wise Appraisals'},
#  {'label': 'COMPANY', 'pattern': 'True elements'},
#  {'label': 'COMPANY', 'pattern': 'Pro Yard Services'},
#  {'label': 'COMPANY', 'pattern': 'VonMaur'},
#  {'label': 'COMPANY', 'pattern': 'Corpbay'},
#  {'label': 'COMPANY', 'pattern': 'J.B. Hunt Transport Services Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Plains All American Pipeline LP'},
#  {'label': 'COMPANY', 'pattern': 'Transocean'},
#  {'label': 'COMPANY', 'pattern': 'KK Group'},
#  {'label': 'COMPANY', 'pattern': 'AK Steel Holding'},
#  {'label': 'COMPANY', 'pattern': 'Pitney Bowes Inc.'},
#  {'label': 'COMPANY', 'pattern': 'CNET'},
#  {'label': 'COMPANY', 'pattern': 'Desert Garden Help'},
#  {'label': 'COMPANY', 'pattern': 'Maruti Suzuki Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Bennett Coleman and Co Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Cablevision Systems Corp'},
#  {'label': 'COMPANY', 'pattern': 'Abbott Laboratories'},
#  {'label': 'COMPANY', 'pattern': 'Administaff, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Verizon Communications Inc'},
#  {'label': 'COMPANY', 'pattern': 'H.J. Heinz Company'},
#  {'label': 'COMPANY', 'pattern': 'Revlon Inc'},
#  {'label': 'COMPANY', 'pattern': 'Johnson Controls Inc.'},
#  {'label': 'COMPANY', 'pattern': 'CBS Corporation'},
#  {'label': 'COMPANY', 'pattern': 'FinEdge Advisory Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'CMC Limited'},
#  {'label': 'COMPANY', 'pattern': 'Polaris Industries'},
#  {'label': 'COMPANY', 'pattern': 'Domtar'},
#  {'label': 'COMPANY', 'pattern': 'MegaSolutions'},
#  {'label': 'COMPANY', 'pattern': 'RGS Energy Group Inc'},
#  {'label': 'COMPANY', 'pattern': 'Tech Mahindra Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Bemis Company, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Pizza Hut'},
#  {'label': 'COMPANY', 'pattern': 'TravelCenters of America Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Knight-Ridder Inc.'},
#  {'label': 'COMPANY', 'pattern': 'The Serendipity Dip'},
#  {'label': 'COMPANY', 'pattern': 'SAP Labs'},
#  {'label': 'COMPANY', 'pattern': 'Sunoco Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Asian Paints'},
#  {'label': 'COMPANY', 'pattern': 'Mercury General Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Spartan Stores Inc'},
#  {'label': 'COMPANY', 'pattern': 'Golden State Bancorp Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Transcend Street India Pvt. Ltd'},
#  {'label': 'COMPANY', 'pattern': 'The Clorox Co.'},
#  {'label': 'COMPANY', 'pattern': 'PalmSource, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'JustDial'},
#  {'label': 'COMPANY', 'pattern': 'Marriott Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Red Fox Tavern'},
#  {'label': 'COMPANY', 'pattern': 'Morningstar'},
#  {'label': 'COMPANY', 'pattern': 'Centex Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Cadence Design Systems, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Verizon Wireless'},
#  {'label': 'COMPANY', 'pattern': 'Telephone & Data Systems Inc'},
#  {'label': 'COMPANY', 'pattern': 'Rickett Benkeiser'},
#  {'label': 'COMPANY', 'pattern': 'Ganesh Premium Tea Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'PWC India'},
#  {'label': 'COMPANY', 'pattern': 'Imperial Sugar Company'},
#  {'label': 'COMPANY', 'pattern': 'Adaptas'},
#  {'label': 'COMPANY', 'pattern': 'Motorola Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Ball Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Kellwood Company'},
#  {'label': 'COMPANY', 'pattern': 'Rivera Property Maintenance'},
#  {'label': 'COMPANY', 'pattern': 'CtrlS Datacenters Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Adaptaz'},
#  {'label': 'COMPANY', 'pattern': 'UTStarcom'},
#  {'label': 'COMPANY', 'pattern': 'Hi-Point Firearms'},
#  {'label': 'COMPANY', 'pattern': "Colt's Manufacturing Company"},
#  {'label': 'COMPANY', 'pattern': 'Avery Dennison Corporation'},
#  {'label': 'COMPANY', 'pattern': 'EMA Partners'},
#  {'label': 'COMPANY', 'pattern': 'BFG Technologies'},
#  {'label': 'COMPANY', 'pattern': 'Omnicare Inc'},
#  {'label': 'COMPANY', 'pattern': 'Orange Mantra'},
#  {'label': 'COMPANY', 'pattern': 'SouthTrust Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Alert Alarm Company'},
#  {'label': 'COMPANY', 'pattern': 'Fresh&Easy Neighbourhood Market'},
#  {'label': 'COMPANY', 'pattern': 'McNally Bharat Engg. Co. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Circus Social'},
#  {'label': 'COMPANY', 'pattern': 'Berry Plastics'},
#  {'label': 'COMPANY', 'pattern': 'Magna Consulting'},
#  {'label': 'COMPANY', 'pattern': 'Qpass'},
#  {'label': 'COMPANY', 'pattern': 'Valuefy Solutions'},
#  {'label': 'COMPANY',
#   'pattern': 'Expeditors International of Washington Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Infor'},
#  {'label': 'COMPANY', 'pattern': 'The Network Chef'},
#  {'label': 'COMPANY', 'pattern': 'Flipkart'},
#  {'label': 'COMPANY', 'pattern': 'Tata Technologies'},
#  {'label': 'COMPANY', 'pattern': 'Level 3 Communications Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Mahindra Nevistar'},
#  {'label': 'COMPANY', 'pattern': 'AMETEK'},
#  {'label': 'COMPANY', 'pattern': 'Anixter International'},
#  {'label': 'COMPANY', 'pattern': 'NiSource Inc'},
#  {'label': 'COMPANY', 'pattern': 'Firestone Tire and Rubber Company'},
#  {'label': 'COMPANY', 'pattern': 'NTT Data Business Solutions Ltd'},
#  {'label': 'COMPANY', 'pattern': 'J.C. Penny Co.'},
#  {'label': 'COMPANY', 'pattern': 'Unified Western Grocers Inc'},
#  {'label': 'COMPANY', 'pattern': 'International Paper Co.'},
#  {'label': 'COMPANY', 'pattern': 'Tesoro Petroleum Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Lam Research Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Enrich Garden Services'},
#  {'label': 'COMPANY', 'pattern': 'Locuz Enterprise Solutions'},
#  {'label': 'COMPANY', 'pattern': 'Dale Carnegie (Walchand Group)'},
#  {'label': 'COMPANY', 'pattern': 'Carnival Corporation & plc'},
#  {'label': 'COMPANY', 'pattern': 'GATX Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Kimberly-Clark Corporation'},
#  {'label': 'COMPANY', 'pattern': 'CMIE'},
#  {'label': 'COMPANY', 'pattern': 'Qwest'},
#  {'label': 'COMPANY', 'pattern': 'Dollar Tree'},
#  {'label': 'COMPANY', 'pattern': 'H. J. Heinz Company'},
#  {'label': 'COMPANY', 'pattern': 'World of Fun'},
#  {'label': 'COMPANY', 'pattern': 'Masco Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Avnet'},
#  {'label': 'COMPANY', 'pattern': 'Saint-Gobain Glass'},
#  {'label': 'COMPANY', 'pattern': 'MagnaSolution'},
#  {'label': 'COMPANY', 'pattern': 'Kerr-McGee Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Sapient'},
#  {'label': 'COMPANY', 'pattern': "Tully's Coffee"},
#  {'label': 'COMPANY', 'pattern': 'Borders Group'},
#  {'label': 'COMPANY', 'pattern': 'Acuit̩ Ratings & Research Limited'},
#  {'label': 'COMPANY', 'pattern': 'Equinox Labs'},
#  {'label': 'COMPANY', 'pattern': 'PayMe India'},
#  {'label': 'COMPANY', 'pattern': 'Body Toning'},
#  {'label': 'COMPANY', 'pattern': 'Kmart'},
#  {'label': 'COMPANY', 'pattern': 'Earthworks Yard Maintenance'},
#  {'label': 'COMPANY', 'pattern': 'OLX GROUP'},
#  {'label': 'COMPANY', 'pattern': 'Arkansas Best Corporation'},
#  {'label': 'COMPANY', 'pattern': 'State Street Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Full Color'},
#  {'label': 'COMPANY', 'pattern': 'savart'},
#  {'label': 'COMPANY', 'pattern': 'Hovnanian Enterprises Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Belk, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Lincoln National Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Applied Materials, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Allergan'},
#  {'label': 'COMPANY', 'pattern': 'PepsiCo Inc.'},
#  {'label': 'COMPANY', 'pattern': 'LG Electronics'},
#  {'label': 'COMPANY', 'pattern': 'Equitable Resources Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Delta Air Lines Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Universal Forest Products Inc'},
#  {'label': 'COMPANY', 'pattern': 'Sealed Air Corp'},
#  {'label': 'COMPANY', 'pattern': 'AGL Resources'},
#  {'label': 'COMPANY', 'pattern': 'Acuity Brands'},
#  {'label': 'COMPANY', 'pattern': 'Merck & Co., Inc.'},
#  {'label': 'COMPANY', 'pattern': 'American Reprographics Company'},
#  {'label': 'COMPANY', 'pattern': 'Towers Perrin'},
#  {'label': 'COMPANY', 'pattern': 'Total Yard Maintenance'},
#  {'label': 'COMPANY', 'pattern': 'Darden Restaurants'},
#  {'label': 'COMPANY', 'pattern': 'Acuserv'},
#  {'label': 'COMPANY', 'pattern': 'Nestle'},
#  {'label': 'COMPANY', 'pattern': 'Cians Analytics'},
#  {'label': 'COMPANY', 'pattern': "Kohl's Corp."},
#  {'label': 'COMPANY', 'pattern': 'Robert Half International Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Salem Communications'},
#  {'label': 'COMPANY', 'pattern': 'DEN Networks Limited'},
#  {'label': 'COMPANY', 'pattern': 'Integra Wealth Planners'},
#  {'label': 'COMPANY', 'pattern': 'S3 Graphics'},
#  {'label': 'COMPANY', 'pattern': 'Alaska Air Group'},
#  {'label': 'COMPANY', 'pattern': 'ESAF Small Finance Bank'},
#  {'label': 'COMPANY', 'pattern': 'Murphy Oil Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Bergwerff Organic India Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'AVST'},
#  {'label': 'COMPANY', 'pattern': 'Costco'},
#  {'label': 'COMPANY', 'pattern': 'Orion'},
#  {'label': 'COMPANY', 'pattern': 'Discover Financial Services'},
#  {'label': 'COMPANY', 'pattern': 'Wm Wrigley Jr Company'},
#  {'label': 'COMPANY', 'pattern': 'Varco International Inc'},
#  {'label': 'COMPANY', 'pattern': 'Monk Real Estate Service'},
#  {'label': 'COMPANY', 'pattern': 'Plan Future'},
#  {'label': 'COMPANY', 'pattern': 'National City Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Hilton Hotels Corporation'},
#  {'label': 'COMPANY', 'pattern': 'eBay'},
#  {'label': 'COMPANY', 'pattern': 'Boise Cascade Corporation'},
#  {'label': 'COMPANY', 'pattern': 'L&L Hawaiian Barbecue'},
#  {'label': 'COMPANY', 'pattern': 'Microsoft Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Ace Hardware'},
#  {'label': 'COMPANY', 'pattern': 'Buena Vista Realty Service'},
#  {'label': 'COMPANY', 'pattern': 'NVR Inc'},
#  {'label': 'COMPANY', 'pattern': 'PepsiCo India Holdings Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Ixoreal Biomed'},
#  {'label': 'COMPANY', 'pattern': 'Oberweis Dairy'},
#  {'label': 'COMPANY', 'pattern': 'Intel'},
#  {'label': 'COMPANY', 'pattern': 'Pall Corp'},
#  {'label': 'COMPANY', 'pattern': 'Bizoneer consulting'},
#  {'label': 'COMPANY', 'pattern': 'American Electric Power Company, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'ConvergenSEE'},
#  {'label': 'COMPANY', 'pattern': 'Vari-Tec'},
#  {'label': 'COMPANY', 'pattern': 'Standard Pacific Corp.'},
#  {'label': 'COMPANY', 'pattern': 'E.W. Scripps Company'},
#  {'label': 'COMPANY', 'pattern': 'Godrej and Boyce'},
#  {'label': 'COMPANY', 'pattern': 'Cisco Systems Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Omni Architectural Designs'},
#  {'label': 'COMPANY', 'pattern': 'Paramount Cables'},
#  {'label': 'COMPANY', 'pattern': 'Atos Origin'},
#  {'label': 'COMPANY', 'pattern': 'Berns Brett Masaood Insurance LLC'},
#  {'label': 'COMPANY', 'pattern': 'Genuity Inc.'},
#  {'label': 'COMPANY', 'pattern': 'System Star Solutions'},
#  {'label': 'COMPANY', 'pattern': 'Tinplate Compay Of India'},
#  {'label': 'COMPANY', 'pattern': 'Aumni Techworks'},
#  {'label': 'COMPANY', 'pattern': 'Mauna Loa Macadamia Nut Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Longs Drug Stores Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Impetus'},
#  {'label': 'COMPANY', 'pattern': 'ExxonMobil'},
#  {'label': 'COMPANY', 'pattern': 'Staples Inc'},
#  {'label': 'COMPANY', 'pattern': 'New World'},
#  {'label': 'COMPANY', 'pattern': 'Mirant Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Innolabz Ventures Private Limited'},
#  {'label': 'COMPANY', 'pattern': 'Corsair Memory'},
#  {'label': 'COMPANY', 'pattern': 'Ecourierz.com'},
#  {'label': 'COMPANY', 'pattern': "Wendy's International Inc"},
#  {'label': 'COMPANY', 'pattern': 'Adams Resources & Energy, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Indegene'},
#  {'label': 'COMPANY', 'pattern': 'Environ Architectural Design'},
#  {'label': 'COMPANY', 'pattern': 'Sonic Automotive Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Matrix Design'},
#  {'label': 'COMPANY', 'pattern': 'Regis Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Respironics, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Host Marriott Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Absolute Reports Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Millenia Life'},
#  {'label': 'COMPANY', 'pattern': "Peter Kiewit Sons', Inc."},
#  {'label': 'COMPANY', 'pattern': 'Bosch Brewing Company'},
#  {'label': 'COMPANY', 'pattern': 'Architectural Genie'},
#  {'label': 'COMPANY', 'pattern': 'Franchise India Brands Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Microsoft'},
#  {'label': 'COMPANY', 'pattern': 'V5 Global Staffing Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'SLM Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Cerner Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Symbol Technologies Inc'},
#  {'label': 'COMPANY', 'pattern': 'Norfolk Southern Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Procter & Gamble Co.'},
#  {'label': 'COMPANY', 'pattern': 'Imation'},
#  {'label': 'COMPANY', 'pattern': 'The Bank of New York Company, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'ISH Trader Pvt. Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Air Products and Chemicals, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Chrysler'},
#  {'label': 'COMPANY', 'pattern': 'Delphi Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Asbury Automotive Group'},
#  {'label': 'COMPANY', 'pattern': 'U.S. Steel'},
#  {'label': 'COMPANY', 'pattern': 'Sankey Solutions'},
#  {'label': 'COMPANY', 'pattern': 'Future Plan'},
#  {'label': 'COMPANY', 'pattern': 'Granite Construction Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'DivX, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'ConocoPhillips'},
#  {'label': 'COMPANY', 'pattern': 'Chubb Corp'},
#  {'label': 'COMPANY', 'pattern': 'Zycus Infotech'},
#  {'label': 'COMPANY', 'pattern': 'ACC Ltd.'},
#  {'label': 'COMPANY', 'pattern': 'Legg Mason Inc.'},
#  {'label': 'COMPANY', 'pattern': 'JM Financials'},
#  {'label': 'COMPANY', 'pattern': 'Big Lots, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'ALLETE, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Federal Mogul Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Good Times'},
#  {'label': 'COMPANY', 'pattern': 'GreenPoint Financial Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Simply Appraisals'},
#  {'label': 'COMPANY', 'pattern': 'Brookdale Senior Living'},
#  {'label': 'COMPANY', 'pattern': 'Incluesiv'},
#  {'label': 'COMPANY', 'pattern': 'Principal Financial Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Comerica Inc.'},
#  {'label': 'COMPANY', 'pattern': 'RoadwayCorp'},
#  {'label': 'COMPANY', 'pattern': 'Hoyden'},
#  {'label': 'COMPANY', 'pattern': 'Control Data Corporation (CDC)'},
#  {'label': 'COMPANY', 'pattern': 'Pentair Inc'},
#  {'label': 'COMPANY', 'pattern': 'Capital One Financial Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Bharti Airtel Services'},
#  {'label': 'COMPANY', 'pattern': "Life's Gold"},
#  {'label': 'COMPANY', 'pattern': 'Dominion Resources'},
#  {'label': 'COMPANY', 'pattern': 'American Broadcasting Company'},
#  {'label': 'COMPANY', 'pattern': 'Advansed Teksyztems'},
#  {'label': 'COMPANY', 'pattern': 'Bajaj Finance Limited'},
#  {'label': 'COMPANY', 'pattern': 'Vassarlabs IT Solutions'},
#  {'label': 'COMPANY', 'pattern': 'Accord Investments'},
#  {'label': 'COMPANY', 'pattern': 'Adolph Coors Company'},
#  {'label': 'COMPANY', 'pattern': 'Adhunik Group'},
#  {'label': 'COMPANY', 'pattern': 'Omni Tech Solutions'},
#  {'label': 'COMPANY', 'pattern': 'Dun & Bradstreet'},
#  {'label': 'COMPANY', 'pattern': 'Integra Wealth'},
#  {'label': 'COMPANY', 'pattern': 'OCZ Technology'},
#  {'label': 'COMPANY', 'pattern': 'American Home Mortgage'},
#  {'label': 'COMPANY', 'pattern': 'Vishay Intertechnology Inc'},
#  {'label': 'COMPANY', 'pattern': 'Bellwether Technology Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Makebot'},
#  {'label': 'COMPANY', 'pattern': 'Charter One Financial Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Landskip Yard Service'},
#  {'label': 'COMPANY', 'pattern': 'IDFC First Bank'},
#  {'label': 'COMPANY', 'pattern': 'Jones Apparel Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Ocean Energy Inc'},
#  {'label': 'COMPANY', 'pattern': 'Monk Home Funding Services'},
#  {'label': 'COMPANY', 'pattern': 'National Service Industries Inc'},
#  {'label': 'COMPANY', 'pattern': 'Reliance Jio'},
#  {'label': 'COMPANY', 'pattern': 'McCormick & Company Incorporated'},
#  {'label': 'COMPANY', 'pattern': 'St. Jude Medical Inc'},
#  {'label': 'COMPANY', 'pattern': 'AFPRO'},
#  {'label': 'COMPANY', 'pattern': 'Syntel'},
#  {'label': 'COMPANY', 'pattern': 'Cummins India'},
#  {'label': 'COMPANY', 'pattern': 'Allen Organ Company'},
#  {'label': 'COMPANY', 'pattern': 'Tiffany & Co'},
#  {'label': 'COMPANY', 'pattern': 'Indus Valley Partners'},
#  {'label': 'COMPANY', 'pattern': 'Agway Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Ryland Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'KFintech'},
#  {'label': 'COMPANY', 'pattern': 'Birdwell'},
#  {'label': 'COMPANY', 'pattern': 'BPCL'},
#  {'label': 'COMPANY', 'pattern': 'Marshall Pottery'},
#  {'label': 'COMPANY', 'pattern': 'Excella'},
#  {'label': 'COMPANY', 'pattern': 'Leap India Pvt Ltd'},
#  {'label': 'COMPANY', 'pattern': 'Better.Com'},
#  {'label': 'COMPANY', 'pattern': 'ICICI Securities'},
#  {'label': 'COMPANY', 'pattern': 'Indusion Consulting'},
#  {'label': 'COMPANY', 'pattern': 'U.S. Bancorp'},
#  {'label': 'COMPANY', 'pattern': 'Union Oil Company of California (Unocal)'},
#  {'label': 'COMPANY', 'pattern': 'Henry Schein Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Complete Tech'},
#  {'label': 'COMPANY', 'pattern': 'Public Service Enterprise Group Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Gas Depot'},
#  {'label': 'COMPANY', 'pattern': 'Textron Inc'},
#  {'label': 'COMPANY', 'pattern': 'Walt Disney Co'},
#  {'label': 'COMPANY', 'pattern': 'Kindred Healthcare Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Future Marketing Insight'},
#  {'label': 'COMPANY', 'pattern': "Domino's Pizza LLC"},
#  {'label': 'COMPANY', 'pattern': 'Bank of America'},
#  {'label': 'COMPANY', 'pattern': 'Practi-Plan'},
#  {'label': 'COMPANY', 'pattern': 'QX Global'},
#  {'label': 'COMPANY', 'pattern': 'Invesco'},
#  {'label': 'COMPANY', 'pattern': 'Parts and Pieces'},
#  {'label': 'COMPANY', 'pattern': 'Sunteck Realty Limited'},
#  {'label': 'COMPANY', 'pattern': 'Wheeling-Pittsburgh Steel'},
#  {'label': 'COMPANY', 'pattern': 'Toll Brothers Inc'},
#  {'label': 'COMPANY', 'pattern': 'Netcore Cloud'},
#  {'label': 'COMPANY', 'pattern': 'Progress Energy Inc'},
#  {'label': 'COMPANY', 'pattern': 'Nordstrom'},
#  {'label': 'COMPANY', 'pattern': 'Nordstrom Inc'},
#  {'label': 'COMPANY', 'pattern': 'Sonata Software'},
#  {'label': 'COMPANY', 'pattern': 'Smurfit-Stone Container Corp'},
#  {'label': 'COMPANY', 'pattern': "Seattle's Best Coffee"},
#  {'label': 'COMPANY', 'pattern': 'Safeway Inc'},
#  {'label': 'COMPANY', 'pattern': 'Asian Fusion'},
#  {'label': 'COMPANY', 'pattern': 'ITC Infotech'},
#  {'label': 'COMPANY', 'pattern': 'Rezi'},
#  {'label': 'COMPANY', 'pattern': 'The LTV Corporation'},
#  {'label': 'COMPANY', 'pattern': 'Sun Microsystems Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Dole Food Company, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Midway Games'},
#  {'label': 'COMPANY', 'pattern': 'Amgen Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Yum Brands Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Reliance Communications'},
#  {'label': 'COMPANY', 'pattern': 'Synovus Financial Corp.'},
#  {'label': 'COMPANY', 'pattern': 'Creando Associates'},
#  {'label': 'COMPANY', 'pattern': 'Bountiful Harvest Health Food Store'},
#  {'label': 'COMPANY', 'pattern': 'Vistikon'},
#  {'label': 'COMPANY', 'pattern': 'Grey Fade'},
#  {'label': 'COMPANY', 'pattern': 'Sur La Table'},
#  {'label': 'COMPANY', 'pattern': 'United Airlines'},
#  {'label': 'COMPANY', 'pattern': 'Tribune Company'},
#  {'label': 'COMPANY', 'pattern': 'Hettich'},
#  {'label': 'COMPANY', 'pattern': 'Walgreens'},
#  {'label': 'COMPANY', 'pattern': 'Mattel'},
#  {'label': 'COMPANY', 'pattern': 'International Game Technology (IGT)'},
#  {'label': 'COMPANY', 'pattern': 'Universal Corporation'},
#  {'label': 'COMPANY', 'pattern': "Applebee's"},
#  {'label': 'COMPANY', 'pattern': 'Integrated Electrical Services Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Dollar General'},
#  {'label': 'COMPANY', 'pattern': 'Nagra Vision'},
#  {'label': 'COMPANY', 'pattern': 'Coho.in'},
#  {'label': 'COMPANY', 'pattern': 'Concord EFS Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Springfield Armory, Inc.'},
#  {'label': 'COMPANY', 'pattern': 'Agilent Technologies'},
#  {'label': 'COMPANY', 'pattern': 'Nortax'},
#  ...]

# %%
generate_rules(company_patterns, 'COMPANY')

# %%
company_rules = spacy.load('COMPANY_ner')

# %%
Training_Data_Company = generate_training_data(company_rules , data['Resume_str'])

# %%
# all_in_one('Company.json',data['Resume_str'],'COMPANY')

# %%
save_data("Training_Data_Company.json",Training_Data_Company)

# %% [markdown]
# ## #Training

# %%
TRAIN_DATA_Company = load_data("Training_Data_COMPANY.json")

# %%
nlp_company = train_spacy(TRAIN_DATA_Company , 50)
# Out:
# Starting iteration 1
# {'ner': 7403.826793408808}
# Time for iteration 1: 14.96875 sec
#
# Starting iteration 2
# {'ner': 136.94826408380936}
# Time for iteration 2: 13.40625 sec
#
# Starting iteration 3
# {'ner': 108.67391396989173}
# Time for iteration 3: 13.28125 sec
#
# Starting iteration 4
# {'ner': 108.36475825126031}
# Time for iteration 4: 14.328125 sec
#
# Starting iteration 5
# {'ner': 98.63942780365065}
# Time for iteration 5: 14.125 sec
#
# Starting iteration 6
# {'ner': 87.91711913030002}
# Time for iteration 6: 13.96875 sec
#
# Starting iteration 7
# {'ner': 60.76499486642481}
# Time for iteration 7: 13.03125 sec
#
# Starting iteration 8
# {'ner': 69.2269151490821}
# Time for iteration 8: 13.96875 sec
#
# Starting iteration 9
# {'ner': 34.24185930832607}
# Time for iteration 9: 13.078125 sec
#
# Starting iteration 10
# {'ner': 377.5546529713121}
# Time for iteration 10: 13.453125 sec
#
# Starting iteration 11
# {'ner': 52.785897381514204}
# Time for iteration 11: 13.515625 sec
#
# Starting iteration 12
# {'ner': 38.58656690532691}
# Time for iteration 12: 13.734375 sec
#
# Starting iteration 13
# {'ner': 111.78138026522}
# Time for iteration 13: 13.671875 sec
#
# Starting iteration 14
# {'ner': 39.255698090198926}
# Time for iteration 14: 13.265625 sec
#
# Starting iteration 15
# {'ner': 32.3197590809212}
# Time for iteration 15: 13.609375 sec
#
# Starting iteration 16
# {'ner': 430.2923332532088}
# Time for iteration 16: 13.265625 sec
#
# Starting iteration 17
# {'ner': 37.17001779595209}
# Time for iteration 17: 14.1875 sec
#
# Starting iteration 18
# {'ner': 27.45563964007166}
# Time for iteration 18: 14.1875 sec
#
# Starting iteration 19
# {'ner': 32.84020908728747}
# Time for iteration 19: 13.1875 sec
#
# Starting iteration 20
# {'ner': 166.81905985044833}
# Time for iteration 20: 13.375 sec
#
# Starting iteration 21
# {'ner': 16.567793609154908}
# Time for iteration 21: 13.609375 sec
#
# Starting iteration 22
# {'ner': 166.74108320939123}
# Time for iteration 22: 13.328125 sec
#
# Starting iteration 23
# {'ner': 20.406037261316673}
# Time for iteration 23: 13.625 sec
#
# Starting iteration 24
# {'ner': 12.007214873765925}
# Time for iteration 24: 13.84375 sec
#
# Starting iteration 25
# {'ner': 265.7673570266679}
# Time for iteration 25: 13.859375 sec
#
# Starting iteration 26
# {'ner': 21.279182395886505}
# Time for iteration 26: 13.234375 sec
#
# Starting iteration 27
# {'ner': 43.4112179325932}
# Time for iteration 27: 14.140625 sec
#
# Starting iteration 28
# {'ner': 40.74342306753078}
# Time for iteration 28: 13.78125 sec
#
# Starting iteration 29
# {'ner': 23.85983742748329}
# Time for iteration 29: 13.59375 sec
#
# Starting iteration 30
# {'ner': 24.418513364958866}
# Time for iteration 30: 14.34375 sec
#
# Starting iteration 31
# {'ner': 24.600449344035773}
# Time for iteration 31: 13.640625 sec
#
# Starting iteration 32
# {'ner': 19.85649208440267}
# Time for iteration 32: 13.5 sec
#
# Starting iteration 33
# {'ner': 23.007187978660422}
# Time for iteration 33: 13.15625 sec
#
# Starting iteration 34
# {'ner': 39.34213014449943}
# Time for iteration 34: 14.515625 sec
#
# Starting iteration 35
# {'ner': 17.41948756485467}
# Time for iteration 35: 13.546875 sec
#
# Starting iteration 36
# {'ner': 8.502326132363892}
# Time for iteration 36: 13.609375 sec
#
# Starting iteration 37
# {'ner': 25.598189868888547}
# Time for iteration 37: 13.078125 sec
#
# Starting iteration 38
# {'ner': 17.636454467061014}
# Time for iteration 38: 13.296875 sec
#
# Starting iteration 39
# {'ner': 9.11692812877399}
# Time for iteration 39: 13.28125 sec
#
# Starting iteration 40
# {'ner': 32.96933860843494}
# Time for iteration 40: 13.171875 sec
#
# Starting iteration 41
# {'ner': 23.595448940556842}
# Time for iteration 41: 13.953125 sec
#
# Starting iteration 42
# {'ner': 10.991769330487418}
# Time for iteration 42: 13.625 sec
#
# Starting iteration 43
# {'ner': 15.657281145861111}
# Time for iteration 43: 13.515625 sec
#
# Starting iteration 44
# {'ner': 18.37759651504098}
# Time for iteration 44: 13.625 sec
#
# Starting iteration 45
# {'ner': 12.363842257450548}
# Time for iteration 45: 13.75 sec
#
# Starting iteration 46
# {'ner': 170.6788517140727}
# Time for iteration 46: 13.890625 sec
#
# Starting iteration 47
# {'ner': 9.058472944652703}
# Time for iteration 47: 13.75 sec
#
# Starting iteration 48
# {'ner': 8.324820128361738}
# Time for iteration 48: 13.46875 sec
#
# Starting iteration 49
# {'ner': 60.965115012705255}
# Time for iteration 49: 13.578125 sec
#
# Starting iteration 50
# {'ner': 13.808073394230453}
# Time for iteration 50: 13.421875 sec
#
# Total Time 682.515625 sec

# %%
nlp_company.to_disk('Company_model')

# %% [markdown]
# ## #Testing

# %%
for text in df['Resume_str'].iloc[750:800]:

    for ent in nlp_company(text).ents:
         
        print(ent.text, ent.label_)
# Out:
# Infor COMPANY
# Infor COMPANY
# Total Quality COMPANY
# ... COMPANY
# Deloitte COMPANY
# Deloitte COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# FactSet COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Google COMPANY
# Google COMPANY
# Microsoft COMPANY
# Citrix COMPANY
# Twitter COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Best Buy COMPANY
# Amazon COMPANY
# Citrix COMPANY
# Citrix COMPANY
# Microsoft COMPANY
# Google COMPANY
# LinkedIn COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Gap COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Google COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Citrix COMPANY
# VLookup COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Microsoft COMPANY

# %% [markdown]
# ## 2.Creating Job model

# %%
all_in_one('Jobs.json',data['Resume_str'],'JOBS')
# Out:
# copy the code to load the training data :
#  TRAIN_DATA_JOBS = load_data("Training_Data_JOBS.json")

# %% [markdown]
# ## #Training

# %%
TRAIN_DATA_JOB = load_data("Training_Data_JOBS.json")

# %%
nlp_job = train_spacy(TRAIN_DATA_JOB , 30)
# Out:
# Starting iteration 1
# {'ner': 4529.982361423046}
# Time for iteration 1: 20.90625 sec
#
# Starting iteration 2
# {'ner': 428.1034681043575}
# Time for iteration 2: 20.4375 sec
#
# Starting iteration 3
# {'ner': 298.4955564291333}
# Time for iteration 3: 19.6875 sec
#
# Starting iteration 4
# {'ner': 256.61046730290457}
# Time for iteration 4: 19.875 sec
#
# Starting iteration 5
# {'ner': 222.30583960599864}
# Time for iteration 5: 19.59375 sec
#
# Starting iteration 6
# {'ner': 156.60888734678366}
# Time for iteration 6: 20.0625 sec
#
# Starting iteration 7
# {'ner': 133.72382892135386}
# Time for iteration 7: 20.203125 sec
#
# Starting iteration 8
# {'ner': 182.1530448441432}
# Time for iteration 8: 19.59375 sec
#
# Starting iteration 9
# {'ner': 140.0385483820626}
# Time for iteration 9: 19.65625 sec
#
# Starting iteration 10
# {'ner': 127.99565015565321}
# Time for iteration 10: 20.0 sec
#
# Starting iteration 11
# {'ner': 89.9441712210246}
# Time for iteration 11: 19.5 sec
#
# Starting iteration 12
# {'ner': 81.72932763982838}
# Time for iteration 12: 20.09375 sec
#
# Starting iteration 13
# {'ner': 103.04921243700306}
# Time for iteration 13: 19.953125 sec
#
# Starting iteration 14
# {'ner': 135.8879492134018}
# Time for iteration 14: 19.4375 sec
#
# Starting iteration 15
# {'ner': 128.68973679768627}
# Time for iteration 15: 19.953125 sec
#
# Starting iteration 16
# {'ner': 105.29962307873396}
# Time for iteration 16: 20.078125 sec
#
# Starting iteration 17
# {'ner': 97.68559303298501}
# Time for iteration 17: 20.171875 sec
#
# Starting iteration 18
# {'ner': 102.36541873664719}
# Time for iteration 18: 21.109375 sec
#
# Starting iteration 19
# {'ner': 77.00331696898557}
# Time for iteration 19: 19.078125 sec
#
# Starting iteration 20
# {'ner': 78.72733920142834}
# Time for iteration 20: 20.453125 sec
#
# Starting iteration 21
# {'ner': 82.9831774074112}
# Time for iteration 21: 19.890625 sec
#
# Starting iteration 22
# {'ner': 65.96379197609583}
# Time for iteration 22: 20.15625 sec
#
# Starting iteration 23
# {'ner': 55.47405903911586}
# Time for iteration 23: 19.4375 sec
#
# Starting iteration 24
# {'ner': 82.6341120118056}
# Time for iteration 24: 20.625 sec
#
# Starting iteration 25
# {'ner': 79.85473834230828}
# Time for iteration 25: 20.046875 sec
#
# Starting iteration 26
# {'ner': 74.59118332338413}
# Time for iteration 26: 19.546875 sec
#
# Starting iteration 27
# {'ner': 55.553323813535926}
# Time for iteration 27: 19.28125 sec
#
# Starting iteration 28
# {'ner': 94.4277141410594}
# Time for iteration 28: 21.046875 sec
#
# Starting iteration 29
# {'ner': 60.04004468742555}
# Time for iteration 29: 20.15625 sec
#
# Starting iteration 30
# {'ner': 48.877244593498055}
# Time for iteration 30: 19.03125 sec
#
# Total Time 599.265625 sec

# %%
nlp_job.to_disk('Jobs_model')

# %% [markdown]
# ## #Testing

# %%
for text in df['Resume_str'].iloc[750:800]:

    for ent in nlp_job(text).ents:
         
        print(ent.text, ent.label_)
# Out:
# Manager JOBS
# Teller JOBS
# Agent JOBS
# Manager JOBS
# Manager JOBS
# Auditor JOBS
# Hostess JOBS
# Cashier JOBS
# Designer JOBS
# Manager JOBS
# Director JOBS
# Director JOBS
# Designer JOBS
# Designer JOBS
# Designer JOBS
# Graphic Designer JOBS
# Customer Service Representative JOBS
# Clerk JOBS
# Manager JOBS
# Professor JOBS
# Paralegal JOBS
# Manager JOBS
# Director JOBS
# Manager JOBS
# Manager JOBS
# Director JOBS
# Professor JOBS
# Manager JOBS
# Physician JOBS
# Director JOBS
# Director JOBS
# Manager JOBS
# Manager JOBS
# Manager JOBS
# Sales Manager JOBS
# Manager JOBS
# Manager JOBS
# Educational JOBS
# Manager JOBS
# Accountant JOBS
# Accountant JOBS
# Director JOBS
# Director JOBS
# Manager JOBS
# Accountant JOBS
# Accountant JOBS
# Director JOBS
# Compensation JOBS
# Adjuster JOBS
# Counselor JOBS
# Property JOBS
# Agent JOBS
# Counselor JOBS
# Physician JOBS
# Manager JOBS
# Specialist JOBS
# Director JOBS
# Director JOBS
# Director JOBS
# Manager JOBS
# Clinical JOBS
# Clinical JOBS
# Manager JOBS
# Director JOBS
# Director JOBS
# Construction Manager JOBS
# Engineer JOBS
# Director JOBS
# Doctor JOBS
# Manager JOBS
# Manager JOBS
# Manager JOBS
# Designer JOBS
# Designer JOBS
# Horticulturalist JOBS
# Manager JOBS
# Designer JOBS
# Designer JOBS
# Manager JOBS
# Technician JOBS
# Designer JOBS
# Manager JOBS
# Designer JOBS
# Designer JOBS
# Designer JOBS
# Customer Service Representative JOBS
# Manager JOBS
# Medical Assistant JOBS
# Clinical JOBS
# Teacher JOBS
# Medical Assistant JOBS
# Doctor JOBS
# Medical Assistant JOBS
# Clinical JOBS
# Medical Assistant JOBS
# Specialist JOBS
# Property JOBS
# Property JOBS
# Manager JOBS
# Manager JOBS
# Manager JOBS
# Director JOBS
# Secretary JOBS
# Manager JOBS
# Manager JOBS
# Baker JOBS
# Manager JOBS
# Manager JOBS
# Director JOBS
# Administrative Assistant JOBS
# Manager JOBS
# Manager JOBS
# Director JOBS
# Administrative Assistant JOBS
# Manager JOBS
# Director JOBS
# Cashier JOBS
# Specialist JOBS
# Specialist JOBS
# Specialist JOBS
# Administrative Assistant JOBS
# Instructor JOBS
# Technician JOBS
# Technician JOBS
# Manager JOBS
# Host JOBS
# Designer JOBS
# Equipment JOBS
# Designer JOBS
# Director JOBS
# Engineer JOBS
# Engineer JOBS
# Eurotech JOBS
# Specialist JOBS
# Director JOBS
# Engineer JOBS
# Manager JOBS
# Engineer JOBS
# Manager JOBS
# Engineer JOBS
# Director JOBS
# Engineer JOBS
# Engineer JOBS
# Director JOBS
# Sales Manager JOBS
# Sales Manager JOBS
# Director JOBS
# Educational JOBS
# Educational JOBS
# Educational JOBS
# Director JOBS
# Director JOBS
# Director JOBS
# Accountant JOBS
# Accountant JOBS
# Accountant JOBS
# Manager JOBS
# Equipment JOBS
# Auditor JOBS
# Manager JOBS
# Child JOBS
# Teller JOBS
# Teller JOBS
# Receptionist JOBS
# Manager JOBS
# Manager JOBS
# Chef JOBS
# Chef JOBS
# Chef JOBS
# Cook JOBS
# Chef JOBS
# Manager JOBS
# Specialist JOBS
# Instructor JOBS
# Fitness Trainer JOBS
# Manager JOBS
# Sales Manager JOBS
# Director JOBS
# Equipment JOBS
# Equipment JOBS
# Equipment JOBS
# Equipment JOBS
# Equipment JOBS
# Indicator JOBS
# Designer JOBS
# Designer JOBS
# Educational JOBS
# Director JOBS
# Manager JOBS
# Director JOBS
# Director JOBS
# Designer JOBS
# Educational JOBS
# Manager JOBS
# Teacher JOBS
# Educational JOBS
# Manager JOBS
# Teacher JOBS
# Director JOBS
# Accountant JOBS
# Accountant JOBS
# Educational JOBS
# Accountant JOBS
# Compensation JOBS
# Manager JOBS
# Mechanic JOBS
# Aircraft Technician JOBS
# Technician JOBS
# Financial Analyst JOBS
# Manager JOBS
# Director JOBS
# Compensation JOBS
# Compensation JOBS
# Manager JOBS
# Manager JOBS
# Manager JOBS
# Manager JOBS
# Engineer JOBS
# Engineer JOBS
# Designer JOBS
# Graphic Designer JOBS
# Editor JOBS
# Proofreader JOBS
# Specialist JOBS
# Producer JOBS
# Producer JOBS
# Producer JOBS
# Director JOBS
# Director JOBS
# Director JOBS
# Director JOBS
# Director JOBS
# Manager JOBS
# Editor JOBS
# Reporter JOBS
# Diplomacy JOBS

# %% [markdown]
# ## 3.Creating Education model

# %%
all_in_one('Education.json',data['Resume_str'],'EDUCATION')
# Out:
# copy the code to load the training data :
#  TRAIN_DATA_EDUCATION = load_data("Training_Data_EDUCATION.json")

# %% [markdown]
# ## #Training

# %%
TRAIN_DATA_EDUCATION = load_data("Training_Data_EDUCATION.json")

# %%
nlp_education = train_spacy(TRAIN_DATA_EDUCATION , 30)
# Out:
# Starting iteration 1
# {'ner': 5744.359347480603}
# Time for iteration 1: 9.25 sec
#
# Starting iteration 2
# {'ner': 251.76508041171246}
# Time for iteration 2: 8.84375 sec
#
# Starting iteration 3
# {'ner': 48.084731241128466}
# Time for iteration 3: 8.375 sec
#
# Starting iteration 4
# {'ner': 41.86431409665979}
# Time for iteration 4: 8.546875 sec
#
# Starting iteration 5
# {'ner': 20.446692312522597}
# Time for iteration 5: 8.515625 sec
#
# Starting iteration 6
# {'ner': 20.907547699762816}
# Time for iteration 6: 8.734375 sec
#
# Starting iteration 7
# {'ner': 22.954360278071373}
# Time for iteration 7: 8.375 sec
#
# Starting iteration 8
# {'ner': 18.880495986052413}
# Time for iteration 8: 8.5 sec
#
# Starting iteration 9
# {'ner': 12.155890301682021}
# Time for iteration 9: 7.953125 sec
#
# Starting iteration 10
# {'ner': 14.263146145917572}
# Time for iteration 10: 8.15625 sec
#
# Starting iteration 11
# {'ner': 11.728171947591989}
# Time for iteration 11: 8.265625 sec
#
# Starting iteration 12
# {'ner': 12.556757428908519}
# Time for iteration 12: 9.203125 sec
#
# Starting iteration 13
# {'ner': 6.638725921115684}
# Time for iteration 13: 8.609375 sec
#
# Starting iteration 14
# {'ner': 3.8389948544625443}
# Time for iteration 14: 8.46875 sec
#
# Starting iteration 15
# {'ner': 6.443179712269293}
# Time for iteration 15: 8.4375 sec
#
# Starting iteration 16
# {'ner': 2.0589730019869035}
# Time for iteration 16: 8.65625 sec
#
# Starting iteration 17
# {'ner': 5.434237758885352}
# Time for iteration 17: 8.90625 sec
#
# Starting iteration 18
# {'ner': 7.941769032911609}
# Time for iteration 18: 9.265625 sec
#
# Starting iteration 19
# {'ner': 2.6317644701587355}
# Time for iteration 19: 8.515625 sec
#
# Starting iteration 20
# {'ner': 2.5802026078520038e-05}
# Time for iteration 20: 9.109375 sec
#
# Starting iteration 21
# {'ner': 0.0003160562775512994}
# Time for iteration 21: 8.6875 sec
#
# Starting iteration 22
# {'ner': 1.755797519528695}
# Time for iteration 22: 9.0625 sec
#
# Starting iteration 23
# {'ner': 6.340608512561848}
# Time for iteration 23: 8.375 sec
#
# Starting iteration 24
# {'ner': 0.019584998850313402}
# Time for iteration 24: 9.46875 sec
#
# Starting iteration 25
# {'ner': 2.2881625334314637}
# Time for iteration 25: 9.15625 sec
#
# Starting iteration 26
# {'ner': 3.172109174726361}
# Time for iteration 26: 9.3125 sec
#
# Starting iteration 27
# {'ner': 5.996183205356219}
# Time for iteration 27: 9.109375 sec
#
# Starting iteration 28
# {'ner': 3.7416649604477805}
# Time for iteration 28: 8.40625 sec
#
# Starting iteration 29
# {'ner': 7.609118822519768}
# Time for iteration 29: 9.203125 sec
#
# Starting iteration 30
# {'ner': 3.916059651411903}
# Time for iteration 30: 8.546875 sec
#
# Total Time 262.203125 sec

# %%
nlp_education.to_disk('Education_model')

# %% [markdown]
# ## #Testing

# %%
for text in df['Resume_str'].iloc[750:800]:

    for ent in nlp_education(text).ents:
         
        print(ent.text, ent.label_)
# Out:
# Diploma EDUCATION
# Diploma EDUCATION
# Master of Science EDUCATION
# Master of Science EDUCATION
# Master's degree EDUCATION
# Diploma EDUCATION
# Diploma EDUCATION
# Bachelor of Professional EDUCATION
# Bachelor's degree EDUCATION
# Bachelor's degree EDUCATION
# Diploma EDUCATION
# Diploma EDUCATION
# Master of Science EDUCATION
# Diploma EDUCATION
# Bachelor of Dental EDUCATION
# Master of Science EDUCATION
# Master's Degree EDUCATION
# Master of Science EDUCATION
# Diploma EDUCATION
# Diploma EDUCATION
# Diploma EDUCATION
# Master of Science EDUCATION
# Bachelor  of EDUCATION
# Diploma EDUCATION
# Diploma EDUCATION
# Master of Technology EDUCATION
# Master of Chiropractic EDUCATION

# %% [markdown]
# ## 4.Creating Skill model

# %%
def load_jsonl(file):
    with open(file , 'r', encoding = 'utf-8') as f:
        data = [json.loads(line) for line in f]
    return data
skill_patterns = load_jsonl("jz_skill_patterns.jsonl")

# %%
generate_rules(skill_patterns, 'SKILL')

# %%
skill_rules = spacy.load('SKILL_ner')

# %%
Training_Data_Skill = generate_training_data(skill_rules , data['Resume_str'])

# %%
save_data("Training_Data_Skill.json",Training_Data_Skill)

# %% [markdown]
# ## #Training

# %%
TRAIN_DATA_SKILL = load_data("Training_Data_Skill.json")

# %%
nlp_skill = train_spacy(TRAIN_DATA_SKILL , 30)
# Out:
# Starting iteration 1
# {'ner': 6408.335494675233}
# Time for iteration 1: 21.46875 sec
#
# Starting iteration 2
# {'ner': 846.4045612367999}
# Time for iteration 2: 20.765625 sec
#
# Starting iteration 3
# {'ner': 540.6862681862888}
# Time for iteration 3: 20.046875 sec
#
# Starting iteration 4
# {'ner': 655.778152417762}
# Time for iteration 4: 21.21875 sec
#
# Starting iteration 5
# {'ner': 475.99520087548495}
# Time for iteration 5: 20.828125 sec
#
# Starting iteration 6
# {'ner': 564.2282106241917}
# Time for iteration 6: 21.546875 sec
#
# Starting iteration 7
# {'ner': 509.8512804234038}
# Time for iteration 7: 21.75 sec
#
# Starting iteration 8
# {'ner': 419.5681777034657}
# Time for iteration 8: 20.46875 sec
#
# Starting iteration 9
# {'ner': 324.69948997156706}
# Time for iteration 9: 21.21875 sec
#
# Starting iteration 10
# {'ner': 305.94626629902194}
# Time for iteration 10: 20.71875 sec
#
# Starting iteration 11
# {'ner': 338.48816361351834}
# Time for iteration 11: 21.578125 sec
#
# Starting iteration 12
# {'ner': 289.51283205946083}
# Time for iteration 12: 20.609375 sec
#
# Starting iteration 13
# {'ner': 308.0879350334808}
# Time for iteration 13: 20.59375 sec
#
# Starting iteration 14
# {'ner': 243.70108608640308}
# Time for iteration 14: 20.921875 sec
#
# Starting iteration 15
# {'ner': 230.53995069626436}
# Time for iteration 15: 20.46875 sec
#
# Starting iteration 16
# {'ner': 192.82138423919582}
# Time for iteration 16: 21.375 sec
#
# Starting iteration 17
# {'ner': 279.9627112029152}
# Time for iteration 17: 21.625 sec
#
# Starting iteration 18
# {'ner': 176.64505596882958}
# Time for iteration 18: 21.078125 sec
#
# Starting iteration 19
# {'ner': 265.6001528746832}
# Time for iteration 19: 20.65625 sec
#
# Starting iteration 20
# {'ner': 205.5547122120051}
# Time for iteration 20: 20.328125 sec
#
# Starting iteration 21
# {'ner': 223.11249077509362}
# Time for iteration 21: 20.671875 sec
#
# Starting iteration 22
# {'ner': 179.2677478161575}
# Time for iteration 22: 20.75 sec
#
# Starting iteration 23
# {'ner': 206.54881323462027}
# Time for iteration 23: 20.171875 sec
#
# Starting iteration 24
# {'ner': 150.26300785870583}
# Time for iteration 24: 21.34375 sec
#
# Starting iteration 25
# {'ner': 221.8917907758993}
# Time for iteration 25: 23.0 sec
#
# Starting iteration 26
# {'ner': 177.67597710622317}
# Time for iteration 26: 21.296875 sec
#
# Starting iteration 27
# {'ner': 122.03414830080251}
# Time for iteration 27: 20.546875 sec
#
# Starting iteration 28
# {'ner': 191.3303155653586}
# Time for iteration 28: 21.046875 sec
#
# Starting iteration 29
# {'ner': 158.95815837225817}
# Time for iteration 29: 21.0625 sec
#
# Starting iteration 30
# {'ner': 118.26316291886526}
# Time for iteration 30: 21.28125 sec
#
# Total Time 630.65625 sec

# %%
nlp_skill.to_disk('Skill_model')

# %% [markdown]
# ## #Testing

# %%
for text in df['Resume_str'].iloc[750:800]:

    for ent in nlp_skill(text).ents:
         
        print(ent.text, ent.label_)
# Out:
# engineering SKILL
# marketing SKILL
# C SKILL
# multimedia SKILL
# Engineering SKILL
# Business Administration SKILL
# Design SKILL
# Business Administration SKILL
# Business Administration SKILL
# finance SKILL
# finance SKILL
# Vault SKILL
# Software SKILL
# security SKILL
# vault SKILL
# payments SKILL
# Accounting SKILL
# finance SKILL
# marketing SKILL
# Operations management SKILL
# Documentation SKILL
# marketing SKILL
# Server SKILL
# server SKILL
# schedule SKILL
# DESIGN SKILL
# Design SKILL
# marketing SKILL
# Spring SKILL
# design SKILL
# Design SKILL
# marketing SKILL
# Project management SKILL
# Design SKILL
# Design SKILL
# spring SKILL
# support SKILL
# schedule SKILL
# material SKILL
# release SKILL
# design SKILL
# schedule SKILL
# schedule SKILL
# schedule SKILL
# support SKILL
# Certificate SKILL
# Certificate SKILL
# BUSINESS SKILL
# Business SKILL
# testing SKILL
# Business SKILL
# Project management SKILL
# Business process SKILL
# testing SKILL
# Business SKILL
# Project Management SKILL
# Business SKILL
# System Analysis SKILL
# business intelligence SKILL
# Oracle SKILL
# security SKILL
# Business SKILL
# database SKILL
# business SKILL
# business SKILL
# marketing SKILL
# Customer Relationship Management SKILL
# CRM SKILL
# business SKILL
# Oracle SKILL
# software SKILL
# business SKILL
# forums SKILL
# business SKILL
# business SKILL
# marketing SKILL
# business SKILL
# knowledge sharing SKILL
# Business SKILL
# business SKILL
# business SKILL
# finance SKILL
# accounting SKILL
# business SKILL
# marketing SKILL
# business SKILL
# Business SKILL
# business SKILL
# business SKILL
# marketing SKILL
# business SKILL
# C SKILL
# business SKILL
# business SKILL
# business SKILL
# marketing SKILL
# marketing SKILL
# Business SKILL
# Certificate SKILL
# Business SKILL
# Accounting SKILL
# Business Administration SKILL
# Business SKILL
# Business SKILL
# Business SKILL
# Business SKILL
# Customer Relationship Management SKILL
# Database SKILL
# Marketing SKILL
# Finance SKILL
# Marketing SKILL
# payments SKILL
# business SKILL
# business SKILL
# accounting SKILL
# accounting SKILL
# Business SKILL
# business SKILL
# accounting SKILL
# Business SKILL
# business SKILL
# marketing SKILL
# accounting SKILL
# Business SKILL
# Business SKILL
# Business SKILL
# Business SKILL
# business SKILL
# marketing SKILL
# OPERATIONS MANAGEMENT SKILL
# BUSINESS SKILL
# R SKILL
# payments SKILL
# schedule SKILL
# Operations Management SKILL
# Business Administration SKILL
# marketing SKILL
# accounting SKILL
# accounting SKILL
# Business Administration SKILL
# marketing SKILL
# Operations Management SKILL
# FINANCE SKILL
# monitoring SKILL
# finance SKILL
# Finance SKILL
# Oracle SKILL
# Business SKILL
# Finance SKILL
# business SKILL
# accounting SKILL
# finance SKILL
# Monitoring SKILL
# marketing SKILL
# sorting SKILL
# business SKILL
# advertising SKILL
# documentation SKILL
# Material SKILL
# Business SKILL
# finance SKILL
# accounting SKILL
# documentation SKILL
# accounting SKILL
# Oracle SKILL
# business SKILL
# Finance SKILL
# accounting SKILL
# Finance SKILL
# business SKILL
# payments SKILL
# schedule SKILL
# schedule SKILL
# payments SKILL
# payments SKILL
# Accounting SKILL
# accounting SKILL
# C SKILL
# Finance SKILL
# Finance SKILL
# Accounting SKILL
# advertising SKILL
# C SKILL
# finance SKILL
# documentation SKILL
# Finance SKILL
# accounting SKILL
# accounting SKILL
# marketing SKILL
# Oracle SKILL
# FINANCE SKILL
# accounting SKILL
# Oracle SKILL
# Finance SKILL
# Finance SKILL
# Finance SKILL
# Finance SKILL
# testing SKILL
# support SKILL
# Segment SKILL
# Business SKILL
# Accounting SKILL
# Support SKILL
# Accounting SKILL
# Oracle SKILL
# Project Management SKILL
# business administration SKILL
# Project Management SKILL
# Business SKILL
# Business SKILL
# workflow SKILL
# business SKILL
# security SKILL
# business SKILL
# documentation SKILL
# accounting SKILL
# business SKILL
# business SKILL
# workflow SKILL
# business SKILL
# business SKILL
# business SKILL
# business SKILL
# Project Management SKILL
# Project Management SKILL
# accounting SKILL
# Business SKILL
# business SKILL
# business SKILL
# documentation SKILL
# Project Management SKILL
# workflow SKILL
# C SKILL
# Project Management SKILL
# operations management SKILL
# design SKILL
# workflow SKILL
# design SKILL
# business SKILL
# Project Management SKILL
# project management SKILL
# business SKILL
# business SKILL
# business SKILL
# schedule SKILL
# design SKILL
# engineering SKILL
# business SKILL
# Civil Engineering SKILL
# Civil Engineering SKILL
# Finance SKILL
# Analytics SKILL
# Communications SKILL
# C SKILL
# design SKILL
# Finance SKILL
# Project Management SKILL
# testing SKILL
# support SKILL
# support SKILL
# support SKILL
# business SKILL
# documentation SKILL
# documentation SKILL
# database SKILL
# Business SKILL
# Business SKILL
# database SKILL
# documentation SKILL
# business SKILL
# design SKILL
# project management SKILL
# design SKILL
# interaction SKILL
# design SKILL
# design SKILL
# design SKILL
# documentation SKILL
# design SKILL
# testing SKILL
# design SKILL
# Design SKILL
# design SKILL
# engineering SKILL
# design SKILL
# design SKILL
# engineering SKILL
# schedule SKILL
# Design SKILL
# Design SKILL
# documentation SKILL
# design SKILL
# Business SKILL
# Security SKILL
# Project Management SKILL
# Data Center SKILL
# Operating Systems SKILL
# Windows SKILL
# Server SKILL
# Server SKILL
# Data Center SKILL
# Server SKILL
# API SKILL
# back office SKILL
# business SKILL
# support SKILL
# data center SKILL
# data center SKILL
# telecommunications SKILL
# support SKILL
# terminal SKILL
# support SKILL
# support SKILL
# support SKILL
# telecommunications SKILL
# software SKILL
# business SKILL
# design SKILL
# web security SKILL
# business SKILL
# Support SKILL
# software SKILL
# operating system SKILL
# email system SKILL
# server SKILL
# software SKILL
# Computer Science SKILL
# Computer Science SKILL
# API SKILL
# business SKILL
# Business SKILL
# support SKILL
# design SKILL
# Server SKILL
# Windows SKILL
# network hardware SKILL
# Operating Systems SKILL
# operating system SKILL
# Project Management SKILL
# telecommunications SKILL
# Design SKILL
# Design SKILL
# Certificate SKILL
# Design SKILL
# Certificate SKILL
# Spring SKILL
# Spring SKILL
# Spring SKILL
# MARKETING SKILL
# Marketing SKILL
# WordPress SKILL
# Google Analytics SKILL
# Adobe Photoshop SKILL
# Marketing SKILL
# marketing SKILL
# marketing SKILL
# payments SKILL
# Communications SKILL
# Communications SKILL
# Communications SKILL
# Communications SKILL
# Adobe Photoshop SKILL
# Google Analytics SKILL
# marketing SKILL
# Marketing SKILL
# Project management SKILL
# first mobile SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# collaboration SKILL
# business SKILL
# business SKILL
# marketing SKILL
# marketing SKILL
# Project management SKILL
# support SKILL
# operating systems SKILL
# software SKILL
# payments SKILL
# software SKILL
# software SKILL
# Support SKILL
# Data Center SKILL
# Support SKILL
# Business SKILL
# Communications SKILL
# Project Management SKILL
# Operating Systems SKILL
# Database SKILL
# Software Engineering SKILL
# Project Management SKILL
# Project Management SKILL
# accounting SKILL
# Business SKILL
# Communications SKILL
# business SKILL
# support SKILL
# Database SKILL
# Operating Systems SKILL
# Project Management SKILL
# Software Engineering SKILL
# SQL SKILL
# Support SKILL
# business SKILL
# support SKILL
# communications SKILL
# business SKILL
# SQL SKILL
# Database SKILL
# business SKILL
# INVISION SKILL
# accounting SKILL
# accounting SKILL
# database SKILL
# software SKILL
# business SKILL
# MARKETING AUTOMATION SKILL
# marketing SKILL
# business SKILL
# marketing SKILL
# business SKILL
# marketing SKILL
# Database SKILL
# collaboration SKILL
# Marketing Automation SKILL
# marketing SKILL
# marketing SKILL
# support SKILL
# marketing SKILL
# business SKILL
# marketing SKILL
# Oracle SKILL
# Twitter SKILL
# support SKILL
# business SKILL
# testing SKILL
# Design SKILL
# API SKILL
# documentation SKILL
# marketing SKILL
# segmentation SKILL
# testing SKILL
# marketing SKILL
# Marketing SKILL
# Marketing Automation SKILL
# Marketing SKILL
# design SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# Testing SKILL
# segmentation SKILL
# Support SKILL
# marketing SKILL
# analytics SKILL
# monitoring SKILL
# Database SKILL
# marketing SKILL
# Marketing SKILL
# Marketing SKILL
# communications SKILL
# project management SKILL
# Support SKILL
# accounting SKILL
# Marketing SKILL
# Marketing SKILL
# Oracle SKILL
# Marketing SKILL
# Oracle SKILL
# Marketing Automation SKILL
# Marketing SKILL
# Marketing SKILL
# ranking SKILL
# marketing SKILL
# system integration SKILL
# business process SKILL
# database SKILL
# Finance SKILL
# documentation SKILL
# documentation SKILL
# databases SKILL
# database SKILL
# documentation SKILL
# Support SKILL
# Schedule SKILL
# Help Desk SKILL
# Compose SKILL
# software SKILL
# relay SKILL
# Design SKILL
# marketing SKILL
# software SKILL
# software SKILL
# Business SKILL
# Business SKILL
# Accounting SKILL
# Accounting SKILL
# Support SKILL
# databases SKILL
# documentation SKILL
# Finance SKILL
# Help Desk SKILL
# marketing SKILL
# database SKILL
# communications SKILL
# marketing SKILL
# Project management SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# advertising SKILL
# marketing SKILL
# advertising SKILL
# database SKILL
# Project management SKILL
# database SKILL
# advertising SKILL
# business SKILL
# Business SKILL
# Business SKILL
# advertising SKILL
# project management SKILL
# marketing SKILL
# communications SKILL
# Software SKILL
# Publishing SKILL
# Software SKILL
# Accounting SKILL
# Schedule SKILL
# marketing SKILL
# communications SKILL
# accounting SKILL
# support SKILL
# LANGUAGES SKILL
# marketing SKILL
# marketing SKILL
# Mobile SKILL
# Mobile SKILL
# Documentation SKILL
# Mobile SKILL
# Mobile SKILL
# Mobile SKILL
# C SKILL
# Languages SKILL
# data management SKILL
# documentation SKILL
# support SKILL
# support SKILL
# database SKILL
# security SKILL
# communications SKILL
# design SKILL
# database SKILL
# support SKILL
# workload SKILL
# accounting SKILL
# data processing SKILL
# gums SKILL
# business SKILL
# accounting SKILL
# data processing SKILL
# database SKILL
# database SKILL
# operating system SKILL
# support SKILL
# Windows SKILL
# software SKILL
# computer network SKILL
# database SKILL
# Software SKILL
# database SKILL
# Windows SKILL
# BUSINESS SKILL
# BUSINESS SKILL
# Business SKILL
# Business SKILL
# business SKILL
# Business SKILL
# BUSINESS SKILL
# business SKILL
# marketing SKILL
# email marketing SKILL
# software SKILL
# business SKILL
# business SKILL
# marketing SKILL
# marketing SKILL
# design SKILL
# graphic design SKILL
# Business SKILL
# Marketing SKILL
# Advertising SKILL
# Advertising SKILL
# Business SKILL
# Marketing SKILL
# business SKILL
# Customer Relationship Management SKILL
# graphic design SKILL
# Marketing SKILL
# marketing SKILL
# Marketing SKILL
# Business SKILL
# INTERACTION SKILL
# design SKILL
# design SKILL
# design SKILL
# interaction SKILL
# Interaction SKILL
# Design SKILL
# engineering SKILL
# User interface SKILL
# design SKILL
# testing SKILL
# design SKILL
# Interaction SKILL
# design SKILL
# Design SKILL
# Software SKILL
# Software SKILL
# testing SKILL
# HTML SKILL
# 3D SKILL
# 3D SKILL
# SQL SKILL
# CDC/ SKILL
# design SKILL
# Project management SKILL
# Design SKILL
# Interaction SKILL
# Design SKILL
# Reality SKILL
# Interaction SKILL
# interaction SKILL
# software SKILL
# software SKILL
# testing SKILL
# interface analysis SKILL
# software SKILL
# Engineering SKILL
# Engineering SKILL
# reality SKILL
# software SKILL
# software SKILL
# support SKILL
# design SKILL
# design SKILL
# multimedia SKILL
# C SKILL
# testing SKILL
# testing SKILL
# business SKILL
# software SKILL
# Design SKILL
# marketing SKILL
# engineering SKILL
# engineering SKILL
# engineering SKILL
# design SKILL
# design SKILL
# workflow SKILL
# design SKILL
# testing SKILL
# software SKILL
# visualization SKILL
# software SKILL
# database SKILL
# security SKILL
# software SKILL
# design SKILL
# workflow SKILL
# software SKILL
# visualization SKILL
# design SKILL
# design SKILL
# workflow SKILL
# data analysis SKILL
# 3D SKILL
# visualization SKILL
# software SKILL
# design SKILL
# workflow SKILL
# 3D SKILL
# software SKILL
# design SKILL
# interaction SKILL
# user Interface SKILL
# design SKILL
# design SKILL
# database SKILL
# design SKILL
# data integrity SKILL
# software SKILL
# software SKILL
# Windows SKILL
# design SKILL
# design SKILL
# database SKILL
# testing SKILL
# marketing SKILL
# database SKILL
# 3D SKILL
# 3D SKILL
# 3D SKILL
# design SKILL
# Design SKILL
# 3D SKILL
# data integrity SKILL
# Software SKILL
# graphical user interface SKILL
# box SKILL
# design SKILL
# design SKILL
# engineering SKILL
# testing SKILL
# engineering SKILL
# marketing SKILL
# 3D SKILL
# 3D SKILL
# Engineering SKILL
# Engineering SKILL
# forums SKILL
# business SKILL
# business SKILL
# schedule SKILL
# Business SKILL
# ACCOUNTING SKILL
# BUSINESS SKILL
# ACCOUNTING SKILL
# ACCOUNTING SKILL
# BUSINESS SKILL
# Accounting SKILL
# Oracle SKILL
# Crystal SKILL
# R SKILL
# accounting SKILL
# accounting SKILL
# business SKILL
# accounting SKILL
# documentation SKILL
# Accounting SKILL
# accounting SKILL
# accounting SKILL
# accounting SKILL
# documentation SKILL
# Data Management SKILL
# accounting SKILL
# support SKILL
# accounting SKILL
# accounting SKILL
# Rotation SKILL
# accounting SKILL
# communications SKILL
# accounting SKILL
# business SKILL
# business SKILL
# Marathon SKILL
# Languages SKILL
# accounting SKILL
# Crystal SKILL
# Data Management SKILL
# documentation SKILL
# accounting SKILL
# Accounting SKILL
# Oracle SKILL
# Marathon SKILL
# Google SKILL
# Business SKILL
# Release SKILL
# publishing SKILL
# trend analysis SKILL
# unity SKILL
# Business SKILL
# business SKILL
# Payments SKILL
# Communications SKILL
# Business SKILL
# Business Administration SKILL
# Computer Science SKILL
# Computer Science SKILL
# Computer Science SKILL
# Documentation SKILL
# Data Processing SKILL
# Business Administration SKILL
# schedule SKILL
# Business Process SKILL
# payments SKILL
# collaboration SKILL
# support SKILL
# Support SKILL
# Task Management SKILL
# Certificate SKILL
# Business SKILL
# Marketing SKILL
# Business SKILL
# Finance SKILL
# marketing SKILL
# Certificate SKILL
# Support SKILL
# Business SKILL
# Business SKILL
# Finance SKILL
# Marketing SKILL
# Business SKILL
# Project Management SKILL
# Payments SKILL
# CHEF SKILL
# Chef SKILL
# Chef SKILL
# Chef SKILL
# Chef SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# business SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# business SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# business SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# business SKILL
# Schedule SKILL
# Schedule SKILL
# Schedule SKILL
# business SKILL
# collaboration SKILL
# support SKILL
# marketing SKILL
# collaboration SKILL
# Marketing SKILL
# Marketing SKILL
# marketing SKILL
# support SKILL
# design SKILL
# testing SKILL
# mobile SKILL
# business SKILL
# business process SKILL
# Design SKILL
# Design SKILL
# business SKILL
# End Testing SKILL
# Documentation SKILL
# Material SKILL
# Software SKILL
# Business SKILL
# Testing SKILL
# Material SKILL
# Testing SKILL
# business SKILL
# Documentation SKILL
# Testing SKILL
# Testing SKILL
# Testing SKILL
# Testing SKILL
# Testing SKILL
# Security SKILL
# Testing SKILL
# Testing SKILL
# Testing SKILL
# Testing SKILL
# Interface Testing SKILL
# Testing SKILL
# Design SKILL
# Data Analysis SKILL
# Business SKILL
# Testing SKILL
# Documentation SKILL
# Design SKILL
# specification SKILL
# engineering SKILL
# Data analysis SKILL
# Interface Testing SKILL
# Testing SKILL
# business SKILL
# support SKILL
# Testing SKILL
# Business SKILL
# business process SKILL
# business SKILL
# Design SKILL
# Segment SKILL
# Design SKILL
# design SKILL
# schedule SKILL
# Mobile SKILL
# Specification SKILL
# business SKILL
# Material SKILL
# Material SKILL
# front end SKILL
# testing SKILL
# Support SKILL
# Testing SKILL
# Debugging SKILL
# Design SKILL
# data model SKILL
# business SKILL
# design SKILL
# Design SKILL
# Data Extraction SKILL
# Business SKILL
# Mobile SKILL
# End Testing SKILL
# Mobile SKILL
# Design SKILL
# Testing SKILL
# Business SKILL
# Business process SKILL
# End Testing SKILL
# Testing SKILL
# Business SKILL
# documentation SKILL
# testing SKILL
# business SKILL
# design SKILL
# Design SKILL
# testing SKILL
# box SKILL
# box SKILL
# testing SKILL
# business SKILL
# business SKILL
# Business process SKILL
# Data analysis SKILL
# Debugging SKILL
# documentation SKILL
# Design SKILL
# Specification SKILL
# design SKILL
# design SKILL
# material SKILL
# design SKILL
# Design SKILL
# advertising SKILL
# Certificate SKILL
# Design SKILL
# Certificate SKILL
# advertising SKILL
# business SKILL
# Business SKILL
# Project Management SKILL
# business SKILL
# project management SKILL
# documentation SKILL
# marketing SKILL
# marketing SKILL
# workflow SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# workflow SKILL
# interaction SKILL
# workflow SKILL
# workflow SKILL
# workflow SKILL
# business SKILL
# Finance SKILL
# Business SKILL
# Finance SKILL
# Business SKILL
# Business SKILL
# documentation SKILL
# marketing SKILL
# marketing SKILL
# Project Management SKILL
# workflow SKILL
# marketing SKILL
# Google Analytics SKILL
# business SKILL
# advertising SKILL
# marketing SKILL
# mobile SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# advertising SKILL
# advertising SKILL
# advertising SKILL
# Google Analytics SKILL
# Google Analytics SKILL
# advertising SKILL
# Google Analytics SKILL
# Google Analytics SKILL
# Google Analytics SKILL
# advertising SKILL
# Google Analytics SKILL
# marketing SKILL
# Google Analytics SKILL
# business SKILL
# business SKILL
# Marketing SKILL
# Google Analytics SKILL
# Google Analytics SKILL
# Google Analytics SKILL
# Marketing SKILL
# business SKILL
# marketing SKILL
# google analytics SKILL
# Marketing SKILL
# marketing SKILL
# spring SKILL
# Commerce SKILL
# Marketing SKILL
# Business SKILL
# Marketing SKILL
# Spring SKILL
# Spring SKILL
# advertising SKILL
# Google Analytics SKILL
# marketing SKILL
# marketing SKILL
# marketing SKILL
# advertising SKILL
# design SKILL
# Solid Modeling SKILL
# Design SKILL
# solid model SKILL
# component SKILL
# testing SKILL
# design SKILL
# simulation SKILL
# release SKILL
# design SKILL
# engineering SKILL
# design SKILL
# engineering SKILL
# engineering SKILL
# engineering SKILL
# Advertising SKILL
# Marketing SKILL
# Graphic Design SKILL
# Graphic Design SKILL
# Microcomputer SKILL
# Business SKILL
# Graphic Design SKILL
# Microcomputer SKILL
# Business SKILL
# databases SKILL
# debugging SKILL
# design SKILL
# publishing SKILL
# Design SKILL
# marketing SKILL
# FINANCE SKILL
# Accounting SKILL
# accounting SKILL
# accounting SKILL
# documentation SKILL
# Accounting SKILL
# accounting SKILL
# software SKILL
# Finance SKILL
# Certificate SKILL
# Accounting SKILL
# Languages SKILL
# Accounting SKILL
# Finance SKILL
# Windows SKILL
# documentation SKILL
# Project Management SKILL
# Business Administration SKILL
# Business Administration SKILL
# Certificate SKILL
# Security SKILL
# material SKILL
# security SKILL
# Certificate SKILL
# Languages SKILL
# Security SKILL
# Windows SKILL
# Windows SKILL
# Windows SKILL
# Security SKILL
# Project Management SKILL
# Documentation SKILL
# Storage Area Network SKILL
# FINANCE SKILL
# finance SKILL
# analytics SKILL
# project management SKILL
# payments SKILL
# Finance SKILL
# analytics SKILL
# SQL SKILL
# Oracle SKILL
# Business Intelligence SKILL
# Data analysis SKILL
# databases SKILL
# Finance SKILL
# Marketing SKILL
# business SKILL
# support SKILL
# testing SKILL
# Finance SKILL
# mobile SKILL
# payments SKILL
# Business Administration SKILL
# Finance SKILL
# Business Administration SKILL
# Finance SKILL
# Business Intelligence SKILL
# Data analysis SKILL
# databases SKILL
# Finance SKILL
# Marketing SKILL
# Oracle SKILL
# SQL SKILL
# library SKILL
# databases SKILL
# support SKILL
# documentation SKILL
# support SKILL
# support SKILL
# SOFTWARE ENGINEERING SKILL
# business SKILL
# Software SKILL
# Engineering SKILL
# Visual C++ SKILL
# Windows SKILL
# HTTP SKILL
# XML SKILL
# API SKILL
# API SKILL
# design SKILL
# documentation SKILL
# workflow SKILL
# business SKILL
# server SKILL
# ScrumMaster SKILL
# Server SKILL
# business SKILL
# Software SKILL
# C++ SKILL
# HTML5 SKILL
# JavaScript SKILL
# dash SKILL
# C SKILL
# framework SKILL
# testing SKILL
# API SKILL
# specification SKILL
# C++ SKILL
# API SKILL
# framework SKILL
# server SKILL
# API SKILL
# C++ SKILL
# C++ SKILL
# server SKILL
# Software SKILL
# Engineering SKILL
# server SKILL
# Software SKILL
# C++ SKILL
# business SKILL
# Software SKILL
# software SKILL
# C++ SKILL
# Windows SKILL
# Computer Science SKILL
# Computer Science SKILL
# Engineering SKILL
# Engineering SKILL
# API SKILL
# C++ SKILL
# documentation SKILL
# HTML5 SKILL
# XML SKILL
# JavaScript SKILL
# C SKILL
# Windows SKILL
# specification SKILL
# Visual C++ SKILL
# workflow SKILL
# business SKILL
# design SKILL
# business SKILL
# HTML SKILL
# CSS SKILL
# Business SKILL
# design SKILL
# collaboration SKILL
# Communications SKILL
# design SKILL
# graphic design SKILL
# support SKILL
# business SKILL
# business SKILL
# communications SKILL
# support SKILL
# Library SKILL
# library SKILL
# support SKILL
# business SKILL
# business SKILL
# finance SKILL
# documentation SKILL
# database SKILL
# business SKILL
# business SKILL
# marketing SKILL
# business SKILL
# business SKILL
# graphic design SKILL
# material SKILL
# Graphic Design SKILL
# Certificate SKILL
# Design SKILL
# Certificate SKILL
# business SKILL
# communications SKILL
# business SKILL
# CSS SKILL
# database SKILL
# documentation SKILL
# finance SKILL
# Graphic Design SKILL
# HTML SKILL
# marketing SKILL
# design SKILL
# BUSINESS SKILL
# business SKILL
# marketing SKILL
# business SKILL
# Marketing SKILL
# business SKILL
# Business SKILL
# business SKILL
# business SKILL
# business SKILL
# Business SKILL
# Business SKILL
# support SKILL
# Business SKILL
# business SKILL
# business SKILL
# Business SKILL
# Marketing SKILL
# CRM SKILL
# software SKILL
# Salespoint SKILL
# Marketing SKILL
# Business SKILL
# business SKILL
